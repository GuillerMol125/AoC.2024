# %%
import sys, os
import numpy as np
np.set_printoptions(threshold=np.inf)
import pandas as pd
from utils.utils import read_txt, read_txt_np_int
from functools import lru_cache
from math import ceil, floor
from copy import deepcopy

# %% [markdown]
# # INPUT

# %%
inputfilename = './inputs/day24.txt'

inputdata = read_txt(inputfilename)

testdata_small = ["x00: 1",
"x01: 1",
"x02: 1",
"y00: 0",
"y01: 1",
"y02: 0",
"",
"x00 AND y00 -> z00",
"x01 XOR y01 -> z01",
"x02 OR y02 -> z02"]

testdata_large = ["x00: 1",
"x01: 0",
"x02: 1",
"x03: 1",
"x04: 0",
"y00: 1",
"y01: 1",
"y02: 1",
"y03: 1",
"y04: 1",
"",
"ntg XOR fgs -> mjb",
"y02 OR x01 -> tnw",
"kwq OR kpj -> z05",
"x00 OR x03 -> fst",
"tgd XOR rvg -> z01",
"vdt OR tnw -> bfw",
"bfw AND frj -> z10",
"ffh OR nrd -> bqk",
"y00 AND y03 -> djm",
"y03 OR y00 -> psh",
"bqk OR frj -> z08",
"tnw OR fst -> frj",
"gnj AND tgd -> z11",
"bfw XOR mjb -> z00",
"x03 OR x00 -> vdt",
"gnj AND wpb -> z02",
"x04 AND y00 -> kjc",
"djm OR pbm -> qhw",
"nrd AND vdt -> hwm",
"kjc AND fst -> rvg",
"y04 OR y02 -> fgs",
"y01 AND x02 -> pbm",
"ntg OR kjc -> kwq",
"psh XOR fgs -> tgd",
"qhw XOR tgd -> z09",
"pbm OR djm -> kpj",
"x03 XOR y03 -> ffh",
"x00 XOR y04 -> ntg",
"bfw OR bqk -> z06",
"nrd XOR fgs -> wpb",
"frj XOR qhw -> z04",
"bqk OR frj -> z07",
"y03 OR x01 -> nrd",
"hwm AND bqk -> z03",
"tgd XOR rvg -> z12",
"tnw OR pbm -> gnj"]

# %%
data_to_use = inputdata
wires = dict([(line.split(': ')[0], int(line.split(': ')[1])) for line in data_to_use if ': ' in line])

logic_gates = [{'inputs': [line.split(' -> ')[0].split(' ')[i] for i in [0, 2]], 'output': line.split(' -> ')[1], 'operation': line.split(' -> ')[0].split(' ')[1]} for line in data_to_use if ' -> ' in line]

for gate in logic_gates:
    wires[gate['output']] = None

print(logic_gates)
print(wires)

print(f"Len logic gates {len(logic_gates)}")
# Out:
# [{'inputs': ['nsg', 'sdh'], 'output': 'nbq', 'operation': 'AND'}, {'inputs': ['nhs', 'qvh'], 'output': 'z21', 'operation': 'XOR'}, {'inputs': ['htr', 'kdm'], 'output': 'vkt', 'operation': 'OR'}, {'inputs': ['dvb', 'wtv'], 'output': 'cdm', 'operation': 'OR'}, {'inputs': ['x37', 'y37'], 'output': 'jdk', 'operation': 'AND'}, {'inputs': ['y27', 'x27'], 'output': 'snj', 'operation': 'AND'}, {'inputs': ['cnp', 'ddh'], 'output': 'pjt', 'operation': 'OR'}, {'inputs': ['fvp', 'kgr'], 'output': 'vbr', 'operation': 'AND'}, {'inputs': ['fvd', 'rpm'], 'output': 'srq', 'operation': 'OR'}, {'inputs': ['y08', 'x08'], 'output': 'pvm', 'operation': 'AND'}, {'inputs': ['y43', 'x43'], 'output': 'nhq', 'operation': 'AND'}, {'inputs': ['vrk', 'hmt'], 'output': 'tpv', 'operation': 'OR'}, {'inputs': ['y18', 'x18'], 'output': 'kdm', 'operation': 'AND'}, {'inputs': ['x27', 'y27'], 'output': 'nhh', 'operation': 'XOR'}, {'inputs': ['jmc', 'qkk'], 'output': 'z29', 'operation': 'XOR'}, {'inputs': ['x01', 'y01'], 'output': 'hqh', 'operation': 'AND'}, {'inputs': ['y36', 'x36'], 'output': 'hsc', 'operation': 'AND'}, {'inputs': ['y43', 'x43'], 'output': 'wjf', 'operation': 'XOR'}, {'inputs': ['x26', 'y26'], 'output': 'dvb', 'operation': 'AND'}, {'inputs': ['y31', 'x31'], 'output': 'mds', 'operation': 'AND'}, {'inputs': ['qkk', 'jmc'], 'output': 'hnj', 'operation': 'AND'}, {'inputs': ['wjt', 'ftt'], 'output': 'htr', 'operation': 'AND'}, {'inputs': ['x40', 'y40'], 'output': 'bwc', 'operation': 'XOR'}, {'inputs': ['x42', 'y42'], 'output': 'tbp', 'operation': 'AND'}, {'inputs': ['x34', 'y34'], 'output': 'tgb', 'operation': 'AND'}, {'inputs': ['nqg', 'hbn'], 'output': 'wqc', 'operation': 'AND'}, {'inputs': ['hkt', 'sms'], 'output': 'fqk', 'operation': 'OR'}, {'inputs': ['x04', 'y04'], 'output': 'cjg', 'operation': 'AND'}, {'inputs': ['cfd', 'cqd'], 'output': 'z28', 'operation': 'XOR'}, {'inputs': ['jpp', 'tpv'], 'output': 'vqk', 'operation': 'AND'}, {'inputs': ['x17', 'y17'], 'output': 'ppw', 'operation': 'AND'}, {'inputs': ['tvs', 'mkh'], 'output': 'z31', 'operation': 'XOR'}, {'inputs': ['cqw', 'wtc'], 'output': 'dnp', 'operation': 'OR'}, {'inputs': ['y21', 'x21'], 'output': 'qvh', 'operation': 'XOR'}, {'inputs': ['y24', 'x24'], 'output': 'bvn', 'operation': 'AND'}, {'inputs': ['y32', 'x32'], 'output': 'cwr', 'operation': 'XOR'}, {'inputs': ['hsp', 'qnp'], 'output': 'dds', 'operation': 'AND'}, {'inputs': ['x03', 'y03'], 'output': 'vng', 'operation': 'XOR'}, {'inputs': ['hvg', 'gtg'], 'output': 'z10', 'operation': 'XOR'}, {'inputs': ['hpm', 'nhq'], 'output': 'kkt', 'operation': 'OR'}, {'inputs': ['cwn', 'pmt'], 'output': 'z07', 'operation': 'XOR'}, {'inputs': ['y12', 'x12'], 'output': 'nsg', 'operation': 'XOR'}, {'inputs': ['cnv', 'jsj'], 'output': 'ddh', 'operation': 'AND'}, {'inputs': ['srq', 'sdr'], 'output': 'dpm', 'operation': 'AND'}, {'inputs': ['ktj', 'dmh'], 'output': 'z38', 'operation': 'XOR'}, {'inputs': ['tcv', 'gqh'], 'output': 'cdk', 'operation': 'AND'}, {'inputs': ['y13', 'x13'], 'output': 'bfw', 'operation': 'AND'}, {'inputs': ['ptt', 'bvn'], 'output': 'nnw', 'operation': 'OR'}, {'inputs': ['x01', 'y01'], 'output': 'nmk', 'operation': 'XOR'}, {'inputs': ['vnn', 'qjh'], 'output': 'z14', 'operation': 'XOR'}, {'inputs': ['y39', 'x39'], 'output': 'sms', 'operation': 'AND'}, {'inputs': ['y07', 'x07'], 'output': 'tcb', 'operation': 'AND'}, {'inputs': ['x23', 'y23'], 'output': 'cnv', 'operation': 'XOR'}, {'inputs': ['nqg', 'hbn'], 'output': 'z08', 'operation': 'XOR'}, {'inputs': ['ppp', 'pjt'], 'output': 'ptt', 'operation': 'AND'}, {'inputs': ['ngc', 'sdt'], 'output': 'rbk', 'operation': 'AND'}, {'inputs': ['hsp', 'qnp'], 'output': 'z15', 'operation': 'XOR'}, {'inputs': ['y07', 'x07'], 'output': 'cwn', 'operation': 'XOR'}, {'inputs': ['x17', 'y17'], 'output': 'mhm', 'operation': 'XOR'}, {'inputs': ['y12', 'x12'], 'output': 'qjf', 'operation': 'AND'}, {'inputs': ['ssq', 'skd'], 'output': 'nqw', 'operation': 'AND'}, {'inputs': ['y24', 'x24'], 'output': 'ppp', ...
# {'x00': 1, 'x01': 0, 'x02': 0, 'x03': 1, 'x04': 1, 'x05': 1, 'x06': 0, 'x07': 0, 'x08': 0, 'x09': 1, 'x10': 0, 'x11': 0, 'x12': 0, 'x13': 1, 'x14': 1, 'x15': 1, 'x16': 0, 'x17': 0, 'x18': 0, 'x19': 1, 'x20': 0, 'x21': 1, 'x22': 0, 'x23': 1, 'x24': 1, 'x25': 0, 'x26': 1, 'x27': 1, 'x28': 1, 'x29': 0, 'x30': 0, 'x31': 0, 'x32': 0, 'x33': 0, 'x34': 0, 'x35': 1, 'x36': 0, 'x37': 1, 'x38': 1, 'x39': 0, 'x40': 1, 'x41': 0, 'x42': 0, 'x43': 0, 'x44': 1, 'y00': 1, 'y01': 1, 'y02': 1, 'y03': 1, 'y04': 0, 'y05': 1, 'y06': 0, 'y07': 1, 'y08': 0, 'y09': 1, 'y10': 1, 'y11': 1, 'y12': 1, 'y13': 0, 'y14': 1, 'y15': 0, 'y16': 0, 'y17': 0, 'y18': 1, 'y19': 1, 'y20': 0, 'y21': 0, 'y22': 1, 'y23': 0, 'y24': 0, 'y25': 1, 'y26': 0, 'y27': 1, 'y28': 0, 'y29': 0, 'y30': 0, 'y31': 1, 'y32': 1, 'y33': 1, 'y34': 1, 'y35': 0, 'y36': 1, 'y37': 1, 'y38': 1, 'y39': 1, 'y40': 0, 'y41': 1, 'y42': 0, 'y43': 1, 'y44': 1, 'nbq': None, 'z21': None, 'vkt': None, 'cdm': None, 'jdk': None, 'snj': None, 'pjt': None, 'vbr': None, 'srq': None, 'pvm': None, 'nhq': None, 'tpv': None, 'kdm': None, 'nhh': None, 'z29': None, 'hqh': None, 'hsc': None, 'wjf': None, 'dvb': None, 'mds': None, 'hnj': None, 'htr': None, 'bwc': None, 'tbp': None, 'tgb': None, 'wqc': None, 'fqk': None, 'cjg': None, 'z28': None, 'vqk': None, 'ppw': None, 'z31': None, 'dnp': None, 'qvh': None, 'bvn': None, 'cwr': None, 'dds': None, 'vng': None, 'z10': None, 'kkt': None, 'z07': None, 'nsg': None, 'ddh': None, 'dpm': None, 'z38': None, 'cdk': None, 'bfw': None, 'nnw': None, 'nmk': None, 'z14': None, 'sms': None, 'tcb': None, 'cnv': None, 'z08': None, 'ptt': None, 'rbk': None, 'z15': None, 'cwn': None, 'mhm': None, 'qjf': None, 'nqw': None, 'ppp': None, 'bmh': None, 'btb': None, 'cqw': None, 'z36': None, 'vrk': None, 'z20': None, 'cbq': None, 'hvg': None, 'z25': None, 'cgr': None, 'vnh': None, 'vnw': None, 'rmn': None, 'rqv': None, 'wtr': None, 'ddt': None, 'z13': None, 'vss': None, 'z17': None, 'wtc': None, 'ssq': None, 'z32': None, 'z23': None, 'z11': None, 'gwt': None, 'z03': None, 'fgv': None, 'sdh': None, 'rtw': None, 'z42': None, 'qkk': None, 'fmn': None, 'hpm': None, 'z16': None, 'svv': None, 'z43': None, 'cpg': None, 'rpm': None, 'gnv': None, 'ngc': None, 'kgh': None, 'vmf': None, 'mdv': None, 'nqg': None, 'z33': None, 'cqd': None, 'cfd': None, 'qrt': None, 'ftt': None, 'bjm': None, 'rwr': None, 'z00': None, 'z40': None, 'tvs': None, 'msm': None, 'z27': None, 'fcg': None, 'pfk': None, 'fnk': None, 'z05': None, 'wpq': None, 'jtf': None, 'mtq': None, 'kbv': None, 'ddn': None, 'dpq': None, 'fvp': None, 'gqh': None, 'z39': None, 'dgj': None, 'pqq': None, 'tjq': None, 'pht': None, 'dcd': None, 'tts': None, 'z22': None, 'z34': None, 'bfc': None, 'jqs': None, 'z41': None, 'hsp': None, 'rvb': None, 'bss': None, 'hmt': None, 'wvn': None, 'jmp': None, 'mmr': None, 'z35': None, 'z04': None, 'qnp': None, 'z44': None, 'gtg': None, 'pmt': None, 'hdc': None, 'cmn': None, 'z30': None, 'wjt': None, 'tcv': None, 'z06': None, 'scb': None, 'vjd': None, 'qds': None, 'nss': None, 'krm': None, 'z19': None, 'gqt': None, 'nbh': None, 'fgg': None, 'cnp': None, 'qnd': None, 'z37': None, 'z01': None, 'ddr': None, 'sdt': None, 'cmd': None, 'dmh': None, 'hbn': None, 'wkn': None, 'mkh': None, 'jmc': None, 'nnf': None, 'jpp': None, 'z24': None, 'z02': None, 'qjh': None, 'kqh': None, 'dsr': None, 'wtv': None, 'qsd': None, 'nsd': None, 'kbj': None, 'dtk': None, 'wrc': None, 'jsv': None, 'kwf': None, 'gcn': None, 'nhs': None, 'sdr': None, 'jhb': None, 'skd': None, 'spk': None, 'hkt': None, 'ktj': None, 'fvd': None, 'cdh': None, 'vnn': None, 'z09': None, 'z26': None, 'vdc': None, 'kgr': None, 'hjp': None, 'z45': None, 'jsj': None, 'fch': None, 'z12': None, 'pjj': None, 'dtt': None, 'wnq': None, 'z18': None, 'dnw': None}
# Len logic gates 222

# %% [markdown]
# # PART 1

# %%
def AND(x, y):
    return x and y

def OR(x, y):
    return x or y

def XOR(x,y):
    return x ^ y

def compute_gate(gate):
    # Missing input
    if any([wires[input] is None for input in gate['inputs']]):
        return None
    # Output already exists
    if wires[gate['output']] is not None:
        return None
    print(f"Evaluating...")
    wires[gate['output']] = eval(f"{gate['operation']}({wires[gate['inputs'][0]]},{wires[gate['inputs'][1]]})")
    return 1

def compute_all_gates(logic_gates):
    pending_logic_gates = logic_gates.copy()
    while len(pending_logic_gates) > 0:        
        next_gate = pending_logic_gates.pop(0)
        print(f"Running gate {next_gate}")
        if compute_gate(next_gate) is None:
            pending_logic_gates.append(next_gate)
    
    bin_solution = ''.join([str(wires[val]) for val in [out_val for out_val in reversed(sorted(wires)) if out_val[0] == 'z'] ])
    print(f"Solution: {bin_solution}")

    print(f"Number: {int(bin_solution, 2)}")

compute_all_gates(logic_gates)
# Out:
# Running gate {'inputs': ['nsg', 'sdh'], 'output': 'nbq', 'operation': 'AND'}
# Running gate {'inputs': ['nhs', 'qvh'], 'output': 'z21', 'operation': 'XOR'}
# Running gate {'inputs': ['htr', 'kdm'], 'output': 'vkt', 'operation': 'OR'}
# Running gate {'inputs': ['dvb', 'wtv'], 'output': 'cdm', 'operation': 'OR'}
# Running gate {'inputs': ['x37', 'y37'], 'output': 'jdk', 'operation': 'AND'}
# Evaluating...
# Running gate {'inputs': ['y27', 'x27'], 'output': 'snj', 'operation': 'AND'}
# Evaluating...
# Running gate {'inputs': ['cnp', 'ddh'], 'output': 'pjt', 'operation': 'OR'}
# Running gate {'inputs': ['fvp', 'kgr'], 'output': 'vbr', 'operation': 'AND'}
# Running gate {'inputs': ['fvd', 'rpm'], 'output': 'srq', 'operation': 'OR'}
# Running gate {'inputs': ['y08', 'x08'], 'output': 'pvm', 'operation': 'AND'}
# Evaluating...
# Running gate {'inputs': ['y43', 'x43'], 'output': 'nhq', 'operation': 'AND'}
# Evaluating...
# Running gate {'inputs': ['vrk', 'hmt'], 'output': 'tpv', 'operation': 'OR'}
# Running gate {'inputs': ['y18', 'x18'], 'output': 'kdm', 'operation': 'AND'}
# Evaluating...
# Running gate {'inputs': ['x27', 'y27'], 'output': 'nhh', 'operation': 'XOR'}
# Evaluating...
# Running gate {'inputs': ['jmc', 'qkk'], 'output': 'z29', 'operation': 'XOR'}
# Running gate {'inputs': ['x01', 'y01'], 'output': 'hqh', 'operation': 'AND'}
# Evaluating...
# Running gate {'inputs': ['y36', 'x36'], 'output': 'hsc', 'operation': 'AND'}
# Evaluating...
# Running gate {'inputs': ['y43', 'x43'], 'output': 'wjf', 'operation': 'XOR'}
# Evaluating...
# Running gate {'inputs': ['x26', 'y26'], 'output': 'dvb', 'operation': 'AND'}
# Evaluating...
# Running gate {'inputs': ['y31', 'x31'], 'output': 'mds', 'operation': 'AND'}
# Evaluating...
# Running gate {'inputs': ['qkk', 'jmc'], 'output': 'hnj', 'operation': 'AND'}
# Running gate {'inputs': ['wjt', 'ftt'], 'output': 'htr', 'operation': 'AND'}
# Running gate {'inputs': ['x40', 'y40'], 'output': 'bwc', 'operation': 'XOR'}
# Evaluating...
# Running gate {'inputs': ['x42', 'y42'], 'output': 'tbp', 'operation': 'AND'}
# Evaluating...
# Running gate {'inputs': ['x34', 'y34'], 'output': 'tgb', 'operation': 'AND'}
# Evaluating...
# Running gate {'inputs': ['nqg', 'hbn'], 'output': 'wqc', 'operation': 'AND'}
# Running gate {'inputs': ['hkt', 'sms'], 'output': 'fqk', 'operation': 'OR'}
# Running gate {'inputs': ['x04', 'y04'], 'output': 'cjg', 'operation': 'AND'}
# Evaluating...
# Running gate {'inputs': ['cfd', 'cqd'], 'output': 'z28', 'operation': 'XOR'}
# Running gate {'inputs': ['jpp', 'tpv'], 'output': 'vqk', 'operation': 'AND'}
# Running gate {'inputs': ['x17', 'y17'], 'output': 'ppw', 'operation': 'AND'}
# Evaluating...
# Running gate {'inputs': ['tvs', 'mkh'], 'output': 'z31', 'operation': 'XOR'}
# Running gate {'inputs': ['cqw', 'wtc'], 'output': 'dnp', 'operation': 'OR'}
# Running gate {'inputs': ['y21', 'x21'], 'output': 'qvh', 'operation': 'XOR'}
# Evaluating...
# Running gate {'inputs': ['y24', 'x24'], 'output': 'bvn', 'operation': 'AND'}
# Evaluating...
# Running gate {'inputs': ['y32', 'x32'], 'output': 'cwr', 'operation': 'XOR'}
# Evaluating...
# Running gate {'inputs': ['hsp', 'qnp'], 'output': 'dds', 'operation': 'AND'}
# Running gate {'inputs': ['x03', 'y03'], 'output': 'vng', 'operation': 'XOR'}
# Evaluating...
# Running gate {'inputs': ['hvg', 'gtg'], 'output': 'z10', 'operation': 'XOR'}
# Running gate {'inputs': ['hpm', 'nhq'], 'output': 'kkt', 'operation': 'OR'}
# Running gate {'inputs': ['cwn', 'pmt'], 'output': 'z07', 'operation': 'XOR'}
# Running gate {'inputs': ['y12', 'x12'], 'output': 'nsg', 'operation': 'XOR'}
# Evaluating...
# Running gate {'inputs': ['cnv', 'jsj'], 'output': 'ddh', 'operation': 'AND'}
# Running gate {'inputs': ['srq', 'sdr'], 'output': 'dpm', 'operation': 'AND'}
# Running gate {'inputs': ['ktj', 'dmh'], 'output': 'z38', 'operation': 'XOR'}
# Running gate {'inputs': ['tcv', 'gqh'], 'output': 'cdk', 'operation': 'AND'}
# Running gate {'inputs': ['y13', 'x13'], 'output': 'bfw', 'operation': 'AND'}
# Evaluating...
# Running gate {'inputs': ['ptt', 'bvn'], 'output': 'nnw', 'operation': 'OR'}
# Running gate {'inputs': ['x01', 'y01'], 'output': 'nmk', 'operation': 'XOR'}
# Evaluating...
# Running gate {'inputs': ['vnn', 'qjh'], 'output': 'z14', 'operation': 'XOR'}
# Running gate {'inputs': ['y39', 'x39'], 'output': 'sms', 'operation': 'AND'}
# Evaluating...
# Running gate {'inputs': ['y07', 'x07'], 'output': 'tcb', 'operation': 'AND'}
# Evaluating...
# Running gate {'inputs': ['x23', 'y23'], 'output': 'cnv', 'operation': 'XOR'}
# Evaluating...
# Running gate {'inputs': ['nqg', 'hbn'], 'output': 'z08', 'operation': 'XOR'}
# Running gate {'inputs': ['ppp', 'pjt'], 'output': 'ptt', 'operation': 'AND'}
# Running gate {'inputs': ['ngc', 'sdt'], 'output': 'rbk', 'operation': 'AND'}
# Running gate {'inputs': ['hsp', 'qnp'], 'output': 'z15', 'operation': 'XOR'}
# Running gate {'inputs': ['y07', 'x07'], 'output': 'cwn', 'operation': 'XOR'}
# Evaluating...
# Running gate {'inputs': ['x17', 'y17'], 'output': 'mhm', 'operation': 'XOR'}
# Evaluating...
# Running gate {'inputs': ['y12', 'x12'], 'output': 'qjf', 'operation': 'AND'}
# Evaluating...
# Running gate {'inputs': ['ssq', 'skd'], 'output': 'nqw', 'operation': 'AND'}
# Running gate {'inputs': ['y24', 'x24'], 'output': 'ppp', 'operation': 'XOR'}
# Evaluating...
# Running gate {'inputs': ['x34', 'y34'], 'output': 'bmh', 'operation': 'XOR'}
# Evaluating...
# Running gate {'inputs': ['x15', 'y15'], 'output': 'btb', 'operation': 'AND'}
# Evaluating...
# Running gate {'inputs': ['cmd', 'pfk'], 'output': 'cqw', 'operation': 'AND'}
# Running gate {'inputs': ['scb', 'dnp'], 'output': 'z36', 'operation': 'XOR'}
# Running gate {'inputs': ['mmr', 'cgr'], 'output': 'vrk', 'operation': 'AND'}
# Running gate {'inputs': ['cdk', 'rmn'], 'output': 'z20', 'operation': 'OR'}
# Running gate {'inputs': ['x44', 'y44'], 'output': 'cbq', 'operation': 'XOR'}
# Evaluating...
# Running gate {'inputs': ['nnf', 'vbr'], 'output': 'hvg', 'operation': 'OR'}
# Running gate {'inputs': ['nnw', 'qnd'], 'output': 'z25', 'operation': 'XOR'}
# Running gate {'inputs': ['y05', 'x05'], 'output': 'cgr', 'operation': 'XOR'}
# Evaluating...
# Running gate {'inputs': ['y37', 'x37'], 'output': 'vnh', 'operation': 'XOR'}
# Evaluating...
# Running gate {'inputs': ['jmp', 'nqw'], 'output': 'vnw', 'operation': 'OR'}
# Running gate {'inputs': ['y20', 'x20'], 'output': 'rmn', 'operation': 'AND'}
# Evaluating...
# Running gate {'inputs': ['y44', 'x44'], 'output': 'rqv', 'operation': 'AND'}
# Evaluating...
# Running gate {'inputs': ['bjm', 'vkt'], 'output': 'wtr', 'operation': 'AND'}
# Running gate {'inputs': ['x29', 'y29'], 'output': 'ddt', 'operation': 'AND'}
# Evaluating...
# Running gate {'inputs': ['kbj', 'nsd'], 'output': 'z13', 'operation': 'XOR'}
# Running gate {'inputs': ['nss', 'vjd'], 'output': 'vss', 'operation': 'OR'}
# Running gate {'inputs': ['hjp', 'mhm'], 'output': 'z17', 'operation': 'XOR'}
# Running gate {'inputs': ['y35', 'x35'], 'output': 'wtc', 'operation': 'AND'}
# Evaluating...
# Running gate {'inputs': ['x02', 'y02'], 'output': 'ssq', 'operation': 'XOR'}
# Evaluating...
# Running gate {'inputs': ['fnk', 'cwr'], 'output': 'z32', 'operation': 'XOR'}
# Running gate {'inputs': ['jsj', 'cnv'], 'output': 'z23', 'operation': 'XOR'}
# Running gate {'inputs': ['rtw', 'wpq'], 'output': 'z11', 'operation': 'XOR'}
# Running gate {'inputs': ['x22', 'y22'], 'output': 'gwt', 'operation': 'AND'}
# Evaluating...
# Running gate {'inputs': ['vng', 'vnw'], 'output': 'z03', 'operation': 'XOR'}
# Running gate {'inputs': ['vnn', 'qjh'], 'output': 'fgv', 'operation': 'AND'}
# Running gate {'inputs': ['kwf', 'nbh'], 'output': 'sdh', 'operation': 'OR'}
# Running gate {'inputs': ['y11', 'x11'], 'output': 'rtw', 'operation': 'XOR'}
# Evaluating...
# Running gate {'inputs': ['kbv', 'bfc'], 'output': 'z42', 'operation': 'XOR'}
# Running gate {'inputs': ['x29', 'y29'], 'output': 'qkk', 'operation': 'XOR'}
# Evaluating...
# Running gate {'inputs': ['hnj', 'ddt'], 'output': 'fmn', 'operation': 'OR'}
# Running gate {'inputs': ['wjf', 'dcd'], 'output': 'hpm', 'operation': 'AND'}
# Running gate {'inputs': ['ddr', 'wkn'], 'output': 'z16', 'operation': 'XOR'}
# Running gate {'inputs': ['krm', 'vdc'], 'output': 'svv', 'operation': 'AND'}
# Running gate {'inputs': ['wjf', 'dcd'], 'output': 'z43', 'operation': 'XOR'}
# Running gate {'inputs': ['y26', 'x26'], 'output': 'cpg', 'operation': 'XOR'}
# Evaluating...
# Running gate {'inputs': ['y40', 'x40'], 'output': 'rpm', 'operation': 'AND'}
# Evaluating...
# Running gate {'inputs': ['qnd', 'nnw'], 'output': 'gnv', 'operation': 'AND'}
# Running gate {'inputs': ['x33', 'y33'], 'output': 'ngc', 'operation': 'XOR'}
# Evaluating...
# Running gate {'inputs': ['y06', 'x06'], 'output': 'kgh', 'operation': 'AND'}
# Evaluating...
# Running gate {'inputs': ['nhh', 'cdm'], 'output': 'vmf', 'operation': 'AND'}
# Running gate {'inputs': ['y33', 'x33'], 'output': 'mdv', 'operation': 'AND'}
# Evaluating...
# Running gate {'inputs': ['tcb', 'fgg'], 'output': 'nqg', 'operation': 'OR'}
# Running gate {'inputs': ['sdt', 'ngc'], 'output': 'z33', 'operation': 'XOR'}
# Running gate {'inputs': ['y28', 'x28'], 'output': 'cqd', 'operation': 'XOR'}
# Evaluating...
# Running gate {'inputs': ['vmf', 'snj'], 'output': 'cfd', 'operation': 'OR'}
# Running gate {'inputs': ['nmk', 'dsr'], 'output': 'qrt', 'operation': 'AND'}
# Running gate {'inputs': ['y18', 'x18'], 'output': 'ftt', 'operation': 'XOR'}
# Evaluating...
# Running gate {'inputs': ['y19', 'x19'], 'output': 'bjm', 'operation': 'XOR'}
# Evaluating...
# Running gate {'inputs': ['x19', 'y19'], 'output': 'rwr', 'operation': 'AND'}
# Evaluating...
# Running gate {'inputs': ['x00', 'y00'], 'output': 'z00', 'operation': 'XOR'}
# Evaluating...
# Running gate {'inputs': ['bwc', 'fqk'], 'output': 'z40', 'operation': 'XOR'}
# Running gate {'inputs': ['y31', 'x31'], 'output': 'tvs', 'operation': 'XOR'}
# Evaluating...
# Running gate {'inputs': ['ktj', 'dmh'], 'output': 'msm', 'operation': 'AND'}
# Running gate {'inputs': ['nhh', 'cdm'], 'output': 'z27', 'operation': 'XOR'}
# Running gate {'inputs': ['vng', 'vnw'], 'output': 'fcg', 'operation': 'AND'}
# Running gate {'inputs': ['wrc', 'tgb'], 'output': 'pfk', 'operation': 'OR'}
# Running gate {'inputs': ['mds', 'cmn'], 'output': 'fnk', 'operation': 'OR'}
# Running gate {'inputs': ['mmr', 'cgr'], 'output': 'z05', 'operation': 'XOR'}
# Running gate {'inputs': ['pjj', 'wvn'], 'output': 'wpq', 'operation': 'OR'}
# Running gate {'inputs': ['mtq', 'vnh'], 'output': 'jtf', 'operation': 'AND'}
# Running gate {'inputs': ['hsc', 'dpq'], 'output': 'mtq', 'operation': 'OR'}
# Running gate {'inputs': ['x42', 'y42'], 'output': 'kbv', 'operation': 'XOR'}
# Evaluating...
# Running gate {'inputs': ['y30', 'x30'], 'output': 'ddn', 'operation': 'XOR'}
# Evaluating...
# Running gate {'inputs': ['scb', 'dnp'], 'output': 'dpq', 'operation': 'AND'}
# Running gate {'inputs': ['y09', 'x09'], 'output': 'fvp', 'operation': 'XOR'}
# Evaluating...
# Running gate {'inputs': ['x20', 'y20'], 'output': 'gqh', 'operation': 'XOR'}
# Evaluating...
# Running gate {'inputs': ['bss', 'fch'], 'output': 'z39', 'operation': 'XOR'}
# Running gate {'inputs': ['x28', 'y28'], 'output': 'dgj', 'operation': 'AND'}
# Evaluating...
# Running gate {'inputs': ['y41', 'x41'], 'output': 'pqq', 'operation': 'AND'}
# Evaluating...
# Running gate {'inputs': ['vss', 'wnq'], 'output': 'tjq', 'operation': 'AND'}
# Running gate {'inputs': ['cfd', 'cqd'], 'output': 'pht', 'operation': 'AND'}
# Running gate {'inputs': ['tbp', 'tts'], 'output': 'dcd', 'operation': 'OR'}
# Running gate {'inputs': ['bfc', 'kbv'], 'output': 'tts', 'operation': 'AND'}
# Running gate {'inputs': ['wnq', 'vss'], 'output': 'z22', 'operation': 'XOR'}
# Running gate {'inputs': ['bmh', 'spk'], 'output': 'z34', 'operation': 'AND'}
# Running gate {'inputs': ['dpm', 'pqq'], 'output': 'bfc', 'operation': 'OR'}
# Running gate {'inputs': ['hjp', 'mhm'], 'output': 'jqs', 'operation': 'AND'}
# Running gate {'inputs': ['srq', 'sdr'], 'output': 'z41', 'operation': 'XOR'}
# Running gate {'inputs': ['jhb', 'fgv'], 'output': 'hsp', 'operation': 'OR'}
# Running gate {'inputs': ['gqt', 'gnv'], 'output': 'rvb', 'operation': 'OR'}
# Running gate {'inputs': ['y39', 'x39'], 'output': 'bss', 'operation': 'XOR'}
# Evaluating...
# Running gate {'inputs': ['y05', 'x05'], 'output': 'hmt', 'operation': 'AND'}
# Evaluating...
# Running gate {'inputs': ['gtg', 'hvg'], 'output': 'wvn', 'operation': 'AND'}
# Running gate {'inputs': ['y02', 'x02'], 'output': 'jmp', 'operation': 'AND'}
# Evaluating...
# Running gate {'inputs': ['svv', 'cjg'], 'output': 'mmr', 'operation': 'OR'}
# Running gate {'inputs': ['pfk', 'cmd'], 'output': 'z35', 'operation': 'XOR'}
# Running gate {'inputs': ['krm', 'vdc'], 'output': 'z04', 'operation': 'XOR'}
# Running gate {'inputs': ['x15', 'y15'], 'output': 'qnp', 'operation': 'XOR'}
# Evaluating...
# Running gate {'inputs': ['kkt', 'cbq'], 'output': 'z44', 'operation': 'XOR'}
# Running gate {'inputs': ['y10', 'x10'], 'output': 'gtg', 'operation': 'XOR'}
# Evaluating...
# Running gate {'inputs': ['vqk', 'kgh'], 'output': 'pmt', 'operation': 'OR'}
# Running gate {'inputs': ['kbj', 'nsd'], 'output': 'hdc', 'operation': 'AND'}
# Running gate {'inputs': ['mkh', 'tvs'], 'output': 'cmn', 'operation': 'AND'}
# Running gate {'inputs': ['fmn', 'kqh'], 'output': 'z30', 'operation': 'XOR'}
# Running gate {'inputs': ['ppw', 'jqs'], 'output': 'wjt', 'operation': 'OR'}
# Running gate {'inputs': ['wtr', 'rwr'], 'output': 'tcv', 'operation': 'OR'}
# Running gate {'inputs': ['jpp', 'tpv'], 'output': 'z06', 'operation': 'XOR'}
# Running gate {'inputs': ['y36', 'x36'], 'output': 'scb', 'operation': 'XOR'}
# Evaluating...
# Running gate {'inputs': ['nhs', 'qvh'], 'output': 'vjd', 'operation': 'AND'}
# Running gate {'inputs': ['x03', 'y03'], 'output': 'qds', 'operation': 'AND'}
# Evaluating...
# Running gate {'inputs': ['y21', 'x21'], 'output': 'nss', 'operation': 'AND'}
# Evaluating...
# Running gate {'inputs': ['x04', 'y04'], 'output': 'krm', 'operation': 'XOR'}
# Evaluating...
# Running gate {'inputs': ['bjm', 'vkt'], 'output': 'z19', 'operation': 'XOR'}
# Running gate {'inputs': ['x25', 'y25'], 'output': 'gqt', 'operation': 'AND'}
# Evaluating...
# Running gate {'inputs': ['rtw', 'wpq'], 'output': 'nbh', 'operation': 'AND'}
# Running gate {'inputs': ['cwn', 'pmt'], 'output': 'fgg', 'operation': 'AND'}
# Running gate {'inputs': ['x23', 'y23'], 'output': 'cnp', 'operation': 'AND'}
# Evaluating...
# Running gate {'inputs': ['y25', 'x25'], 'output': 'qnd', 'operation': 'XOR'}
# Evaluating...
# Running gate {'inputs': ['vnh', 'mtq'], 'output': 'z37', 'operation': 'XOR'}
# Running gate {'inputs': ['nmk', 'dsr'], 'output': 'z01', 'operation': 'XOR'}
# Running gate {'inputs': ['dds', 'btb'], 'output': 'ddr', 'operation': 'OR'}
# Running gate {'inputs': ['dnw', 'dtt'], 'output': 'sdt', 'operation': 'OR'}
# Running gate {'inputs': ['y35', 'x35'], 'output': 'cmd', 'operation': 'XOR'}
# Evaluating...
# Running gate {'inputs': ['y38', 'x38'], 'output': 'dmh', 'operation': 'XOR'}
# Evaluating...
# Running gate {'inputs': ['y08', 'x08'], 'output': 'hbn', 'operation': 'XOR'}
# Evaluating...
# Running gate {'inputs': ['x16', 'y16'], 'output': 'wkn', 'operation': 'XOR'}
# Evaluating...
# Running gate {'inputs': ['dtk', 'ddn'], 'output': 'mkh', 'operation': 'OR'}
# Running gate {'inputs': ['pht', 'dgj'], 'output': 'jmc', 'operation': 'OR'}
# Running gate {'inputs': ['kgr', 'fvp'], 'output': 'nnf', 'operation': 'XOR'}
# Running gate {'inputs': ['y06', 'x06'], 'output': 'jpp', 'operation': 'XOR'}
# Evaluating...
# Running gate {'inputs': ['pjt', 'ppp'], 'output': 'z24', 'operation': 'XOR'}
# Running gate {'inputs': ['skd', 'ssq'], 'output': 'z02', 'operation': 'XOR'}
# Running gate {'inputs': ['x14', 'y14'], 'output': 'qjh', 'operation': 'XOR'}
# Evaluating...
# Running gate {'inputs': ['x30', 'y30'], 'output': 'kqh', 'operation': 'AND'}
# Evaluating...
# Running gate {'inputs': ['x00', 'y00'], 'output': 'dsr', 'operation': 'AND'}
# Evaluating...
# Running gate {'inputs': ['rvb', 'cpg'], 'output': 'wtv', 'operation': 'AND'}
# Running gate {'inputs': ['y16', 'x16'], 'output': 'qsd', 'operation': 'AND'}
# Evaluating...
# Running gate {'inputs': ['x13', 'y13'], 'output': 'nsd', 'operation': 'XOR'}
# Evaluating...
# Running gate {'inputs': ['nbq', 'qjf'], 'output': 'kbj', 'operation': 'OR'}
# Running gate {'inputs': ['kqh', 'fmn'], 'output': 'dtk', 'operation': 'AND'}
# Running gate {'inputs': ['spk', 'bmh'], 'output': 'wrc', 'operation': 'XOR'}
# Running gate {'inputs': ['ddr', 'wkn'], 'output': 'jsv', 'operation': 'AND'}
# Running gate {'inputs': ['y11', 'x11'], 'output': 'kwf', 'operation': 'AND'}
# Evaluating...
# Running gate {'inputs': ['y38', 'x38'], 'output': 'gcn', 'operation': 'AND'}
# Evaluating...
# Running gate {'inputs': ['gqh', 'tcv'], 'output': 'nhs', 'operation': 'XOR'}
# Running gate {'inputs': ['y41', 'x41'], 'output': 'sdr', 'operation': 'XOR'}
# Evaluating...
# Running gate {'inputs': ['y14', 'x14'], 'output': 'jhb', 'operation': 'AND'}
# Evaluating...
# Running gate {'inputs': ['hqh', 'qrt'], 'output': 'skd', 'operation': 'OR'}
# Running gate {'inputs': ['rbk', 'mdv'], 'output': 'spk', 'operation': 'OR'}
# Running gate {'inputs': ['bss', 'fch'], 'output': 'hkt', 'operation': 'AND'}
# Running gate {'inputs': ['jtf', 'jdk'], 'output': 'ktj', 'operation': 'OR'}
# Running gate {'inputs': ['bwc', 'fqk'], 'output': 'fvd', 'operation': 'AND'}
# Running gate {'inputs': ['cbq', 'kkt'], 'output': 'cdh', 'operation': 'AND'}
# Running gate {'inputs': ['hdc', 'bfw'], 'output': 'vnn', 'operation': 'OR'}
# Running gate {'inputs': ['y09', 'x09'], 'output': 'z09', 'operation': 'AND'}
# Evaluating...
# Running gate {'inputs': ['rvb', 'cpg'], 'output': 'z26', 'operation': 'XOR'}
# Running gate {'inputs': ['qds', 'fcg'], 'output': 'vdc', 'operation': 'OR'}
# Running gate {'inputs': ['wqc', 'pvm'], 'output': 'kgr', 'operation': 'OR'}
# Running gate {'inputs': ['jsv', 'qsd'], 'output': 'hjp', 'operation': 'OR'}
# Running gate {'inputs': ['cdh', 'rqv'], 'output': 'z45', 'operation': 'OR'}
# Running gate {'inputs': ['tjq', 'gwt'], 'output': 'jsj', 'operation': 'OR'}
# Running gate {'inputs': ['msm', 'gcn'], 'output': 'fch', 'operation': 'OR'}
# Running gate {'inputs': ['sdh', 'nsg'], 'output': 'z12', 'operation': 'XOR'}
# Running gate {'inputs': ['y10', 'x10'], 'output': 'pjj', 'operation': 'AND'}
# Evaluating...
# Running gate {'inputs': ['cwr', 'fnk'], 'output': 'dtt', 'operation': 'AND'}
# Running gate {'inputs': ['y22', 'x22'], 'output': 'wnq', 'operation': 'XOR'}
# Evaluating...
# Running gate {'inputs': ['wjt', 'ftt'], 'output': 'z18', 'operation': 'XOR'}
# Running gate {'inputs': ['y32', 'x32'], 'output': 'dnw', 'operation': 'AND'}
# Evaluating...
# Running gate {'inputs': ['nsg', 'sdh'], 'output': 'nbq', 'operation': 'AND'}
# Running gate {'inputs': ['nhs', 'qvh'], 'output': 'z21', 'operation': 'XOR'}
# Running gate {'inputs': ['htr', 'kdm'], 'output': 'vkt', 'operation': 'OR'}
# Running gate {'inputs': ['dvb', 'wtv'], 'output': 'cdm', 'operation': 'OR'}
# Running gate {'inputs': ['cnp', 'ddh'], 'output': 'pjt', 'operation': 'OR'}
# Running gate {'inputs': ['fvp', 'kgr'], 'output': 'vbr', 'operation': 'AND'}
# Running gate {'inputs': ['fvd', 'rpm'], 'output': 'srq', 'operation': 'OR'}
# Running gate {'inputs': ['vrk', 'hmt'], 'output': 'tpv', 'operation': 'OR'}
# Running gate {'inputs': ['jmc', 'qkk'], 'output': 'z29', 'operation': 'XOR'}
# Running gate {'inputs': ['qkk', 'jmc'], 'output': 'hnj', 'operation': 'AND'}
# Running gate {'inputs': ['wjt', 'ftt'], 'output': 'htr', 'operation': 'AND'}
# Running gate {'inputs': ['nqg', 'hbn'], 'output': 'wqc', 'operation': 'AND'}
# Running gate {'inputs': ['hkt', 'sms'], 'output': 'fqk', 'operation': 'OR'}
# Running gate {'inputs': ['cfd', 'cqd'], 'output': 'z28', 'operation': 'XOR'}
# Running gate {'inputs': ['jpp', 'tpv'], 'output': 'vqk', 'operation': 'AND'}
# Running gate {'inputs': ['tvs', 'mkh'], 'output': 'z31', 'operation': 'XOR'}
# Running gate {'inputs': ['cqw', 'wtc'], 'output': 'dnp', 'operation': 'OR'}
# Running gate {'inputs': ['hsp', 'qnp'], 'output': 'dds', 'operation': 'AND'}
# Running gate {'inputs': ['hvg', 'gtg'], 'output': 'z10', 'operation': 'XOR'}
# Running gate {'inputs': ['hpm', 'nhq'], 'output': 'kkt', 'operation': 'OR'}
# Running gate {'inputs': ['cwn', 'pmt'], 'output': 'z07', 'operation': 'XOR'}
# Running gate {'inputs': ['cnv', 'jsj'], 'output': 'ddh', 'operation': 'AND'}
# Running gate {'inputs': ['srq', 'sdr'], 'output': 'dpm', 'operation': 'AND'}
# Running gate {'inputs': ['ktj', 'dmh'], 'output': 'z38', 'operation': 'XOR'}
# Running gate {'inputs': ['tcv', 'gqh'], 'output': 'cdk', 'operation': 'AND'}
# Running gate {'inputs': ['ptt', 'bvn'], 'output': 'nnw', 'operation': 'OR'}
# Running gate {'inputs': ['vnn', 'qjh'], 'output': 'z14', 'operation': 'XOR'}
# Running gate {'inputs': ['nqg', 'hbn'], 'output': 'z08', 'operation': 'XOR'}
# Running gate {'inputs': ['ppp', 'pjt'], 'output': 'ptt', 'operation': 'AND'}
# Running gate {'inputs': ['ngc', 'sdt'], 'output': 'rbk', 'operation': 'AND'}
# Running gate {'inputs': ['hsp', 'qnp'], 'output': 'z15', 'operation': 'XOR'}
# Running gate {'inputs': ['ssq', 'skd'], 'output': 'nqw', 'operation': 'AND'}
# Running gate {'inputs': ['cmd', 'pfk'], 'output': 'cqw', 'operation': 'AND'}
# Running gate {'inputs': ['scb', 'dnp'], 'output': 'z36', 'operation': 'XOR'}
# Running gate {'inputs': ['mmr', 'cgr'], 'output': 'vrk', 'operation': 'AND'}
# Running gate {'inputs': ['cdk', 'rmn'], 'output': 'z20', 'operation': 'OR'}
# Running gate {'inputs': ['nnf', 'vbr'], 'output': 'hvg', 'operation': 'OR'}
# Running gate {'inputs': ['nnw', 'qnd'], 'output': 'z25', 'operation': 'XOR'}
# Running gate {'inputs': ['jmp', 'nqw'], 'output': 'vnw', 'operation': 'OR'}
# Running gate {'inputs': ['bjm', 'vkt'], 'output': 'wtr', 'operation': 'AND'}
# Running gate {'inputs': ['kbj', 'nsd'], 'output': 'z13', 'operation': 'XOR'}
# Running gate {'inputs': ['nss', 'vjd'], 'output': 'vss', 'operation': 'OR'}
# Running gate {'inputs': ['hjp', 'mhm'], 'output': 'z17', 'operation': 'XOR'}
# Running gate {'inputs': ['fnk', 'cwr'], 'output': 'z32', 'operation': 'XOR'}
# Running gate {'inputs': ['jsj', 'cnv'], 'output': 'z23', 'operation': 'XOR'}
# Running gate {'inputs': ['rtw', 'wpq'], 'output': 'z11', 'operation': 'XOR'}
# Running gate {'inputs': ['vng', 'vnw'], 'output': 'z03', 'operation': 'XOR'}
# Running gate {'inputs': ['vnn', 'qjh'], 'output': 'fgv', 'operation': 'AND'}
# Running gate {'inputs': ['kwf', 'nbh'], 'output': 'sdh', 'operation': 'OR'}
# Running gate {'inputs': ['kbv', 'bfc'], 'output': 'z42', 'operation': 'XOR'}
# Running gate {'inputs': ['hnj', 'ddt'], 'output': 'fmn', 'operation': 'OR'}
# Running gate {'inputs': ['wjf', 'dcd'], 'output': 'hpm', 'operation': 'AND'}
# Running gate {'inputs': ['ddr', 'wkn'], 'output': 'z16', 'operation': 'XOR'}
# Running gate {'inputs': ['krm', 'vdc'], 'output': 'svv', 'operation': 'AND'}
# Running gate {'inputs': ['wjf', 'dcd'], 'output': 'z43', 'operation': 'XOR'}
# Running gate {'inputs': ['qnd', 'nnw'], 'output': 'gnv', 'operation': 'AND'}
# Running gate {'inputs': ['nhh', 'cdm'], 'output': 'vmf', 'operation': 'AND'}
# Running gate {'inputs': ['tcb', 'fgg'], 'output': 'nqg', 'operation': 'OR'}
# Running gate {'inputs': ['sdt', 'ngc'], 'output': 'z33', 'operation': 'XOR'}
# Running gate {'inputs': ['vmf', 'snj'], 'output': 'cfd', 'operation': 'OR'}
# Running gate {'inputs': ['nmk', 'dsr'], 'output': 'qrt', 'operation': 'AND'}
# Evaluating...
# Running gate {'inputs': ['bwc', 'fqk'], 'output': 'z40', 'operation': 'XOR'}
# Running gate {'inputs': ['ktj', 'dmh'], 'output': 'msm', 'operation': 'AND'}
# Running gate {'inputs': ['nhh', 'cdm'], 'output': 'z27', 'operation': 'XOR'}
# Running gate {'inputs': ['vng', 'vnw'], 'output': 'fcg', 'operation': 'AND'}
# Running gate {'inputs': ['wrc', 'tgb'], 'output': 'pfk', 'operation': 'OR'}
# Running gate {'inputs': ['mds', 'cmn'], 'output': 'fnk', 'operation': 'OR'}
# Running gate {'inputs': ['mmr', 'cgr'], 'output': 'z05', 'operation': 'XOR'}
# Running gate {'inputs': ['pjj', 'wvn'], 'output': 'wpq', 'operation': 'OR'}
# Running gate {'inputs': ['mtq', 'vnh'], 'output': 'jtf', 'operation': 'AND'}
# Running gate {'inputs': ['hsc', 'dpq'], 'output': 'mtq', 'operation': 'OR'}
# Running gate {'inputs': ['scb', 'dnp'], 'output': 'dpq', 'operation': 'AND'}
# Running gate {'inputs': ['bss', 'fch'], 'output': 'z39', 'operation': 'XOR'}
# Running gate {'inputs': ['vss', 'wnq'], 'output': 'tjq', 'operation': 'AND'}
# Running gate {'inputs': ['cfd', 'cqd'], 'output': 'pht', 'operation': 'AND'}
# Running gate {'inputs': ['tbp', 'tts'], 'output': 'dcd', 'operation': 'OR'}
# Running gate {'inputs': ['bfc', 'kbv'], 'output': 'tts', 'operation': 'AND'}
# Running gate {'inputs': ['wnq', 'vss'], 'output': 'z22', 'operation': 'XOR'}
# Running gate {'inputs': ['bmh', 'spk'], 'output': 'z34', 'operation': 'AND'}
# Running gate {'inputs': ['dpm', 'pqq'], 'output': 'bfc', 'operation': 'OR'}
# Running gate {'inputs': ['hjp', 'mhm'], 'output': 'jqs', 'operation': 'AND'}
# Running gate {'inputs': ['srq', 'sdr'], 'output': 'z41', 'operation': 'XOR'}
# Running gate {'inputs': ['jhb', 'fgv'], 'output': 'hsp', 'operation': 'OR'}
# Running gate {'inputs': ['gqt', 'gnv'], 'output': 'rvb', 'operation': 'OR'}
# Running gate {'inputs': ['gtg', 'hvg'], 'output': 'wvn', 'operation': 'AND'}
# Running gate {'inputs': ['svv', 'cjg'], 'output': 'mmr', 'operation': 'OR'}
# Running gate {'inputs': ['pfk', 'cmd'], 'output': 'z35', 'operation': 'XOR'}
# Running gate {'inputs': ['krm', 'vdc'], 'output': 'z04', 'operation': 'XOR'}
# Running gate {'inputs': ['kkt', 'cbq'], 'output': 'z44', 'operation': 'XOR'}
# Running gate {'inputs': ['vqk', 'kgh'], 'output': 'pmt', 'operation': 'OR'}
# Running gate {'inputs': ['kbj', 'nsd'], 'output': 'hdc', 'operation': 'AND'}
# Running gate {'inputs': ['mkh', 'tvs'], 'output': 'cmn', 'operation': 'AND'}
# Running gate {'inputs': ['fmn', 'kqh'], 'output': 'z30', 'operation': 'XOR'}
# Running gate {'inputs': ['ppw', 'jqs'], 'output': 'wjt', 'operation': 'OR'}
# Running gate {'inputs': ['wtr', 'rwr'], 'output': 'tcv', 'operation': 'OR'}
# Running gate {'inputs': ['jpp', 'tpv'], 'output': 'z06', 'operation': 'XOR'}
# Running gate {'inputs': ['nhs', 'qvh'], 'output': 'vjd', 'operation': 'AND'}
# Running gate {'inputs': ['bjm', 'vkt'], 'output': 'z19', 'operation': 'XOR'}
# Running gate {'inputs': ['rtw', 'wpq'], 'output': 'nbh', 'operation': 'AND'}
# Running gate {'inputs': ['cwn', 'pmt'], 'output': 'fgg', 'operation': 'AND'}
# Running gate {'inputs': ['vnh', 'mtq'], 'output': 'z37', 'operation': 'XOR'}
# Running gate {'inputs': ['nmk', 'dsr'], 'output': 'z01', 'operation': 'XOR'}
# Evaluating...
# Running gate {'inputs': ['dds', 'btb'], 'output': 'ddr', 'operation': 'OR'}
# Running gate {'inputs': ['dnw', 'dtt'], 'output': 'sdt', 'operation': 'OR'}
# Running gate {'inputs': ['dtk', 'ddn'], 'output': 'mkh', 'operation': 'OR'}
# Running gate {'inputs': ['pht', 'dgj'], 'output': 'jmc', 'operation': 'OR'}
# Running gate {'inputs': ['kgr', 'fvp'], 'output': 'nnf', 'operation': 'XOR'}
# Running gate {'inputs': ['pjt', 'ppp'], 'output': 'z24', 'operation': 'XOR'}
# Running gate {'inputs': ['skd', 'ssq'], 'output': 'z02', 'operation': 'XOR'}
# Running gate {'inputs': ['rvb', 'cpg'], 'output': 'wtv', 'operation': 'AND'}
# Running gate {'inputs': ['nbq', 'qjf'], 'output': 'kbj', 'operation': 'OR'}
# Running gate {'inputs': ['kqh', 'fmn'], 'output': 'dtk', 'operation': 'AND'}
# Running gate {'inputs': ['spk', 'bmh'], 'output': 'wrc', 'operation': 'XOR'}
# Running gate {'inputs': ['ddr', 'wkn'], 'output': 'jsv', 'operation': 'AND'}
# Running gate {'inputs': ['gqh', 'tcv'], 'output': 'nhs', 'operation': 'XOR'}
# Running gate {'inputs': ['hqh', 'qrt'], 'output': 'skd', 'operation': 'OR'}
# Evaluating...
# Running gate {'inputs': ['rbk', 'mdv'], 'output': 'spk', 'operation': 'OR'}
# Running gate {'inputs': ['bss', 'fch'], 'output': 'hkt', 'operation': 'AND'}
# Running gate {'inputs': ['jtf', 'jdk'], 'output': 'ktj', 'operation': 'OR'}
# Running gate {'inputs': ['bwc', 'fqk'], 'output': 'fvd', 'operation': 'AND'}
# Running gate {'inputs': ['cbq', 'kkt'], 'output': 'cdh', 'operation': 'AND'}
# Running gate {'inputs': ['hdc', 'bfw'], 'output': 'vnn', 'operation': 'OR'}
# Running gate {'inputs': ['rvb', 'cpg'], 'output': 'z26', 'operation': 'XOR'}
# Running gate {'inputs': ['qds', 'fcg'], 'output': 'vdc', 'operation': 'OR'}
# Running gate {'inputs': ['wqc', 'pvm'], 'output': 'kgr', 'operation': 'OR'}
# Running gate {'inputs': ['jsv', 'qsd'], 'output': 'hjp', 'operation': 'OR'}
# Running gate {'inputs': ['cdh', 'rqv'], 'output': 'z45', 'operation': 'OR'}
# Running gate {'inputs': ['tjq', 'gwt'], 'output': 'jsj', 'operation': 'OR'}
# Running gate {'inputs': ['msm', 'gcn'], 'output': 'fch', 'operation': 'OR'}
# Running gate {'inputs': ['sdh', 'nsg'], 'output': 'z12', 'operation': 'XOR'}
# Running gate {'inputs': ['cwr', 'fnk'], 'output': 'dtt', 'operation': 'AND'}
# Running gate {'inputs': ['wjt', 'ftt'], 'output': 'z18', 'operation': 'XOR'}
# Running gate {'inputs': ['nsg', 'sdh'], 'output': 'nbq', 'operation': 'AND'}
# Running gate {'inputs': ['nhs', 'qvh'], 'output': 'z21', 'operation': 'XOR'}
# Running gate {'inputs': ['htr', 'kdm'], 'output': 'vkt', 'operation': 'OR'}
# Running gate {'inputs': ['dvb', 'wtv'], 'output': 'cdm', 'operation': 'OR'}
# Running gate {'inputs': ['cnp', 'ddh'], 'output': 'pjt', 'operation': 'OR'}
# Running gate {'inputs': ['fvp', 'kgr'], 'output': 'vbr', 'operation': 'AND'}
# Running gate {'inputs': ['fvd', 'rpm'], 'output': 'srq', 'operation': 'OR'}
# Running gate {'inputs': ['vrk', 'hmt'], 'output': 'tpv', 'operation': 'OR'}
# Running gate {'inputs': ['jmc', 'qkk'], 'output': 'z29', 'operation': 'XOR'}
# Running gate {'inputs': ['qkk', 'jmc'], 'output': 'hnj', 'operation': 'AND'}
# Running gate {'inputs': ['wjt', 'ftt'], 'output': 'htr', 'operation': 'AND'}
# Running gate {'inputs': ['nqg', 'hbn'], 'output': 'wqc', 'operation': 'AND'}
# Running gate {'inputs': ['hkt', 'sms'], 'output': 'fqk', 'operation': 'OR'}
# Running gate {'inputs': ['cfd', 'cqd'], 'output': 'z28', 'operation': 'XOR'}
# Running gate {'inputs': ['jpp', 'tpv'], 'output': 'vqk', 'operation': 'AND'}
# Running gate {'inputs': ['tvs', 'mkh'], 'output': 'z31', 'operation': 'XOR'}
# Running gate {'inputs': ['cqw', 'wtc'], 'output': 'dnp', 'operation': 'OR'}
# Running gate {'inputs': ['hsp', 'qnp'], 'output': 'dds', 'operation': 'AND'}
# Running gate {'inputs': ['hvg', 'gtg'], 'output': 'z10', 'operation': 'XOR'}
# Running gate {'inputs': ['hpm', 'nhq'], 'output': 'kkt', 'operation': 'OR'}
# Running gate {'inputs': ['cwn', 'pmt'], 'output': 'z07', 'operation': 'XOR'}
# Running gate {'inputs': ['cnv', 'jsj'], 'output': 'ddh', 'operation': 'AND'}
# Running gate {'inputs': ['srq', 'sdr'], 'output': 'dpm', 'operation': 'AND'}
# Running gate {'inputs': ['ktj', 'dmh'], 'output': 'z38', 'operation': 'XOR'}
# Running gate {'inputs': ['tcv', 'gqh'], 'output': 'cdk', 'operation': 'AND'}
# Running gate {'inputs': ['ptt', 'bvn'], 'output': 'nnw', 'operation': 'OR'}
# Running gate {'inputs': ['vnn', 'qjh'], 'output': 'z14', 'operation': 'XOR'}
# Running gate {'inputs': ['nqg', 'hbn'], 'output': 'z08', 'operation': 'XOR'}
# Running gate {'inputs': ['ppp', 'pjt'], 'output': 'ptt', 'operation': 'AND'}
# Running gate {'inputs': ['ngc', 'sdt'], 'output': 'rbk', 'operation': 'AND'}
# Running gate {'inputs': ['hsp', 'qnp'], 'output': 'z15', 'operation': 'XOR'}
# Running gate {'inputs': ['ssq', 'skd'], 'output': 'nqw', 'operation': 'AND'}
# Evaluating...
# Running gate {'inputs': ['cmd', 'pfk'], 'output': 'cqw', 'operation': 'AND'}
# Running gate {'inputs': ['scb', 'dnp'], 'output': 'z36', 'operation': 'XOR'}
# Running gate {'inputs': ['mmr', 'cgr'], 'output': 'vrk', 'operation': 'AND'}
# Running gate {'inputs': ['cdk', 'rmn'], 'output': 'z20', 'operation': 'OR'}
# Running gate {'inputs': ['nnf', 'vbr'], 'output': 'hvg', 'operation': 'OR'}
# Running gate {'inputs': ['nnw', 'qnd'], 'output': 'z25', 'operation': 'XOR'}
# Running gate {'inputs': ['jmp', 'nqw'], 'output': 'vnw', 'operation': 'OR'}
# Evaluating...
# Running gate {'inputs': ['bjm', 'vkt'], 'output': 'wtr', 'operation': 'AND'}
# Running gate {'inputs': ['kbj', 'nsd'], 'output': 'z13', 'operation': 'XOR'}
# Running gate {'inputs': ['nss', 'vjd'], 'output': 'vss', 'operation': 'OR'}
# Running gate {'inputs': ['hjp', 'mhm'], 'output': 'z17', 'operation': 'XOR'}
# Running gate {'inputs': ['fnk', 'cwr'], 'output': 'z32', 'operation': 'XOR'}
# Running gate {'inputs': ['jsj', 'cnv'], 'output': 'z23', 'operation': 'XOR'}
# Running gate {'inputs': ['rtw', 'wpq'], 'output': 'z11', 'operation': 'XOR'}
# Running gate {'inputs': ['vng', 'vnw'], 'output': 'z03', 'operation': 'XOR'}
# Evaluating...
# Running gate {'inputs': ['vnn', 'qjh'], 'output': 'fgv', 'operation': 'AND'}
# Running gate {'inputs': ['kwf', 'nbh'], 'output': 'sdh', 'operation': 'OR'}
# Running gate {'inputs': ['kbv', 'bfc'], 'output': 'z42', 'operation': 'XOR'}
# Running gate {'inputs': ['hnj', 'ddt'], 'output': 'fmn', 'operation': 'OR'}
# Running gate {'inputs': ['wjf', 'dcd'], 'output': 'hpm', 'operation': 'AND'}
# Running gate {'inputs': ['ddr', 'wkn'], 'output': 'z16', 'operation': 'XOR'}
# Running gate {'inputs': ['krm', 'vdc'], 'output': 'svv', 'operation': 'AND'}
# Running gate {'inputs': ['wjf', 'dcd'], 'output': 'z43', 'operation': 'XOR'}
# Running gate {'inputs': ['qnd', 'nnw'], 'output': 'gnv', 'operation': 'AND'}
# Running gate {'inputs': ['nhh', 'cdm'], 'output': 'vmf', 'operation': 'AND'}
# Running gate {'inputs': ['tcb', 'fgg'], 'output': 'nqg', 'operation': 'OR'}
# Running gate {'inputs': ['sdt', 'ngc'], 'output': 'z33', 'operation': 'XOR'}
# Running gate {'inputs': ['vmf', 'snj'], 'output': 'cfd', 'operation': 'OR'}
# Running gate {'inputs': ['bwc', 'fqk'], 'output': 'z40', 'operation': 'XOR'}
# Running gate {'inputs': ['ktj', 'dmh'], 'output': 'msm', 'operation': 'AND'}
# Running gate {'inputs': ['nhh', 'cdm'], 'output': 'z27', 'operation': 'XOR'}
# Running gate {'inputs': ['vng', 'vnw'], 'output': 'fcg', 'operation': 'AND'}
# Evaluating...
# Running gate {'inputs': ['wrc', 'tgb'], 'output': 'pfk', 'operation': 'OR'}
# Running gate {'inputs': ['mds', 'cmn'], 'output': 'fnk', 'operation': 'OR'}
# Running gate {'inputs': ['mmr', 'cgr'], 'output': 'z05', 'operation': 'XOR'}
# Running gate {'inputs': ['pjj', 'wvn'], 'output': 'wpq', 'operation': 'OR'}
# Running gate {'inputs': ['mtq', 'vnh'], 'output': 'jtf', 'operation': 'AND'}
# Running gate {'inputs': ['hsc', 'dpq'], 'output': 'mtq', 'operation': 'OR'}
# Running gate {'inputs': ['scb', 'dnp'], 'output': 'dpq', 'operation': 'AND'}
# Running gate {'inputs': ['bss', 'fch'], 'output': 'z39', 'operation': 'XOR'}
# Running gate {'inputs': ['vss', 'wnq'], 'output': 'tjq', 'operation': 'AND'}
# Running gate {'inputs': ['cfd', 'cqd'], 'output': 'pht', 'operation': 'AND'}
# Running gate {'inputs': ['tbp', 'tts'], 'output': 'dcd', 'operation': 'OR'}
# Running gate {'inputs': ['bfc', 'kbv'], 'output': 'tts', 'operation': 'AND'}
# Running gate {'inputs': ['wnq', 'vss'], 'output': 'z22', 'operation': 'XOR'}
# Running gate {'inputs': ['bmh', 'spk'], 'output': 'z34', 'operation': 'AND'}
# Running gate {'inputs': ['dpm', 'pqq'], 'output': 'bfc', 'operation': 'OR'}
# Running gate {'inputs': ['hjp', 'mhm'], 'output': 'jqs', 'operation': 'AND'}
# Running gate {'inputs': ['srq', 'sdr'], 'output': 'z41', 'operation': 'XOR'}
# Running gate {'inputs': ['jhb', 'fgv'], 'output': 'hsp', 'operation': 'OR'}
# Running gate {'inputs': ['gqt', 'gnv'], 'output': 'rvb', 'operation': 'OR'}
# Running gate {'inputs': ['gtg', 'hvg'], 'output': 'wvn', 'operation': 'AND'}
# Running gate {'inputs': ['svv', 'cjg'], 'output': 'mmr', 'operation': 'OR'}
# Running gate {'inputs': ['pfk', 'cmd'], 'output': 'z35', 'operation': 'XOR'}
# Running gate {'inputs': ['krm', 'vdc'], 'output': 'z04', 'operation': 'XOR'}
# Running gate {'inputs': ['kkt', 'cbq'], 'output': 'z44', 'operation': 'XOR'}
# Running gate {'inputs': ['vqk', 'kgh'], 'output': 'pmt', 'operation': 'OR'}
# Running gate {'inputs': ['kbj', 'nsd'], 'output': 'hdc', 'operation': 'AND'}
# Running gate {'inputs': ['mkh', 'tvs'], 'output': 'cmn', 'operation': 'AND'}
# Running gate {'inputs': ['fmn', 'kqh'], 'output': 'z30', 'operation': 'XOR'}
# Running gate {'inputs': ['ppw', 'jqs'], 'output': 'wjt', 'operation': 'OR'}
# Running gate {'inputs': ['wtr', 'rwr'], 'output': 'tcv', 'operation': 'OR'}
# Running gate {'inputs': ['jpp', 'tpv'], 'output': 'z06', 'operation': 'XOR'}
# Running gate {'inputs': ['nhs', 'qvh'], 'output': 'vjd', 'operation': 'AND'}
# Running gate {'inputs': ['bjm', 'vkt'], 'output': 'z19', 'operation': 'XOR'}
# Running gate {'inputs': ['rtw', 'wpq'], 'output': 'nbh', 'operation': 'AND'}
# Running gate {'inputs': ['cwn', 'pmt'], 'output': 'fgg', 'operation': 'AND'}
# Running gate {'inputs': ['vnh', 'mtq'], 'output': 'z37', 'operation': 'XOR'}
# Running gate {'inputs': ['dds', 'btb'], 'output': 'ddr', 'operation': 'OR'}
# Running gate {'inputs': ['dnw', 'dtt'], 'output': 'sdt', 'operation': 'OR'}
# Running gate {'inputs': ['dtk', 'ddn'], 'output': 'mkh', 'operation': 'OR'}
# Running gate {'inputs': ['pht', 'dgj'], 'output': 'jmc', 'operation': 'OR'}
# Running gate {'inputs': ['kgr', 'fvp'], 'output': 'nnf', 'operation': 'XOR'}
# Running gate {'inputs': ['pjt', 'ppp'], 'output': 'z24', 'operation': 'XOR'}
# Running gate {'inputs': ['skd', 'ssq'], 'output': 'z02', 'operation': 'XOR'}
# Evaluating...
# Running gate {'inputs': ['rvb', 'cpg'], 'output': 'wtv', 'operation': 'AND'}
# Running gate {'inputs': ['nbq', 'qjf'], 'output': 'kbj', 'operation': 'OR'}
# Running gate {'inputs': ['kqh', 'fmn'], 'output': 'dtk', 'operation': 'AND'}
# Running gate {'inputs': ['spk', 'bmh'], 'output': 'wrc', 'operation': 'XOR'}
# Running gate {'inputs': ['ddr', 'wkn'], 'output': 'jsv', 'operation': 'AND'}
# Running gate {'inputs': ['gqh', 'tcv'], 'output': 'nhs', 'operation': 'XOR'}
# Running gate {'inputs': ['rbk', 'mdv'], 'output': 'spk', 'operation': 'OR'}
# Running gate {'inputs': ['bss', 'fch'], 'output': 'hkt', 'operation': 'AND'}
# Running gate {'inputs': ['jtf', 'jdk'], 'output': 'ktj', 'operation': 'OR'}
# Running gate {'inputs': ['bwc', 'fqk'], 'output': 'fvd', 'operation': 'AND'}
# Running gate {'inputs': ['cbq', 'kkt'], 'output': 'cdh', 'operation': 'AND'}
# Running gate {'inputs': ['hdc', 'bfw'], 'output': 'vnn', 'operation': 'OR'}
# Running gate {'inputs': ['rvb', 'cpg'], 'output': 'z26', 'operation': 'XOR'}
# Running gate {'inputs': ['qds', 'fcg'], 'output': 'vdc', 'operation': 'OR'}
# Evaluating...
# Running gate {'inputs': ['wqc', 'pvm'], 'output': 'kgr', 'operation': 'OR'}
# Running gate {'inputs': ['jsv', 'qsd'], 'output': 'hjp', 'operation': 'OR'}
# Running gate {'inputs': ['cdh', 'rqv'], 'output': 'z45', 'operation': 'OR'}
# Running gate {'inputs': ['tjq', 'gwt'], 'output': 'jsj', 'operation': 'OR'}
# Running gate {'inputs': ['msm', 'gcn'], 'output': 'fch', 'operation': 'OR'}
# Running gate {'inputs': ['sdh', 'nsg'], 'output': 'z12', 'operation': 'XOR'}
# Running gate {'inputs': ['cwr', 'fnk'], 'output': 'dtt', 'operation': 'AND'}
# Running gate {'inputs': ['wjt', 'ftt'], 'output': 'z18', 'operation': 'XOR'}
# Running gate {'inputs': ['nsg', 'sdh'], 'output': 'nbq', 'operation': 'AND'}
# Running gate {'inputs': ['nhs', 'qvh'], 'output': 'z21', 'operation': 'XOR'}
# Running gate {'inputs': ['htr', 'kdm'], 'output': 'vkt', 'operation': 'OR'}
# Running gate {'inputs': ['dvb', 'wtv'], 'output': 'cdm', 'operation': 'OR'}
# Running gate {'inputs': ['cnp', 'ddh'], 'output': 'pjt', 'operation': 'OR'}
# Running gate {'inputs': ['fvp', 'kgr'], 'output': 'vbr', 'operation': 'AND'}
# Running gate {'inputs': ['fvd', 'rpm'], 'output': 'srq', 'operation': 'OR'}
# Running gate {'inputs': ['vrk', 'hmt'], 'output': 'tpv', 'operation': 'OR'}
# Running gate {'inputs': ['jmc', 'qkk'], 'output': 'z29', 'operation': 'XOR'}
# Running gate {'inputs': ['qkk', 'jmc'], 'output': 'hnj', 'operation': 'AND'}
# Running gate {'inputs': ['wjt', 'ftt'], 'output': 'htr', 'operation': 'AND'}
# Running gate {'inputs': ['nqg', 'hbn'], 'output': 'wqc', 'operation': 'AND'}
# Running gate {'inputs': ['hkt', 'sms'], 'output': 'fqk', 'operation': 'OR'}
# Running gate {'inputs': ['cfd', 'cqd'], 'output': 'z28', 'operation': 'XOR'}
# Running gate {'inputs': ['jpp', 'tpv'], 'output': 'vqk', 'operation': 'AND'}
# Running gate {'inputs': ['tvs', 'mkh'], 'output': 'z31', 'operation': 'XOR'}
# Running gate {'inputs': ['cqw', 'wtc'], 'output': 'dnp', 'operation': 'OR'}
# Running gate {'inputs': ['hsp', 'qnp'], 'output': 'dds', 'operation': 'AND'}
# Running gate {'inputs': ['hvg', 'gtg'], 'output': 'z10', 'operation': 'XOR'}
# Running gate {'inputs': ['hpm', 'nhq'], 'output': 'kkt', 'operation': 'OR'}
# Running gate {'inputs': ['cwn', 'pmt'], 'output': 'z07', 'operation': 'XOR'}
# Running gate {'inputs': ['cnv', 'jsj'], 'output': 'ddh', 'operation': 'AND'}
# Running gate {'inputs': ['srq', 'sdr'], 'output': 'dpm', 'operation': 'AND'}
# Running gate {'inputs': ['ktj', 'dmh'], 'output': 'z38', 'operation': 'XOR'}
# Running gate {'inputs': ['tcv', 'gqh'], 'output': 'cdk', 'operation': 'AND'}
# Running gate {'inputs': ['ptt', 'bvn'], 'output': 'nnw', 'operation': 'OR'}
# Running gate {'inputs': ['vnn', 'qjh'], 'output': 'z14', 'operation': 'XOR'}
# Running gate {'inputs': ['nqg', 'hbn'], 'output': 'z08', 'operation': 'XOR'}
# Running gate {'inputs': ['ppp', 'pjt'], 'output': 'ptt', 'operation': 'AND'}
# Running gate {'inputs': ['ngc', 'sdt'], 'output': 'rbk', 'operation': 'AND'}
# Running gate {'inputs': ['hsp', 'qnp'], 'output': 'z15', 'operation': 'XOR'}
# Running gate {'inputs': ['cmd', 'pfk'], 'output': 'cqw', 'operation': 'AND'}
# Running gate {'inputs': ['scb', 'dnp'], 'output': 'z36', 'operation': 'XOR'}
# Running gate {'inputs': ['mmr', 'cgr'], 'output': 'vrk', 'operation': 'AND'}
# Running gate {'inputs': ['cdk', 'rmn'], 'output': 'z20', 'operation': 'OR'}
# Running gate {'inputs': ['nnf', 'vbr'], 'output': 'hvg', 'operation': 'OR'}
# Running gate {'inputs': ['nnw', 'qnd'], 'output': 'z25', 'operation': 'XOR'}
# Running gate {'inputs': ['bjm', 'vkt'], 'output': 'wtr', 'operation': 'AND'}
# Running gate {'inputs': ['kbj', 'nsd'], 'output': 'z13', 'operation': 'XOR'}
# Running gate {'inputs': ['nss', 'vjd'], 'output': 'vss', 'operation': 'OR'}
# Running gate {'inputs': ['hjp', 'mhm'], 'output': 'z17', 'operation': 'XOR'}
# Running gate {'inputs': ['fnk', 'cwr'], 'output': 'z32', 'operation': 'XOR'}
# Running gate {'inputs': ['jsj', 'cnv'], 'output': 'z23', 'operation': 'XOR'}
# Running gate {'inputs': ['rtw', 'wpq'], 'output': 'z11', 'operation': 'XOR'}
# Running gate {'inputs': ['vnn', 'qjh'], 'output': 'fgv', 'operation': 'AND'}
# Running gate {'inputs': ['kwf', 'nbh'], 'output': 'sdh', 'operation': 'OR'}
# Running gate {'inputs': ['kbv', 'bfc'], 'output': 'z42', 'operation': 'XOR'}
# Running gate {'inputs': ['hnj', 'ddt'], 'output': 'fmn', 'operation': 'OR'}
# Running gate {'inputs': ['wjf', 'dcd'], 'output': 'hpm', 'operation': 'AND'}
# Running gate {'inputs': ['ddr', 'wkn'], 'output': 'z16', 'operation': 'XOR'}
# Running gate {'inputs': ['krm', 'vdc'], 'output': 'svv', 'operation': 'AND'}
# Evaluating...
# Running gate {'inputs': ['wjf', 'dcd'], 'output': 'z43', 'operation': 'XOR'}
# Running gate {'inputs': ['qnd', 'nnw'], 'output': 'gnv', 'operation': 'AND'}
# Running gate {'inputs': ['nhh', 'cdm'], 'output': 'vmf', 'operation': 'AND'}
# Running gate {'inputs': ['tcb', 'fgg'], 'output': 'nqg', 'operation': 'OR'}
# Running gate {'inputs': ['sdt', 'ngc'], 'output': 'z33', 'operation': 'XOR'}
# Running gate {'inputs': ['vmf', 'snj'], 'output': 'cfd', 'operation': 'OR'}
# Running gate {'inputs': ['bwc', 'fqk'], 'output': 'z40', 'operation': 'XOR'}
# Running gate {'inputs': ['ktj', 'dmh'], 'output': 'msm', 'operation': 'AND'}
# Running gate {'inputs': ['nhh', 'cdm'], 'output': 'z27', 'operation': 'XOR'}
# Running gate {'inputs': ['wrc', 'tgb'], 'output': 'pfk', 'operation': 'OR'}
# Running gate {'inputs': ['mds', 'cmn'], 'output': 'fnk', 'operation': 'OR'}
# Running gate {'inputs': ['mmr', 'cgr'], 'output': 'z05', 'operation': 'XOR'}
# Running gate {'inputs': ['pjj', 'wvn'], 'output': 'wpq', 'operation': 'OR'}
# Running gate {'inputs': ['mtq', 'vnh'], 'output': 'jtf', 'operation': 'AND'}
# Running gate {'inputs': ['hsc', 'dpq'], 'output': 'mtq', 'operation': 'OR'}
# Running gate {'inputs': ['scb', 'dnp'], 'output': 'dpq', 'operation': 'AND'}
# Running gate {'inputs': ['bss', 'fch'], 'output': 'z39', 'operation': 'XOR'}
# Running gate {'inputs': ['vss', 'wnq'], 'output': 'tjq', 'operation': 'AND'}
# Running gate {'inputs': ['cfd', 'cqd'], 'output': 'pht', 'operation': 'AND'}
# Running gate {'inputs': ['tbp', 'tts'], 'output': 'dcd', 'operation': 'OR'}
# Running gate {'inputs': ['bfc', 'kbv'], 'output': 'tts', 'operation': 'AND'}
# Running gate {'inputs': ['wnq', 'vss'], 'output': 'z22', 'operation': 'XOR'}
# Running gate {'inputs': ['bmh', 'spk'], 'output': 'z34', 'operation': 'AND'}
# Running gate {'inputs': ['dpm', 'pqq'], 'output': 'bfc', 'operation': 'OR'}
# Running gate {'inputs': ['hjp', 'mhm'], 'output': 'jqs', 'operation': 'AND'}
# Running gate {'inputs': ['srq', 'sdr'], 'output': 'z41', 'operation': 'XOR'}
# Running gate {'inputs': ['jhb', 'fgv'], 'output': 'hsp', 'operation': 'OR'}
# Running gate {'inputs': ['gqt', 'gnv'], 'output': 'rvb', 'operation': 'OR'}
# Running gate {'inputs': ['gtg', 'hvg'], 'output': 'wvn', 'operation': 'AND'}
# Running gate {'inputs': ['svv', 'cjg'], 'output': 'mmr', 'operation': 'OR'}
# Evaluating...
# Running gate {'inputs': ['pfk', 'cmd'], 'output': 'z35', 'operation': 'XOR'}
# Running gate {'inputs': ['krm', 'vdc'], 'output': 'z04', 'operation': 'XOR'}
# Evaluating...
# Running gate {'inputs': ['kkt', 'cbq'], 'output': 'z44', 'operation': 'XOR'}
# Running gate {'inputs': ['vqk', 'kgh'], 'output': 'pmt', 'operation': 'OR'}
# Running gate {'inputs': ['kbj', 'nsd'], 'output': 'hdc', 'operation': 'AND'}
# Running gate {'inputs': ['mkh', 'tvs'], 'output': 'cmn', 'operation': 'AND'}
# Running gate {'inputs': ['fmn', 'kqh'], 'output': 'z30', 'operation': 'XOR'}
# Running gate {'inputs': ['ppw', 'jqs'], 'output': 'wjt', 'operation': 'OR'}
# Running gate {'inputs': ['wtr', 'rwr'], 'output': 'tcv', 'operation': 'OR'}
# Running gate {'inputs': ['jpp', 'tpv'], 'output': 'z06', 'operation': 'XOR'}
# Running gate {'inputs': ['nhs', 'qvh'], 'output': 'vjd', 'operation': 'AND'}
# Running gate {'inputs': ['bjm', 'vkt'], 'output': 'z19', 'operation': 'XOR'}
# Running gate {'inputs': ['rtw', 'wpq'], 'output': 'nbh', 'operation': 'AND'}
# Running gate {'inputs': ['cwn', 'pmt'], 'output': 'fgg', 'operation': 'AND'}
# Running gate {'inputs': ['vnh', 'mtq'], 'output': 'z37', 'operation': 'XOR'}
# Running gate {'inputs': ['dds', 'btb'], 'output': 'ddr', 'operation': 'OR'}
# Running gate {'inputs': ['dnw', 'dtt'], 'output': 'sdt', 'operation': 'OR'}
# Running gate {'inputs': ['dtk', 'ddn'], 'output': 'mkh', 'operation': 'OR'}
# Running gate {'inputs': ['pht', 'dgj'], 'output': 'jmc', 'operation': 'OR'}
# Running gate {'inputs': ['kgr', 'fvp'], 'output': 'nnf', 'operation': 'XOR'}
# Running gate {'inputs': ['pjt', 'ppp'], 'output': 'z24', 'operation': 'XOR'}
# Running gate {'inputs': ['rvb', 'cpg'], 'output': 'wtv', 'operation': 'AND'}
# Running gate {'inputs': ['nbq', 'qjf'], 'output': 'kbj', 'operation': 'OR'}
# Running gate {'inputs': ['kqh', 'fmn'], 'output': 'dtk', 'operation': 'AND'}
# Running gate {'inputs': ['spk', 'bmh'], 'output': 'wrc', 'operation': 'XOR'}
# Running gate {'inputs': ['ddr', 'wkn'], 'output': 'jsv', 'operation': 'AND'}
# Running gate {'inputs': ['gqh', 'tcv'], 'output': 'nhs', 'operation': 'XOR'}
# Running gate {'inputs': ['rbk', 'mdv'], 'output': 'spk', 'operation': 'OR'}
# Running gate {'inputs': ['bss', 'fch'], 'output': 'hkt', 'operation': 'AND'}
# Running gate {'inputs': ['jtf', 'jdk'], 'output': 'ktj', 'operation': 'OR'}
# Running gate {'inputs': ['bwc', 'fqk'], 'output': 'fvd', 'operation': 'AND'}
# Running gate {'inputs': ['cbq', 'kkt'], 'output': 'cdh', 'operation': 'AND'}
# Running gate {'inputs': ['hdc', 'bfw'], 'output': 'vnn', 'operation': 'OR'}
# Running gate {'inputs': ['rvb', 'cpg'], 'output': 'z26', 'operation': 'XOR'}
# Running gate {'inputs': ['wqc', 'pvm'], 'output': 'kgr', 'operation': 'OR'}
# Running gate {'inputs': ['jsv', 'qsd'], 'output': 'hjp', 'operation': 'OR'}
# Running gate {'inputs': ['cdh', 'rqv'], 'output': 'z45', 'operation': 'OR'}
# Running gate {'inputs': ['tjq', 'gwt'], 'output': 'jsj', 'operation': 'OR'}
# Running gate {'inputs': ['msm', 'gcn'], 'output': 'fch', 'operation': 'OR'}
# Running gate {'inputs': ['sdh', 'nsg'], 'output': 'z12', 'operation': 'XOR'}
# Running gate {'inputs': ['cwr', 'fnk'], 'output': 'dtt', 'operation': 'AND'}
# Running gate {'inputs': ['wjt', 'ftt'], 'output': 'z18', 'operation': 'XOR'}
# Running gate {'inputs': ['nsg', 'sdh'], 'output': 'nbq', 'operation': 'AND'}
# ...
# Running gate {'inputs': ['cbq', 'kkt'], 'output': 'cdh', 'operation': 'AND'}
# Running gate {'inputs': ['cdh', 'rqv'], 'output': 'z45', 'operation': 'OR'}
# Running gate {'inputs': ['msm', 'gcn'], 'output': 'fch', 'operation': 'OR'}
# Running gate {'inputs': ['fvd', 'rpm'], 'output': 'srq', 'operation': 'OR'}
# Running gate {'inputs': ['hkt', 'sms'], 'output': 'fqk', 'operation': 'OR'}
# Running gate {'inputs': ['cqw', 'wtc'], 'output': 'dnp', 'operation': 'OR'}
# Running gate {'inputs': ['hpm', 'nhq'], 'output': 'kkt', 'operation': 'OR'}
# Running gate {'inputs': ['srq', 'sdr'], 'output': 'dpm', 'operation': 'AND'}
# Running gate {'inputs': ['ktj', 'dmh'], 'output': 'z38', 'operation': 'XOR'}
# Running gate {'inputs': ['cmd', 'pfk'], 'output': 'cqw', 'operation': 'AND'}
# Evaluating...
# Running gate {'inputs': ['scb', 'dnp'], 'output': 'z36', 'operation': 'XOR'}
# Running gate {'inputs': ['kbv', 'bfc'], 'output': 'z42', 'operation': 'XOR'}
# Running gate {'inputs': ['wjf', 'dcd'], 'output': 'hpm', 'operation': 'AND'}
# Running gate {'inputs': ['wjf', 'dcd'], 'output': 'z43', 'operation': 'XOR'}
# Running gate {'inputs': ['bwc', 'fqk'], 'output': 'z40', 'operation': 'XOR'}
# Running gate {'inputs': ['ktj', 'dmh'], 'output': 'msm', 'operation': 'AND'}
# Running gate {'inputs': ['mtq', 'vnh'], 'output': 'jtf', 'operation': 'AND'}
# Running gate {'inputs': ['hsc', 'dpq'], 'output': 'mtq', 'operation': 'OR'}
# Running gate {'inputs': ['scb', 'dnp'], 'output': 'dpq', 'operation': 'AND'}
# Running gate {'inputs': ['bss', 'fch'], 'output': 'z39', 'operation': 'XOR'}
# Running gate {'inputs': ['tbp', 'tts'], 'output': 'dcd', 'operation': 'OR'}
# Running gate {'inputs': ['bfc', 'kbv'], 'output': 'tts', 'operation': 'AND'}
# Running gate {'inputs': ['dpm', 'pqq'], 'output': 'bfc', 'operation': 'OR'}
# Running gate {'inputs': ['srq', 'sdr'], 'output': 'z41', 'operation': 'XOR'}
# Running gate {'inputs': ['kkt', 'cbq'], 'output': 'z44', 'operation': 'XOR'}
# Running gate {'inputs': ['vnh', 'mtq'], 'output': 'z37', 'operation': 'XOR'}
# Running gate {'inputs': ['bss', 'fch'], 'output': 'hkt', 'operation': 'AND'}
# Running gate {'inputs': ['jtf', 'jdk'], 'output': 'ktj', 'operation': 'OR'}
# Running gate {'inputs': ['bwc', 'fqk'], 'output': 'fvd', 'operation': 'AND'}
# Running gate {'inputs': ['cbq', 'kkt'], 'output': 'cdh', 'operation': 'AND'}
# Running gate {'inputs': ['cdh', 'rqv'], 'output': 'z45', 'operation': 'OR'}
# Running gate {'inputs': ['msm', 'gcn'], 'output': 'fch', 'operation': 'OR'}
# Running gate {'inputs': ['fvd', 'rpm'], 'output': 'srq', 'operation': 'OR'}
# Running gate {'inputs': ['hkt', 'sms'], 'output': 'fqk', 'operation': 'OR'}
# Running gate {'inputs': ['cqw', 'wtc'], 'output': 'dnp', 'operation': 'OR'}
# Evaluating...
# Running gate {'inputs': ['hpm', 'nhq'], 'output': 'kkt', 'operation': 'OR'}
# Running gate {'inputs': ['srq', 'sdr'], 'output': 'dpm', 'operation': 'AND'}
# Running gate {'inputs': ['ktj', 'dmh'], 'output': 'z38', 'operation': 'XOR'}
# Running gate {'inputs': ['scb', 'dnp'], 'output': 'z36', 'operation': 'XOR'}
# Evaluating...
# Running gate {'inputs': ['kbv', 'bfc'], 'output': 'z42', 'operation': 'XOR'}
# Running gate {'inputs': ['wjf', 'dcd'], 'output': 'hpm', 'operation': 'AND'}
# Running gate {'inputs': ['wjf', 'dcd'], 'output': 'z43', 'operation': 'XOR'}
# Running gate {'inputs': ['bwc', 'fqk'], 'output': 'z40', 'operation': 'XOR'}
# Running gate {'inputs': ['ktj', 'dmh'], 'output': 'msm', 'operation': 'AND'}
# Running gate {'inputs': ['mtq', 'vnh'], 'output': 'jtf', 'operation': 'AND'}
# Running gate {'inputs': ['hsc', 'dpq'], 'output': 'mtq', 'operation': 'OR'}
# Running gate {'inputs': ['scb', 'dnp'], 'output': 'dpq', 'operation': 'AND'}
# Evaluating...
# Running gate {'inputs': ['bss', 'fch'], 'output': 'z39', 'operation': 'XOR'}
# Running gate {'inputs': ['tbp', 'tts'], 'output': 'dcd', 'operation': 'OR'}
# Running gate {'inputs': ['bfc', 'kbv'], 'output': 'tts', 'operation': 'AND'}
# Running gate {'inputs': ['dpm', 'pqq'], 'output': 'bfc', 'operation': 'OR'}
# Running gate {'inputs': ['srq', 'sdr'], 'output': 'z41', 'operation': 'XOR'}
# Running gate {'inputs': ['kkt', 'cbq'], 'output': 'z44', 'operation': 'XOR'}
# Running gate {'inputs': ['vnh', 'mtq'], 'output': 'z37', 'operation': 'XOR'}
# Running gate {'inputs': ['bss', 'fch'], 'output': 'hkt', 'operation': 'AND'}
# Running gate {'inputs': ['jtf', 'jdk'], 'output': 'ktj', 'operation': 'OR'}
# Running gate {'inputs': ['bwc', 'fqk'], 'output': 'fvd', 'operation': 'AND'}
# Running gate {'inputs': ['cbq', 'kkt'], 'output': 'cdh', 'operation': 'AND'}
# Running gate {'inputs': ['cdh', 'rqv'], 'output': 'z45', 'operation': 'OR'}
# Running gate {'inputs': ['msm', 'gcn'], 'output': 'fch', 'operation': 'OR'}
# Running gate {'inputs': ['fvd', 'rpm'], 'output': 'srq', 'operation': 'OR'}
# Running gate {'inputs': ['hkt', 'sms'], 'output': 'fqk', 'operation': 'OR'}
# Running gate {'inputs': ['hpm', 'nhq'], 'output': 'kkt', 'operation': 'OR'}
# Running gate {'inputs': ['srq', 'sdr'], 'output': 'dpm', 'operation': 'AND'}
# Running gate {'inputs': ['ktj', 'dmh'], 'output': 'z38', 'operation': 'XOR'}
# Running gate {'inputs': ['kbv', 'bfc'], 'output': 'z42', 'operation': 'XOR'}
# Running gate {'inputs': ['wjf', 'dcd'], 'output': 'hpm', 'operation': 'AND'}
# Running gate {'inputs': ['wjf', 'dcd'], 'output': 'z43', 'operation': 'XOR'}
# Running gate {'inputs': ['bwc', 'fqk'], 'output': 'z40', 'operation': 'XOR'}
# Running gate {'inputs': ['ktj', 'dmh'], 'output': 'msm', 'operation': 'AND'}
# Running gate {'inputs': ['mtq', 'vnh'], 'output': 'jtf', 'operation': 'AND'}
# Running gate {'inputs': ['hsc', 'dpq'], 'output': 'mtq', 'operation': 'OR'}
# Evaluating...
# Running gate {'inputs': ['bss', 'fch'], 'output': 'z39', 'operation': 'XOR'}
# Running gate {'inputs': ['tbp', 'tts'], 'output': 'dcd', 'operation': 'OR'}
# Running gate {'inputs': ['bfc', 'kbv'], 'output': 'tts', 'operation': 'AND'}
# Running gate {'inputs': ['dpm', 'pqq'], 'output': 'bfc', 'operation': 'OR'}
# Running gate {'inputs': ['srq', 'sdr'], 'output': 'z41', 'operation': 'XOR'}
# Running gate {'inputs': ['kkt', 'cbq'], 'output': 'z44', 'operation': 'XOR'}
# Running gate {'inputs': ['vnh', 'mtq'], 'output': 'z37', 'operation': 'XOR'}
# Evaluating...
# Running gate {'inputs': ['bss', 'fch'], 'output': 'hkt', 'operation': 'AND'}
# Running gate {'inputs': ['jtf', 'jdk'], 'output': 'ktj', 'operation': 'OR'}
# Running gate {'inputs': ['bwc', 'fqk'], 'output': 'fvd', 'operation': 'AND'}
# Running gate {'inputs': ['cbq', 'kkt'], 'output': 'cdh', 'operation': 'AND'}
# Running gate {'inputs': ['cdh', 'rqv'], 'output': 'z45', 'operation': 'OR'}
# Running gate {'inputs': ['msm', 'gcn'], 'output': 'fch', 'operation': 'OR'}
# Running gate {'inputs': ['fvd', 'rpm'], 'output': 'srq', 'operation': 'OR'}
# Running gate {'inputs': ['hkt', 'sms'], 'output': 'fqk', 'operation': 'OR'}
# Running gate {'inputs': ['hpm', 'nhq'], 'output': 'kkt', 'operation': 'OR'}
# Running gate {'inputs': ['srq', 'sdr'], 'output': 'dpm', 'operation': 'AND'}
# Running gate {'inputs': ['ktj', 'dmh'], 'output': 'z38', 'operation': 'XOR'}
# Running gate {'inputs': ['kbv', 'bfc'], 'output': 'z42', 'operation': 'XOR'}
# Running gate {'inputs': ['wjf', 'dcd'], 'output': 'hpm', 'operation': 'AND'}
# Running gate {'inputs': ['wjf', 'dcd'], 'output': 'z43', 'operation': 'XOR'}
# Running gate {'inputs': ['bwc', 'fqk'], 'output': 'z40', 'operation': 'XOR'}
# Running gate {'inputs': ['ktj', 'dmh'], 'output': 'msm', 'operation': 'AND'}
# Running gate {'inputs': ['mtq', 'vnh'], 'output': 'jtf', 'operation': 'AND'}
# Evaluating...
# Running gate {'inputs': ['bss', 'fch'], 'output': 'z39', 'operation': 'XOR'}
# Running gate {'inputs': ['tbp', 'tts'], 'output': 'dcd', 'operation': 'OR'}
# Running gate {'inputs': ['bfc', 'kbv'], 'output': 'tts', 'operation': 'AND'}
# Running gate {'inputs': ['dpm', 'pqq'], 'output': 'bfc', 'operation': 'OR'}
# Running gate {'inputs': ['srq', 'sdr'], 'output': 'z41', 'operation': 'XOR'}
# Running gate {'inputs': ['kkt', 'cbq'], 'output': 'z44', 'operation': 'XOR'}
# Running gate {'inputs': ['bss', 'fch'], 'output': 'hkt', 'operation': 'AND'}
# Running gate {'inputs': ['jtf', 'jdk'], 'output': 'ktj', 'operation': 'OR'}
# Evaluating...
# Running gate {'inputs': ['bwc', 'fqk'], 'output': 'fvd', 'operation': 'AND'}
# Running gate {'inputs': ['cbq', 'kkt'], 'output': 'cdh', 'operation': 'AND'}
# Running gate {'inputs': ['cdh', 'rqv'], 'output': 'z45', 'operation': 'OR'}
# Running gate {'inputs': ['msm', 'gcn'], 'output': 'fch', 'operation': 'OR'}
# Running gate {'inputs': ['fvd', 'rpm'], 'output': 'srq', 'operation': 'OR'}
# Running gate {'inputs': ['hkt', 'sms'], 'output': 'fqk', 'operation': 'OR'}
# Running gate {'inputs': ['hpm', 'nhq'], 'output': 'kkt', 'operation': 'OR'}
# Running gate {'inputs': ['srq', 'sdr'], 'output': 'dpm', 'operation': 'AND'}
# Running gate {'inputs': ['ktj', 'dmh'], 'output': 'z38', 'operation': 'XOR'}
# Evaluating...
# Running gate {'inputs': ['kbv', 'bfc'], 'output': 'z42', 'operation': 'XOR'}
# Running gate {'inputs': ['wjf', 'dcd'], 'output': 'hpm', 'operation': 'AND'}
# Running gate {'inputs': ['wjf', 'dcd'], 'output': 'z43', 'operation': 'XOR'}
# Running gate {'inputs': ['bwc', 'fqk'], 'output': 'z40', 'operation': 'XOR'}
# Running gate {'inputs': ['ktj', 'dmh'], 'output': 'msm', 'operation': 'AND'}
# Evaluating...
# Running gate {'inputs': ['bss', 'fch'], 'output': 'z39', 'operation': 'XOR'}
# Running gate {'inputs': ['tbp', 'tts'], 'output': 'dcd', 'operation': 'OR'}
# Running gate {'inputs': ['bfc', 'kbv'], 'output': 'tts', 'operation': 'AND'}
# Running gate {'inputs': ['dpm', 'pqq'], 'output': 'bfc', 'operation': 'OR'}
# Running gate {'inputs': ['srq', 'sdr'], 'output': 'z41', 'operation': 'XOR'}
# Running gate {'inputs': ['kkt', 'cbq'], 'output': 'z44', 'operation': 'XOR'}
# Running gate {'inputs': ['bss', 'fch'], 'output': 'hkt', 'operation': 'AND'}
# Running gate {'inputs': ['bwc', 'fqk'], 'output': 'fvd', 'operation': 'AND'}
# Running gate {'inputs': ['cbq', 'kkt'], 'output': 'cdh', 'operation': 'AND'}
# Running gate {'inputs': ['cdh', 'rqv'], 'output': 'z45', 'operation': 'OR'}
# Running gate {'inputs': ['msm', 'gcn'], 'output': 'fch', 'operation': 'OR'}
# Evaluating...
# Running gate {'inputs': ['fvd', 'rpm'], 'output': 'srq', 'operation': 'OR'}
# Running gate {'inputs': ['hkt', 'sms'], 'output': 'fqk', 'operation': 'OR'}
# Running gate {'inputs': ['hpm', 'nhq'], 'output': 'kkt', 'operation': 'OR'}
# Running gate {'inputs': ['srq', 'sdr'], 'output': 'dpm', 'operation': 'AND'}
# Running gate {'inputs': ['kbv', 'bfc'], 'output': 'z42', 'operation': 'XOR'}
# Running gate {'inputs': ['wjf', 'dcd'], 'output': 'hpm', 'operation': 'AND'}
# Running gate {'inputs': ['wjf', 'dcd'], 'output': 'z43', 'operation': 'XOR'}
# Running gate {'inputs': ['bwc', 'fqk'], 'output': 'z40', 'operation': 'XOR'}
# Running gate {'inputs': ['bss', 'fch'], 'output': 'z39', 'operation': 'XOR'}
# Evaluating...
# Running gate {'inputs': ['tbp', 'tts'], 'output': 'dcd', 'operation': 'OR'}
# Running gate {'inputs': ['bfc', 'kbv'], 'output': 'tts', 'operation': 'AND'}
# Running gate {'inputs': ['dpm', 'pqq'], 'output': 'bfc', 'operation': 'OR'}
# Running gate {'inputs': ['srq', 'sdr'], 'output': 'z41', 'operation': 'XOR'}
# Running gate {'inputs': ['kkt', 'cbq'], 'output': 'z44', 'operation': 'XOR'}
# Running gate {'inputs': ['bss', 'fch'], 'output': 'hkt', 'operation': 'AND'}
# Evaluating...
# Running gate {'inputs': ['bwc', 'fqk'], 'output': 'fvd', 'operation': 'AND'}
# Running gate {'inputs': ['cbq', 'kkt'], 'output': 'cdh', 'operation': 'AND'}
# Running gate {'inputs': ['cdh', 'rqv'], 'output': 'z45', 'operation': 'OR'}
# Running gate {'inputs': ['fvd', 'rpm'], 'output': 'srq', 'operation': 'OR'}
# Running gate {'inputs': ['hkt', 'sms'], 'output': 'fqk', 'operation': 'OR'}
# Evaluating...
# Running gate {'inputs': ['hpm', 'nhq'], 'output': 'kkt', 'operation': 'OR'}
# Running gate {'inputs': ['srq', 'sdr'], 'output': 'dpm', 'operation': 'AND'}
# Running gate {'inputs': ['kbv', 'bfc'], 'output': 'z42', 'operation': 'XOR'}
# Running gate {'inputs': ['wjf', 'dcd'], 'output': 'hpm', 'operation': 'AND'}
# Running gate {'inputs': ['wjf', 'dcd'], 'output': 'z43', 'operation': 'XOR'}
# Running gate {'inputs': ['bwc', 'fqk'], 'output': 'z40', 'operation': 'XOR'}
# Evaluating...
# Running gate {'inputs': ['tbp', 'tts'], 'output': 'dcd', 'operation': 'OR'}
# Running gate {'inputs': ['bfc', 'kbv'], 'output': 'tts', 'operation': 'AND'}
# Running gate {'inputs': ['dpm', 'pqq'], 'output': 'bfc', 'operation': 'OR'}
# Running gate {'inputs': ['srq', 'sdr'], 'output': 'z41', 'operation': 'XOR'}
# Running gate {'inputs': ['kkt', 'cbq'], 'output': 'z44', 'operation': 'XOR'}
# Running gate {'inputs': ['bwc', 'fqk'], 'output': 'fvd', 'operation': 'AND'}
# Evaluating...
# Running gate {'inputs': ['cbq', 'kkt'], 'output': 'cdh', 'operation': 'AND'}
# Running gate {'inputs': ['cdh', 'rqv'], 'output': 'z45', 'operation': 'OR'}
# Running gate {'inputs': ['fvd', 'rpm'], 'output': 'srq', 'operation': 'OR'}
# Evaluating...
# Running gate {'inputs': ['hpm', 'nhq'], 'output': 'kkt', 'operation': 'OR'}
# Running gate {'inputs': ['srq', 'sdr'], 'output': 'dpm', 'operation': 'AND'}
# Evaluating...
# Running gate {'inputs': ['kbv', 'bfc'], 'output': 'z42', 'operation': 'XOR'}
# Running gate {'inputs': ['wjf', 'dcd'], 'output': 'hpm', 'operation': 'AND'}
# Running gate {'inputs': ['wjf', 'dcd'], 'output': 'z43', 'operation': 'XOR'}
# Running gate {'inputs': ['tbp', 'tts'], 'output': 'dcd', 'operation': 'OR'}
# Running gate {'inputs': ['bfc', 'kbv'], 'output': 'tts', 'operation': 'AND'}
# Running gate {'inputs': ['dpm', 'pqq'], 'output': 'bfc', 'operation': 'OR'}
# Evaluating...
# Running gate {'inputs': ['srq', 'sdr'], 'output': 'z41', 'operation': 'XOR'}
# Evaluating...
# Running gate {'inputs': ['kkt', 'cbq'], 'output': 'z44', 'operation': 'XOR'}
# Running gate {'inputs': ['cbq', 'kkt'], 'output': 'cdh', 'operation': 'AND'}
# Running gate {'inputs': ['cdh', 'rqv'], 'output': 'z45', 'operation': 'OR'}
# Running gate {'inputs': ['hpm', 'nhq'], 'output': 'kkt', 'operation': 'OR'}
# Running gate {'inputs': ['kbv', 'bfc'], 'output': 'z42', 'operation': 'XOR'}
# Evaluating...
# Running gate {'inputs': ['wjf', 'dcd'], 'output': 'hpm', 'operation': 'AND'}
# Running gate {'inputs': ['wjf', 'dcd'], 'output': 'z43', 'operation': 'XOR'}
# Running gate {'inputs': ['tbp', 'tts'], 'output': 'dcd', 'operation': 'OR'}
# Running gate {'inputs': ['bfc', 'kbv'], 'output': 'tts', 'operation': 'AND'}
# Evaluating...
# Running gate {'inputs': ['kkt', 'cbq'], 'output': 'z44', 'operation': 'XOR'}
# Running gate {'inputs': ['cbq', 'kkt'], 'output': 'cdh', 'operation': 'AND'}
# Running gate {'inputs': ['cdh', 'rqv'], 'output': 'z45', 'operation': 'OR'}
# Running gate {'inputs': ['hpm', 'nhq'], 'output': 'kkt', 'operation': 'OR'}
# Running gate {'inputs': ['wjf', 'dcd'], 'output': 'hpm', 'operation': 'AND'}
# Running gate {'inputs': ['wjf', 'dcd'], 'output': 'z43', 'operation': 'XOR'}
# Running gate {'inputs': ['tbp', 'tts'], 'output': 'dcd', 'operation': 'OR'}
# Evaluating...
# Running gate {'inputs': ['kkt', 'cbq'], 'output': 'z44', 'operation': 'XOR'}
# Running gate {'inputs': ['cbq', 'kkt'], 'output': 'cdh', 'operation': 'AND'}
# Running gate {'inputs': ['cdh', 'rqv'], 'output': 'z45', 'operation': 'OR'}
# Running gate {'inputs': ['hpm', 'nhq'], 'output': 'kkt', 'operation': 'OR'}
# Running gate {'inputs': ['wjf', 'dcd'], 'output': 'hpm', 'operation': 'AND'}
# Evaluating...
# Running gate {'inputs': ['wjf', 'dcd'], 'output': 'z43', 'operation': 'XOR'}
# Evaluating...
# Running gate {'inputs': ['kkt', 'cbq'], 'output': 'z44', 'operation': 'XOR'}
# Running gate {'inputs': ['cbq', 'kkt'], 'output': 'cdh', 'operation': 'AND'}
# Running gate {'inputs': ['cdh', 'rqv'], 'output': 'z45', 'operation': 'OR'}
# Running gate {'inputs': ['hpm', 'nhq'], 'output': 'kkt', 'operation': 'OR'}
# Evaluating...
# Running gate {'inputs': ['kkt', 'cbq'], 'output': 'z44', 'operation': 'XOR'}
# Evaluating...
# Running gate {'inputs': ['cbq', 'kkt'], 'output': 'cdh', 'operation': 'AND'}
# Evaluating...
# Running gate {'inputs': ['cdh', 'rqv'], 'output': 'z45', 'operation': 'OR'}
# Evaluating...
# Solution: 1011000110001110101000000001010011111011101000
# Number: 48806532300520

# %%
wires
# Out:
# {'x00': 1,
#  'x01': 0,
#  'x02': 1,
#  'x03': 1,
#  'x04': 0,
#  'y00': 1,
#  'y01': 1,
#  'y02': 1,
#  'y03': 1,
#  'y04': 1,
#  'mjb': 1,
#  'tnw': 1,
#  'z05': None,
#  'fst': 1,
#  'z01': None,
#  'bfw': None,
#  'z10': None,
#  'bqk': 1,
#  'djm': 1,
#  'psh': 1,
#  'z08': None,
#  'frj': None,
#  'z11': None,
#  'z00': None,
#  'vdt': 1,
#  'z02': None,
#  'kjc': 0,
#  'qhw': None,
#  'hwm': None,
#  'rvg': None,
#  'fgs': 1,
#  'pbm': 1,
#  'kwq': None,
#  'tgd': None,
#  'z09': None,
#  'kpj': None,
#  'ffh': 0,
#  'ntg': 0,
#  'z06': None,
#  'wpb': None,
#  'z04': None,
#  'z07': None,
#  'nrd': 1,
#  'z03': None,
#  'z12': None,
#  'gnj': None}

# %%
wires
# Out:
# {'x00': '1',
#  'x01': '1',
#  'x02': '1',
#  'y00': '0',
#  'y01': '1',
#  'y02': '0',
#  'z00': None,
#  'z01': None,
#  'z02': 1}

# %% [markdown]
# # PART 2

# %%
for key in wires:
    wires[key] = None

xvalue = pow(2,45)-1
yvalue = pow(2,45)-1
print(xvalue + yvalue)
print(str(bin(xvalue+yvalue)))

x_bin_value = bin(xvalue)
y_bin_value = bin(yvalue)

x_keys = [key for key in (sorted(wires.keys())) if key[0] == 'x']
y_keys = [key for key in (sorted(wires.keys())) if key[0] == 'y']

for x_key in x_keys:
    wires[x_key] = xvalue % 2
    xvalue = floor(xvalue / 2)

for y_key in y_keys:
    wires[y_key] = yvalue % 2
    yvalue = floor(yvalue / 2)
# Out:
# 70368744177662
# 0b1111111111111111111111111111111111111111111110

# %%
gate_dict = {}
for logic_gate in logic_gates:
    gate_dict[logic_gate['output']] = {'inputs': logic_gate['inputs'], 'operation': logic_gate['operation']}

gate_dict

def define_output_recursively(gate_dict, output, remove_outer_layers = 0):
    gate = gate_dict[output]
    input1 = gate['inputs'][0]
    input2 = gate['inputs'][1]
    if input1 in gate_dict.keys():
        input1 = define_output_recursively(gate_dict, input1)
    if input2 in gate_dict.keys():
        input2 = define_output_recursively(gate_dict, input2)
    output = f"({input1} {gate['operation']} {input2})"

    for outer_layer in range(remove_outer_layers):
        try:
            output = output.rsplit(')',1)[0].split('(',1)[1]
        except:
            output = ''
            break

    return output

def swap_gates(gate_dict, gate1, gate2):
    swapped_gate_dict = gate_dict.copy()
    gate = swapped_gate_dict[gate1]
    swapped_gate_dict[gate1] = swapped_gate_dict[gate2]
    swapped_gate_dict[gate2] = gate
    return swapped_gate_dict

# %%
output_list = [out_val for out_val in reversed(sorted(wires)) if out_val[0] == 'z']
for output in output_list:
    print(f"{output} is defined as: {define_output_recursively(gate_dict, output, 3)}")
# Out:
# z45 is defined as: x44 XOR y44) AND (((y43 XOR x43) AND ((x42 AND y42) OR ((((((x40 XOR y40) AND (((y39 XOR x39) AND ((((((y36 AND x36) OR ((y36 XOR x36) AND (((y35 XOR x35) AND (((((x33 XOR y33) AND ((y32 AND x32) OR ((y32 XOR x32) AND ((y31 AND x31) OR ((((x30 AND y30) AND (((x29 XOR y29) AND (((((x27 XOR y27) AND ((x26 AND y26) OR (((x25 AND y25) OR ((y25 XOR x25) AND (((y24 XOR x24) AND ((x23 AND y23) OR ((x23 XOR y23) AND ((((y21 AND x21) OR (((x20 XOR y20) XOR (((y19 XOR x19) AND ((((x17 AND y17) OR (((((((y14 AND x14) OR ((((((y12 XOR x12) AND ((y11 AND x11) OR ((y11 XOR x11) AND ((y10 AND x10) OR ((y10 XOR x10) AND ((((((y07 AND x07) OR ((y07 XOR x07) AND (((y06 XOR x06) AND (((((x04 XOR y04) AND ((x03 AND y03) OR ((x03 XOR y03) AND ((y02 AND x02) OR ((x02 XOR y02) AND ((x01 AND y01) OR ((x01 XOR y01) AND (x00 AND y00)))))))) OR (x04 AND y04)) AND (y05 XOR x05)) OR (y05 AND x05))) OR (y06 AND x06)))) AND (y08 XOR x08)) OR (y08 AND x08)) XOR (y09 XOR x09)) OR ((y09 XOR x09) AND ((((y07 AND x07) OR ((y07 XOR x07) AND (((y06 XOR x06) AND (((((x04 XOR y04) AND ((x03 AND y03) OR ((x03 XOR y03) AND ((y02 AND x02) OR ((x02 XOR y02) AND ((x01 AND y01) OR ((x01 XOR y01) AND (x00 AND y00)))))))) OR (x04 AND y04)) AND (y05 XOR x05)) OR (y05 AND x05))) OR (y06 AND x06)))) AND (y08 XOR x08)) OR (y08 AND x08))))))))) OR (y12 AND x12)) AND (x13 XOR y13)) OR (y13 AND x13)) AND (x14 XOR y14))) AND (x15 XOR y15)) OR (x15 AND y15)) AND (x16 XOR y16)) OR (y16 AND x16)) AND (x17 XOR y17))) AND (y18 XOR x18)) OR (y18 AND x18))) OR (x19 AND y19))) AND (y21 XOR x21))) AND (y22 XOR x22)) OR (x22 AND y22))))) OR (y24 AND x24)))) AND (y26 XOR x26)))) OR (y27 AND x27)) AND (y28 XOR x28)) OR (x28 AND y28))) OR (x29 AND y29))) OR (y30 XOR x30)) AND (y31 XOR x31)))))) OR (y33 AND x33)) XOR (x34 XOR y34)) OR (x34 AND y34))) OR (y35 AND x35)))) AND (y37 XOR x37)) OR (x37 AND y37)) AND (y38 XOR x38)) OR (y38 AND x38))) OR (y39 AND x39))) OR (y40 AND x40)) AND (y41 XOR x41)) OR (y41 AND x41)) AND (x42 XOR y42)))) OR (y43 AND x43))
# z44 is defined as: (y43 XOR x43) AND ((x42 AND y42) OR ((((((x40 XOR y40) AND (((y39 XOR x39) AND ((((((y36 AND x36) OR ((y36 XOR x36) AND (((y35 XOR x35) AND (((((x33 XOR y33) AND ((y32 AND x32) OR ((y32 XOR x32) AND ((y31 AND x31) OR ((((x30 AND y30) AND (((x29 XOR y29) AND (((((x27 XOR y27) AND ((x26 AND y26) OR (((x25 AND y25) OR ((y25 XOR x25) AND (((y24 XOR x24) AND ((x23 AND y23) OR ((x23 XOR y23) AND ((((y21 AND x21) OR (((x20 XOR y20) XOR (((y19 XOR x19) AND ((((x17 AND y17) OR (((((((y14 AND x14) OR ((((((y12 XOR x12) AND ((y11 AND x11) OR ((y11 XOR x11) AND ((y10 AND x10) OR ((y10 XOR x10) AND ((((((y07 AND x07) OR ((y07 XOR x07) AND (((y06 XOR x06) AND (((((x04 XOR y04) AND ((x03 AND y03) OR ((x03 XOR y03) AND ((y02 AND x02) OR ((x02 XOR y02) AND ((x01 AND y01) OR ((x01 XOR y01) AND (x00 AND y00)))))))) OR (x04 AND y04)) AND (y05 XOR x05)) OR (y05 AND x05))) OR (y06 AND x06)))) AND (y08 XOR x08)) OR (y08 AND x08)) XOR (y09 XOR x09)) OR ((y09 XOR x09) AND ((((y07 AND x07) OR ((y07 XOR x07) AND (((y06 XOR x06) AND (((((x04 XOR y04) AND ((x03 AND y03) OR ((x03 XOR y03) AND ((y02 AND x02) OR ((x02 XOR y02) AND ((x01 AND y01) OR ((x01 XOR y01) AND (x00 AND y00)))))))) OR (x04 AND y04)) AND (y05 XOR x05)) OR (y05 AND x05))) OR (y06 AND x06)))) AND (y08 XOR x08)) OR (y08 AND x08))))))))) OR (y12 AND x12)) AND (x13 XOR y13)) OR (y13 AND x13)) AND (x14 XOR y14))) AND (x15 XOR y15)) OR (x15 AND y15)) AND (x16 XOR y16)) OR (y16 AND x16)) AND (x17 XOR y17))) AND (y18 XOR x18)) OR (y18 AND x18))) OR (x19 AND y19))) AND (y21 XOR x21))) AND (y22 XOR x22)) OR (x22 AND y22))))) OR (y24 AND x24)))) AND (y26 XOR x26)))) OR (y27 AND x27)) AND (y28 XOR x28)) OR (x28 AND y28))) OR (x29 AND y29))) OR (y30 XOR x30)) AND (y31 XOR x31)))))) OR (y33 AND x33)) XOR (x34 XOR y34)) OR (x34 AND y34))) OR (y35 AND x35)))) AND (y37 XOR x37)) OR (x37 AND y37)) AND (y38 XOR x38)) OR (y38 AND x38))) OR (y39 AND x39))) OR (y40 AND x40)) AND (y41 XOR x41)) OR (y41 AND x41)) AND (x42 XOR y42)))) OR (y43 AND x43)
# z43 is defined as: (x42 AND y42) OR ((((((x40 XOR y40) AND (((y39 XOR x39) AND ((((((y36 AND x36) OR ((y36 XOR x36) AND (((y35 XOR x35) AND (((((x33 XOR y33) AND ((y32 AND x32) OR ((y32 XOR x32) AND ((y31 AND x31) OR ((((x30 AND y30) AND (((x29 XOR y29) AND (((((x27 XOR y27) AND ((x26 AND y26) OR (((x25 AND y25) OR ((y25 XOR x25) AND (((y24 XOR x24) AND ((x23 AND y23) OR ((x23 XOR y23) AND ((((y21 AND x21) OR (((x20 XOR y20) XOR (((y19 XOR x19) AND ((((x17 AND y17) OR (((((((y14 AND x14) OR ((((((y12 XOR x12) AND ((y11 AND x11) OR ((y11 XOR x11) AND ((y10 AND x10) OR ((y10 XOR x10) AND ((((((y07 AND x07) OR ((y07 XOR x07) AND (((y06 XOR x06) AND (((((x04 XOR y04) AND ((x03 AND y03) OR ((x03 XOR y03) AND ((y02 AND x02) OR ((x02 XOR y02) AND ((x01 AND y01) OR ((x01 XOR y01) AND (x00 AND y00)))))))) OR (x04 AND y04)) AND (y05 XOR x05)) OR (y05 AND x05))) OR (y06 AND x06)))) AND (y08 XOR x08)) OR (y08 AND x08)) XOR (y09 XOR x09)) OR ((y09 XOR x09) AND ((((y07 AND x07) OR ((y07 XOR x07) AND (((y06 XOR x06) AND (((((x04 XOR y04) AND ((x03 AND y03) OR ((x03 XOR y03) AND ((y02 AND x02) OR ((x02 XOR y02) AND ((x01 AND y01) OR ((x01 XOR y01) AND (x00 AND y00)))))))) OR (x04 AND y04)) AND (y05 XOR x05)) OR (y05 AND x05))) OR (y06 AND x06)))) AND (y08 XOR x08)) OR (y08 AND x08))))))))) OR (y12 AND x12)) AND (x13 XOR y13)) OR (y13 AND x13)) AND (x14 XOR y14))) AND (x15 XOR y15)) OR (x15 AND y15)) AND (x16 XOR y16)) OR (y16 AND x16)) AND (x17 XOR y17))) AND (y18 XOR x18)) OR (y18 AND x18))) OR (x19 AND y19))) AND (y21 XOR x21))) AND (y22 XOR x22)) OR (x22 AND y22))))) OR (y24 AND x24)))) AND (y26 XOR x26)))) OR (y27 AND x27)) AND (y28 XOR x28)) OR (x28 AND y28))) OR (x29 AND y29))) OR (y30 XOR x30)) AND (y31 XOR x31)))))) OR (y33 AND x33)) XOR (x34 XOR y34)) OR (x34 AND y34))) OR (y35 AND x35)))) AND (y37 XOR x37)) OR (x37 AND y37)) AND (y38 XOR x38)) OR (y38 AND x38))) OR (y39 AND x39))) OR (y40 AND x40)) AND (y41 XOR x41)) OR (y41 AND x41)) AND (x42 XOR y42)
# z42 is defined as: ((((x40 XOR y40) AND (((y39 XOR x39) AND ((((((y36 AND x36) OR ((y36 XOR x36) AND (((y35 XOR x35) AND (((((x33 XOR y33) AND ((y32 AND x32) OR ((y32 XOR x32) AND ((y31 AND x31) OR ((((x30 AND y30) AND (((x29 XOR y29) AND (((((x27 XOR y27) AND ((x26 AND y26) OR (((x25 AND y25) OR ((y25 XOR x25) AND (((y24 XOR x24) AND ((x23 AND y23) OR ((x23 XOR y23) AND ((((y21 AND x21) OR (((x20 XOR y20) XOR (((y19 XOR x19) AND ((((x17 AND y17) OR (((((((y14 AND x14) OR ((((((y12 XOR x12) AND ((y11 AND x11) OR ((y11 XOR x11) AND ((y10 AND x10) OR ((y10 XOR x10) AND ((((((y07 AND x07) OR ((y07 XOR x07) AND (((y06 XOR x06) AND (((((x04 XOR y04) AND ((x03 AND y03) OR ((x03 XOR y03) AND ((y02 AND x02) OR ((x02 XOR y02) AND ((x01 AND y01) OR ((x01 XOR y01) AND (x00 AND y00)))))))) OR (x04 AND y04)) AND (y05 XOR x05)) OR (y05 AND x05))) OR (y06 AND x06)))) AND (y08 XOR x08)) OR (y08 AND x08)) XOR (y09 XOR x09)) OR ((y09 XOR x09) AND ((((y07 AND x07) OR ((y07 XOR x07) AND (((y06 XOR x06) AND (((((x04 XOR y04) AND ((x03 AND y03) OR ((x03 XOR y03) AND ((y02 AND x02) OR ((x02 XOR y02) AND ((x01 AND y01) OR ((x01 XOR y01) AND (x00 AND y00)))))))) OR (x04 AND y04)) AND (y05 XOR x05)) OR (y05 AND x05))) OR (y06 AND x06)))) AND (y08 XOR x08)) OR (y08 AND x08))))))))) OR (y12 AND x12)) AND (x13 XOR y13)) OR (y13 AND x13)) AND (x14 XOR y14))) AND (x15 XOR y15)) OR (x15 AND y15)) AND (x16 XOR y16)) OR (y16 AND x16)) AND (x17 XOR y17))) AND (y18 XOR x18)) OR (y18 AND x18))) OR (x19 AND y19))) AND (y21 XOR x21))) AND (y22 XOR x22)) OR (x22 AND y22))))) OR (y24 AND x24)))) AND (y26 XOR x26)))) OR (y27 AND x27)) AND (y28 XOR x28)) OR (x28 AND y28))) OR (x29 AND y29))) OR (y30 XOR x30)) AND (y31 XOR x31)))))) OR (y33 AND x33)) XOR (x34 XOR y34)) OR (x34 AND y34))) OR (y35 AND x35)))) AND (y37 XOR x37)) OR (x37 AND y37)) AND (y38 XOR x38)) OR (y38 AND x38))) OR (y39 AND x39))) OR (y40 AND x40)) AND (y41 XOR x41)) OR (y41 AND x41
# z41 is defined as: (x40 XOR y40) AND (((y39 XOR x39) AND ((((((y36 AND x36) OR ((y36 XOR x36) AND (((y35 XOR x35) AND (((((x33 XOR y33) AND ((y32 AND x32) OR ((y32 XOR x32) AND ((y31 AND x31) OR ((((x30 AND y30) AND (((x29 XOR y29) AND (((((x27 XOR y27) AND ((x26 AND y26) OR (((x25 AND y25) OR ((y25 XOR x25) AND (((y24 XOR x24) AND ((x23 AND y23) OR ((x23 XOR y23) AND ((((y21 AND x21) OR (((x20 XOR y20) XOR (((y19 XOR x19) AND ((((x17 AND y17) OR (((((((y14 AND x14) OR ((((((y12 XOR x12) AND ((y11 AND x11) OR ((y11 XOR x11) AND ((y10 AND x10) OR ((y10 XOR x10) AND ((((((y07 AND x07) OR ((y07 XOR x07) AND (((y06 XOR x06) AND (((((x04 XOR y04) AND ((x03 AND y03) OR ((x03 XOR y03) AND ((y02 AND x02) OR ((x02 XOR y02) AND ((x01 AND y01) OR ((x01 XOR y01) AND (x00 AND y00)))))))) OR (x04 AND y04)) AND (y05 XOR x05)) OR (y05 AND x05))) OR (y06 AND x06)))) AND (y08 XOR x08)) OR (y08 AND x08)) XOR (y09 XOR x09)) OR ((y09 XOR x09) AND ((((y07 AND x07) OR ((y07 XOR x07) AND (((y06 XOR x06) AND (((((x04 XOR y04) AND ((x03 AND y03) OR ((x03 XOR y03) AND ((y02 AND x02) OR ((x02 XOR y02) AND ((x01 AND y01) OR ((x01 XOR y01) AND (x00 AND y00)))))))) OR (x04 AND y04)) AND (y05 XOR x05)) OR (y05 AND x05))) OR (y06 AND x06)))) AND (y08 XOR x08)) OR (y08 AND x08))))))))) OR (y12 AND x12)) AND (x13 XOR y13)) OR (y13 AND x13)) AND (x14 XOR y14))) AND (x15 XOR y15)) OR (x15 AND y15)) AND (x16 XOR y16)) OR (y16 AND x16)) AND (x17 XOR y17))) AND (y18 XOR x18)) OR (y18 AND x18))) OR (x19 AND y19))) AND (y21 XOR x21))) AND (y22 XOR x22)) OR (x22 AND y22))))) OR (y24 AND x24)))) AND (y26 XOR x26)))) OR (y27 AND x27)) AND (y28 XOR x28)) OR (x28 AND y28))) OR (x29 AND y29))) OR (y30 XOR x30)) AND (y31 XOR x31)))))) OR (y33 AND x33)) XOR (x34 XOR y34)) OR (x34 AND y34))) OR (y35 AND x35)))) AND (y37 XOR x37)) OR (x37 AND y37)) AND (y38 XOR x38)) OR (y38 AND x38))) OR (y39 AND x39))) OR (y40 AND x40)
# z40 is defined as: ((y39 XOR x39) AND ((((((y36 AND x36) OR ((y36 XOR x36) AND (((y35 XOR x35) AND (((((x33 XOR y33) AND ((y32 AND x32) OR ((y32 XOR x32) AND ((y31 AND x31) OR ((((x30 AND y30) AND (((x29 XOR y29) AND (((((x27 XOR y27) AND ((x26 AND y26) OR (((x25 AND y25) OR ((y25 XOR x25) AND (((y24 XOR x24) AND ((x23 AND y23) OR ((x23 XOR y23) AND ((((y21 AND x21) OR (((x20 XOR y20) XOR (((y19 XOR x19) AND ((((x17 AND y17) OR (((((((y14 AND x14) OR ((((((y12 XOR x12) AND ((y11 AND x11) OR ((y11 XOR x11) AND ((y10 AND x10) OR ((y10 XOR x10) AND ((((((y07 AND x07) OR ((y07 XOR x07) AND (((y06 XOR x06) AND (((((x04 XOR y04) AND ((x03 AND y03) OR ((x03 XOR y03) AND ((y02 AND x02) OR ((x02 XOR y02) AND ((x01 AND y01) OR ((x01 XOR y01) AND (x00 AND y00)))))))) OR (x04 AND y04)) AND (y05 XOR x05)) OR (y05 AND x05))) OR (y06 AND x06)))) AND (y08 XOR x08)) OR (y08 AND x08)) XOR (y09 XOR x09)) OR ((y09 XOR x09) AND ((((y07 AND x07) OR ((y07 XOR x07) AND (((y06 XOR x06) AND (((((x04 XOR y04) AND ((x03 AND y03) OR ((x03 XOR y03) AND ((y02 AND x02) OR ((x02 XOR y02) AND ((x01 AND y01) OR ((x01 XOR y01) AND (x00 AND y00)))))))) OR (x04 AND y04)) AND (y05 XOR x05)) OR (y05 AND x05))) OR (y06 AND x06)))) AND (y08 XOR x08)) OR (y08 AND x08))))))))) OR (y12 AND x12)) AND (x13 XOR y13)) OR (y13 AND x13)) AND (x14 XOR y14))) AND (x15 XOR y15)) OR (x15 AND y15)) AND (x16 XOR y16)) OR (y16 AND x16)) AND (x17 XOR y17))) AND (y18 XOR x18)) OR (y18 AND x18))) OR (x19 AND y19))) AND (y21 XOR x21))) AND (y22 XOR x22)) OR (x22 AND y22))))) OR (y24 AND x24)))) AND (y26 XOR x26)))) OR (y27 AND x27)) AND (y28 XOR x28)) OR (x28 AND y28))) OR (x29 AND y29))) OR (y30 XOR x30)) AND (y31 XOR x31)))))) OR (y33 AND x33)) XOR (x34 XOR y34)) OR (x34 AND y34))) OR (y35 AND x35)))) AND (y37 XOR x37)) OR (x37 AND y37)) AND (y38 XOR x38)) OR (y38 AND x38))) OR (y39 AND x39
# z39 is defined as: (((((y36 AND x36) OR ((y36 XOR x36) AND (((y35 XOR x35) AND (((((x33 XOR y33) AND ((y32 AND x32) OR ((y32 XOR x32) AND ((y31 AND x31) OR ((((x30 AND y30) AND (((x29 XOR y29) AND (((((x27 XOR y27) AND ((x26 AND y26) OR (((x25 AND y25) OR ((y25 XOR x25) AND (((y24 XOR x24) AND ((x23 AND y23) OR ((x23 XOR y23) AND ((((y21 AND x21) OR (((x20 XOR y20) XOR (((y19 XOR x19) AND ((((x17 AND y17) OR (((((((y14 AND x14) OR ((((((y12 XOR x12) AND ((y11 AND x11) OR ((y11 XOR x11) AND ((y10 AND x10) OR ((y10 XOR x10) AND ((((((y07 AND x07) OR ((y07 XOR x07) AND (((y06 XOR x06) AND (((((x04 XOR y04) AND ((x03 AND y03) OR ((x03 XOR y03) AND ((y02 AND x02) OR ((x02 XOR y02) AND ((x01 AND y01) OR ((x01 XOR y01) AND (x00 AND y00)))))))) OR (x04 AND y04)) AND (y05 XOR x05)) OR (y05 AND x05))) OR (y06 AND x06)))) AND (y08 XOR x08)) OR (y08 AND x08)) XOR (y09 XOR x09)) OR ((y09 XOR x09) AND ((((y07 AND x07) OR ((y07 XOR x07) AND (((y06 XOR x06) AND (((((x04 XOR y04) AND ((x03 AND y03) OR ((x03 XOR y03) AND ((y02 AND x02) OR ((x02 XOR y02) AND ((x01 AND y01) OR ((x01 XOR y01) AND (x00 AND y00)))))))) OR (x04 AND y04)) AND (y05 XOR x05)) OR (y05 AND x05))) OR (y06 AND x06)))) AND (y08 XOR x08)) OR (y08 AND x08))))))))) OR (y12 AND x12)) AND (x13 XOR y13)) OR (y13 AND x13)) AND (x14 XOR y14))) AND (x15 XOR y15)) OR (x15 AND y15)) AND (x16 XOR y16)) OR (y16 AND x16)) AND (x17 XOR y17))) AND (y18 XOR x18)) OR (y18 AND x18))) OR (x19 AND y19))) AND (y21 XOR x21))) AND (y22 XOR x22)) OR (x22 AND y22))))) OR (y24 AND x24)))) AND (y26 XOR x26)))) OR (y27 AND x27)) AND (y28 XOR x28)) OR (x28 AND y28))) OR (x29 AND y29))) OR (y30 XOR x30)) AND (y31 XOR x31)))))) OR (y33 AND x33)) XOR (x34 XOR y34)) OR (x34 AND y34))) OR (y35 AND x35)))) AND (y37 XOR x37)) OR (x37 AND y37)) AND (y38 XOR x38)) OR (y38 AND x38
# z38 is defined as: ((y36 AND x36) OR ((y36 XOR x36) AND (((y35 XOR x35) AND (((((x33 XOR y33) AND ((y32 AND x32) OR ((y32 XOR x32) AND ((y31 AND x31) OR ((((x30 AND y30) AND (((x29 XOR y29) AND (((((x27 XOR y27) AND ((x26 AND y26) OR (((x25 AND y25) OR ((y25 XOR x25) AND (((y24 XOR x24) AND ((x23 AND y23) OR ((x23 XOR y23) AND ((((y21 AND x21) OR (((x20 XOR y20) XOR (((y19 XOR x19) AND ((((x17 AND y17) OR (((((((y14 AND x14) OR ((((((y12 XOR x12) AND ((y11 AND x11) OR ((y11 XOR x11) AND ((y10 AND x10) OR ((y10 XOR x10) AND ((((((y07 AND x07) OR ((y07 XOR x07) AND (((y06 XOR x06) AND (((((x04 XOR y04) AND ((x03 AND y03) OR ((x03 XOR y03) AND ((y02 AND x02) OR ((x02 XOR y02) AND ((x01 AND y01) OR ((x01 XOR y01) AND (x00 AND y00)))))))) OR (x04 AND y04)) AND (y05 XOR x05)) OR (y05 AND x05))) OR (y06 AND x06)))) AND (y08 XOR x08)) OR (y08 AND x08)) XOR (y09 XOR x09)) OR ((y09 XOR x09) AND ((((y07 AND x07) OR ((y07 XOR x07) AND (((y06 XOR x06) AND (((((x04 XOR y04) AND ((x03 AND y03) OR ((x03 XOR y03) AND ((y02 AND x02) OR ((x02 XOR y02) AND ((x01 AND y01) OR ((x01 XOR y01) AND (x00 AND y00)))))))) OR (x04 AND y04)) AND (y05 XOR x05)) OR (y05 AND x05))) OR (y06 AND x06)))) AND (y08 XOR x08)) OR (y08 AND x08))))))))) OR (y12 AND x12)) AND (x13 XOR y13)) OR (y13 AND x13)) AND (x14 XOR y14))) AND (x15 XOR y15)) OR (x15 AND y15)) AND (x16 XOR y16)) OR (y16 AND x16)) AND (x17 XOR y17))) AND (y18 XOR x18)) OR (y18 AND x18))) OR (x19 AND y19))) AND (y21 XOR x21))) AND (y22 XOR x22)) OR (x22 AND y22))))) OR (y24 AND x24)))) AND (y26 XOR x26)))) OR (y27 AND x27)) AND (y28 XOR x28)) OR (x28 AND y28))) OR (x29 AND y29))) OR (y30 XOR x30)) AND (y31 XOR x31)))))) OR (y33 AND x33)) XOR (x34 XOR y34)) OR (x34 AND y34))) OR (y35 AND x35)))) AND (y37 XOR x37)) OR (x37 AND y37)
# z37 is defined as: (y36 AND x36) OR ((y36 XOR x36) AND (((y35 XOR x35) AND (((((x33 XOR y33) AND ((y32 AND x32) OR ((y32 XOR x32) AND ((y31 AND x31) OR ((((x30 AND y30) AND (((x29 XOR y29) AND (((((x27 XOR y27) AND ((x26 AND y26) OR (((x25 AND y25) OR ((y25 XOR x25) AND (((y24 XOR x24) AND ((x23 AND y23) OR ((x23 XOR y23) AND ((((y21 AND x21) OR (((x20 XOR y20) XOR (((y19 XOR x19) AND ((((x17 AND y17) OR (((((((y14 AND x14) OR ((((((y12 XOR x12) AND ((y11 AND x11) OR ((y11 XOR x11) AND ((y10 AND x10) OR ((y10 XOR x10) AND ((((((y07 AND x07) OR ((y07 XOR x07) AND (((y06 XOR x06) AND (((((x04 XOR y04) AND ((x03 AND y03) OR ((x03 XOR y03) AND ((y02 AND x02) OR ((x02 XOR y02) AND ((x01 AND y01) OR ((x01 XOR y01) AND (x00 AND y00)))))))) OR (x04 AND y04)) AND (y05 XOR x05)) OR (y05 AND x05))) OR (y06 AND x06)))) AND (y08 XOR x08)) OR (y08 AND x08)) XOR (y09 XOR x09)) OR ((y09 XOR x09) AND ((((y07 AND x07) OR ((y07 XOR x07) AND (((y06 XOR x06) AND (((((x04 XOR y04) AND ((x03 AND y03) OR ((x03 XOR y03) AND ((y02 AND x02) OR ((x02 XOR y02) AND ((x01 AND y01) OR ((x01 XOR y01) AND (x00 AND y00)))))))) OR (x04 AND y04)) AND (y05 XOR x05)) OR (y05 AND x05))) OR (y06 AND x06)))) AND (y08 XOR x08)) OR (y08 AND x08))))))))) OR (y12 AND x12)) AND (x13 XOR y13)) OR (y13 AND x13)) AND (x14 XOR y14))) AND (x15 XOR y15)) OR (x15 AND y15)) AND (x16 XOR y16)) OR (y16 AND x16)) AND (x17 XOR y17))) AND (y18 XOR x18)) OR (y18 AND x18))) OR (x19 AND y19))) AND (y21 XOR x21))) AND (y22 XOR x22)) OR (x22 AND y22))))) OR (y24 AND x24)))) AND (y26 XOR x26)))) OR (y27 AND x27)) AND (y28 XOR x28)) OR (x28 AND y28))) OR (x29 AND y29))) OR (y30 XOR x30)) AND (y31 XOR x31)))))) OR (y33 AND x33)) XOR (x34 XOR y34)) OR (x34 AND y34))) OR (y35 AND x35))
# z36 is defined as: ((y35 XOR x35) AND (((((x33 XOR y33) AND ((y32 AND x32) OR ((y32 XOR x32) AND ((y31 AND x31) OR ((((x30 AND y30) AND (((x29 XOR y29) AND (((((x27 XOR y27) AND ((x26 AND y26) OR (((x25 AND y25) OR ((y25 XOR x25) AND (((y24 XOR x24) AND ((x23 AND y23) OR ((x23 XOR y23) AND ((((y21 AND x21) OR (((x20 XOR y20) XOR (((y19 XOR x19) AND ((((x17 AND y17) OR (((((((y14 AND x14) OR ((((((y12 XOR x12) AND ((y11 AND x11) OR ((y11 XOR x11) AND ((y10 AND x10) OR ((y10 XOR x10) AND ((((((y07 AND x07) OR ((y07 XOR x07) AND (((y06 XOR x06) AND (((((x04 XOR y04) AND ((x03 AND y03) OR ((x03 XOR y03) AND ((y02 AND x02) OR ((x02 XOR y02) AND ((x01 AND y01) OR ((x01 XOR y01) AND (x00 AND y00)))))))) OR (x04 AND y04)) AND (y05 XOR x05)) OR (y05 AND x05))) OR (y06 AND x06)))) AND (y08 XOR x08)) OR (y08 AND x08)) XOR (y09 XOR x09)) OR ((y09 XOR x09) AND ((((y07 AND x07) OR ((y07 XOR x07) AND (((y06 XOR x06) AND (((((x04 XOR y04) AND ((x03 AND y03) OR ((x03 XOR y03) AND ((y02 AND x02) OR ((x02 XOR y02) AND ((x01 AND y01) OR ((x01 XOR y01) AND (x00 AND y00)))))))) OR (x04 AND y04)) AND (y05 XOR x05)) OR (y05 AND x05))) OR (y06 AND x06)))) AND (y08 XOR x08)) OR (y08 AND x08))))))))) OR (y12 AND x12)) AND (x13 XOR y13)) OR (y13 AND x13)) AND (x14 XOR y14))) AND (x15 XOR y15)) OR (x15 AND y15)) AND (x16 XOR y16)) OR (y16 AND x16)) AND (x17 XOR y17))) AND (y18 XOR x18)) OR (y18 AND x18))) OR (x19 AND y19))) AND (y21 XOR x21))) AND (y22 XOR x22)) OR (x22 AND y22))))) OR (y24 AND x24)))) AND (y26 XOR x26)))) OR (y27 AND x27)) AND (y28 XOR x28)) OR (x28 AND y28))) OR (x29 AND y29))) OR (y30 XOR x30)) AND (y31 XOR x31)))))) OR (y33 AND x33)) XOR (x34 XOR y34)) OR (x34 AND y34))) OR (y35 AND x35
# z35 is defined as: (((x33 XOR y33) AND ((y32 AND x32) OR ((y32 XOR x32) AND ((y31 AND x31) OR ((((x30 AND y30) AND (((x29 XOR y29) AND (((((x27 XOR y27) AND ((x26 AND y26) OR (((x25 AND y25) OR ((y25 XOR x25) AND (((y24 XOR x24) AND ((x23 AND y23) OR ((x23 XOR y23) AND ((((y21 AND x21) OR (((x20 XOR y20) XOR (((y19 XOR x19) AND ((((x17 AND y17) OR (((((((y14 AND x14) OR ((((((y12 XOR x12) AND ((y11 AND x11) OR ((y11 XOR x11) AND ((y10 AND x10) OR ((y10 XOR x10) AND ((((((y07 AND x07) OR ((y07 XOR x07) AND (((y06 XOR x06) AND (((((x04 XOR y04) AND ((x03 AND y03) OR ((x03 XOR y03) AND ((y02 AND x02) OR ((x02 XOR y02) AND ((x01 AND y01) OR ((x01 XOR y01) AND (x00 AND y00)))))))) OR (x04 AND y04)) AND (y05 XOR x05)) OR (y05 AND x05))) OR (y06 AND x06)))) AND (y08 XOR x08)) OR (y08 AND x08)) XOR (y09 XOR x09)) OR ((y09 XOR x09) AND ((((y07 AND x07) OR ((y07 XOR x07) AND (((y06 XOR x06) AND (((((x04 XOR y04) AND ((x03 AND y03) OR ((x03 XOR y03) AND ((y02 AND x02) OR ((x02 XOR y02) AND ((x01 AND y01) OR ((x01 XOR y01) AND (x00 AND y00)))))))) OR (x04 AND y04)) AND (y05 XOR x05)) OR (y05 AND x05))) OR (y06 AND x06)))) AND (y08 XOR x08)) OR (y08 AND x08))))))))) OR (y12 AND x12)) AND (x13 XOR y13)) OR (y13 AND x13)) AND (x14 XOR y14))) AND (x15 XOR y15)) OR (x15 AND y15)) AND (x16 XOR y16)) OR (y16 AND x16)) AND (x17 XOR y17))) AND (y18 XOR x18)) OR (y18 AND x18))) OR (x19 AND y19))) AND (y21 XOR x21))) AND (y22 XOR x22)) OR (x22 AND y22))))) OR (y24 AND x24)))) AND (y26 XOR x26)))) OR (y27 AND x27)) AND (y28 XOR x28)) OR (x28 AND y28))) OR (x29 AND y29))) OR (y30 XOR x30)) AND (y31 XOR x31)))))) OR (y33 AND x33)) XOR (x34 XOR y34)) OR (x34 AND y34)
# z34 is defined as: ((x33 XOR y33) AND ((y32 AND x32) OR ((y32 XOR x32) AND ((y31 AND x31) OR ((((x30 AND y30) AND (((x29 XOR y29) AND (((((x27 XOR y27) AND ((x26 AND y26) OR (((x25 AND y25) OR ((y25 XOR x25) AND (((y24 XOR x24) AND ((x23 AND y23) OR ((x23 XOR y23) AND ((((y21 AND x21) OR (((x20 XOR y20) XOR (((y19 XOR x19) AND ((((x17 AND y17) OR (((((((y14 AND x14) OR ((((((y12 XOR x12) AND ((y11 AND x11) OR ((y11 XOR x11) AND ((y10 AND x10) OR ((y10 XOR x10) AND ((((((y07 AND x07) OR ((y07 XOR x07) AND (((y06 XOR x06) AND (((((x04 XOR y04) AND ((x03 AND y03) OR ((x03 XOR y03) AND ((y02 AND x02) OR ((x02 XOR y02) AND ((x01 AND y01) OR ((x01 XOR y01) AND (x00 AND y00)))))))) OR (x04 AND y04)) AND (y05 XOR x05)) OR (y05 AND x05))) OR (y06 AND x06)))) AND (y08 XOR x08)) OR (y08 AND x08)) XOR (y09 XOR x09)) OR ((y09 XOR x09) AND ((((y07 AND x07) OR ((y07 XOR x07) AND (((y06 XOR x06) AND (((((x04 XOR y04) AND ((x03 AND y03) OR ((x03 XOR y03) AND ((y02 AND x02) OR ((x02 XOR y02) AND ((x01 AND y01) OR ((x01 XOR y01) AND (x00 AND y00)))))))) OR (x04 AND y04)) AND (y05 XOR x05)) OR (y05 AND x05))) OR (y06 AND x06)))) AND (y08 XOR x08)) OR (y08 AND x08))))))))) OR (y12 AND x12)) AND (x13 XOR y13)) OR (y13 AND x13)) AND (x14 XOR y14))) AND (x15 XOR y15)) OR (x15 AND y15)) AND (x16 XOR y16)) OR (y16 AND x16)) AND (x17 XOR y17))) AND (y18 XOR x18)) OR (y18 AND x18))) OR (x19 AND y19))) AND (y21 XOR x21))) AND (y22 XOR x22)) OR (x22 AND y22))))) OR (y24 AND x24)))) AND (y26 XOR x26)))) OR (y27 AND x27)) AND (y28 XOR x28)) OR (x28 AND y28))) OR (x29 AND y29))) OR (y30 XOR x30)) AND (y31 XOR x31)))))) OR (y33 AND x33
# z33 is defined as: y32 AND x32) OR ((y32 XOR x32) AND ((y31 AND x31) OR ((((x30 AND y30) AND (((x29 XOR y29) AND (((((x27 XOR y27) AND ((x26 AND y26) OR (((x25 AND y25) OR ((y25 XOR x25) AND (((y24 XOR x24) AND ((x23 AND y23) OR ((x23 XOR y23) AND ((((y21 AND x21) OR (((x20 XOR y20) XOR (((y19 XOR x19) AND ((((x17 AND y17) OR (((((((y14 AND x14) OR ((((((y12 XOR x12) AND ((y11 AND x11) OR ((y11 XOR x11) AND ((y10 AND x10) OR ((y10 XOR x10) AND ((((((y07 AND x07) OR ((y07 XOR x07) AND (((y06 XOR x06) AND (((((x04 XOR y04) AND ((x03 AND y03) OR ((x03 XOR y03) AND ((y02 AND x02) OR ((x02 XOR y02) AND ((x01 AND y01) OR ((x01 XOR y01) AND (x00 AND y00)))))))) OR (x04 AND y04)) AND (y05 XOR x05)) OR (y05 AND x05))) OR (y06 AND x06)))) AND (y08 XOR x08)) OR (y08 AND x08)) XOR (y09 XOR x09)) OR ((y09 XOR x09) AND ((((y07 AND x07) OR ((y07 XOR x07) AND (((y06 XOR x06) AND (((((x04 XOR y04) AND ((x03 AND y03) OR ((x03 XOR y03) AND ((y02 AND x02) OR ((x02 XOR y02) AND ((x01 AND y01) OR ((x01 XOR y01) AND (x00 AND y00)))))))) OR (x04 AND y04)) AND (y05 XOR x05)) OR (y05 AND x05))) OR (y06 AND x06)))) AND (y08 XOR x08)) OR (y08 AND x08))))))))) OR (y12 AND x12)) AND (x13 XOR y13)) OR (y13 AND x13)) AND (x14 XOR y14))) AND (x15 XOR y15)) OR (x15 AND y15)) AND (x16 XOR y16)) OR (y16 AND x16)) AND (x17 XOR y17))) AND (y18 XOR x18)) OR (y18 AND x18))) OR (x19 AND y19))) AND (y21 XOR x21))) AND (y22 XOR x22)) OR (x22 AND y22))))) OR (y24 AND x24)))) AND (y26 XOR x26)))) OR (y27 AND x27)) AND (y28 XOR x28)) OR (x28 AND y28))) OR (x29 AND y29))) OR (y30 XOR x30)) AND (y31 XOR x31))))
# z32 is defined as: y31 AND x31) OR ((((x30 AND y30) AND (((x29 XOR y29) AND (((((x27 XOR y27) AND ((x26 AND y26) OR (((x25 AND y25) OR ((y25 XOR x25) AND (((y24 XOR x24) AND ((x23 AND y23) OR ((x23 XOR y23) AND ((((y21 AND x21) OR (((x20 XOR y20) XOR (((y19 XOR x19) AND ((((x17 AND y17) OR (((((((y14 AND x14) OR ((((((y12 XOR x12) AND ((y11 AND x11) OR ((y11 XOR x11) AND ((y10 AND x10) OR ((y10 XOR x10) AND ((((((y07 AND x07) OR ((y07 XOR x07) AND (((y06 XOR x06) AND (((((x04 XOR y04) AND ((x03 AND y03) OR ((x03 XOR y03) AND ((y02 AND x02) OR ((x02 XOR y02) AND ((x01 AND y01) OR ((x01 XOR y01) AND (x00 AND y00)))))))) OR (x04 AND y04)) AND (y05 XOR x05)) OR (y05 AND x05))) OR (y06 AND x06)))) AND (y08 XOR x08)) OR (y08 AND x08)) XOR (y09 XOR x09)) OR ((y09 XOR x09) AND ((((y07 AND x07) OR ((y07 XOR x07) AND (((y06 XOR x06) AND (((((x04 XOR y04) AND ((x03 AND y03) OR ((x03 XOR y03) AND ((y02 AND x02) OR ((x02 XOR y02) AND ((x01 AND y01) OR ((x01 XOR y01) AND (x00 AND y00)))))))) OR (x04 AND y04)) AND (y05 XOR x05)) OR (y05 AND x05))) OR (y06 AND x06)))) AND (y08 XOR x08)) OR (y08 AND x08))))))))) OR (y12 AND x12)) AND (x13 XOR y13)) OR (y13 AND x13)) AND (x14 XOR y14))) AND (x15 XOR y15)) OR (x15 AND y15)) AND (x16 XOR y16)) OR (y16 AND x16)) AND (x17 XOR y17))) AND (y18 XOR x18)) OR (y18 AND x18))) OR (x19 AND y19))) AND (y21 XOR x21))) AND (y22 XOR x22)) OR (x22 AND y22))))) OR (y24 AND x24)))) AND (y26 XOR x26)))) OR (y27 AND x27)) AND (y28 XOR x28)) OR (x28 AND y28))) OR (x29 AND y29))) OR (y30 XOR x30)) AND (y31 XOR x31))
# z31 is defined as: ((x30 AND y30) AND (((x29 XOR y29) AND (((((x27 XOR y27) AND ((x26 AND y26) OR (((x25 AND y25) OR ((y25 XOR x25) AND (((y24 XOR x24) AND ((x23 AND y23) OR ((x23 XOR y23) AND ((((y21 AND x21) OR (((x20 XOR y20) XOR (((y19 XOR x19) AND ((((x17 AND y17) OR (((((((y14 AND x14) OR ((((((y12 XOR x12) AND ((y11 AND x11) OR ((y11 XOR x11) AND ((y10 AND x10) OR ((y10 XOR x10) AND ((((((y07 AND x07) OR ((y07 XOR x07) AND (((y06 XOR x06) AND (((((x04 XOR y04) AND ((x03 AND y03) OR ((x03 XOR y03) AND ((y02 AND x02) OR ((x02 XOR y02) AND ((x01 AND y01) OR ((x01 XOR y01) AND (x00 AND y00)))))))) OR (x04 AND y04)) AND (y05 XOR x05)) OR (y05 AND x05))) OR (y06 AND x06)))) AND (y08 XOR x08)) OR (y08 AND x08)) XOR (y09 XOR x09)) OR ((y09 XOR x09) AND ((((y07 AND x07) OR ((y07 XOR x07) AND (((y06 XOR x06) AND (((((x04 XOR y04) AND ((x03 AND y03) OR ((x03 XOR y03) AND ((y02 AND x02) OR ((x02 XOR y02) AND ((x01 AND y01) OR ((x01 XOR y01) AND (x00 AND y00)))))))) OR (x04 AND y04)) AND (y05 XOR x05)) OR (y05 AND x05))) OR (y06 AND x06)))) AND (y08 XOR x08)) OR (y08 AND x08))))))))) OR (y12 AND x12)) AND (x13 XOR y13)) OR (y13 AND x13)) AND (x14 XOR y14))) AND (x15 XOR y15)) OR (x15 AND y15)) AND (x16 XOR y16)) OR (y16 AND x16)) AND (x17 XOR y17))) AND (y18 XOR x18)) OR (y18 AND x18))) OR (x19 AND y19))) AND (y21 XOR x21))) AND (y22 XOR x22)) OR (x22 AND y22))))) OR (y24 AND x24)))) AND (y26 XOR x26)))) OR (y27 AND x27)) AND (y28 XOR x28)) OR (x28 AND y28))) OR (x29 AND y29))) OR (y30 XOR x30
# z30 is defined as: (x29 XOR y29) AND (((((x27 XOR y27) AND ((x26 AND y26) OR (((x25 AND y25) OR ((y25 XOR x25) AND (((y24 XOR x24) AND ((x23 AND y23) OR ((x23 XOR y23) AND ((((y21 AND x21) OR (((x20 XOR y20) XOR (((y19 XOR x19) AND ((((x17 AND y17) OR (((((((y14 AND x14) OR ((((((y12 XOR x12) AND ((y11 AND x11) OR ((y11 XOR x11) AND ((y10 AND x10) OR ((y10 XOR x10) AND ((((((y07 AND x07) OR ((y07 XOR x07) AND (((y06 XOR x06) AND (((((x04 XOR y04) AND ((x03 AND y03) OR ((x03 XOR y03) AND ((y02 AND x02) OR ((x02 XOR y02) AND ((x01 AND y01) OR ((x01 XOR y01) AND (x00 AND y00)))))))) OR (x04 AND y04)) AND (y05 XOR x05)) OR (y05 AND x05))) OR (y06 AND x06)))) AND (y08 XOR x08)) OR (y08 AND x08)) XOR (y09 XOR x09)) OR ((y09 XOR x09) AND ((((y07 AND x07) OR ((y07 XOR x07) AND (((y06 XOR x06) AND (((((x04 XOR y04) AND ((x03 AND y03) OR ((x03 XOR y03) AND ((y02 AND x02) OR ((x02 XOR y02) AND ((x01 AND y01) OR ((x01 XOR y01) AND (x00 AND y00)))))))) OR (x04 AND y04)) AND (y05 XOR x05)) OR (y05 AND x05))) OR (y06 AND x06)))) AND (y08 XOR x08)) OR (y08 AND x08))))))))) OR (y12 AND x12)) AND (x13 XOR y13)) OR (y13 AND x13)) AND (x14 XOR y14))) AND (x15 XOR y15)) OR (x15 AND y15)) AND (x16 XOR y16)) OR (y16 AND x16)) AND (x17 XOR y17))) AND (y18 XOR x18)) OR (y18 AND x18))) OR (x19 AND y19))) AND (y21 XOR x21))) AND (y22 XOR x22)) OR (x22 AND y22))))) OR (y24 AND x24)))) AND (y26 XOR x26)))) OR (y27 AND x27)) AND (y28 XOR x28)) OR (x28 AND y28))) OR (x29 AND y29)
# z29 is defined as: (((x27 XOR y27) AND ((x26 AND y26) OR (((x25 AND y25) OR ((y25 XOR x25) AND (((y24 XOR x24) AND ((x23 AND y23) OR ((x23 XOR y23) AND ((((y21 AND x21) OR (((x20 XOR y20) XOR (((y19 XOR x19) AND ((((x17 AND y17) OR (((((((y14 AND x14) OR ((((((y12 XOR x12) AND ((y11 AND x11) OR ((y11 XOR x11) AND ((y10 AND x10) OR ((y10 XOR x10) AND ((((((y07 AND x07) OR ((y07 XOR x07) AND (((y06 XOR x06) AND (((((x04 XOR y04) AND ((x03 AND y03) OR ((x03 XOR y03) AND ((y02 AND x02) OR ((x02 XOR y02) AND ((x01 AND y01) OR ((x01 XOR y01) AND (x00 AND y00)))))))) OR (x04 AND y04)) AND (y05 XOR x05)) OR (y05 AND x05))) OR (y06 AND x06)))) AND (y08 XOR x08)) OR (y08 AND x08)) XOR (y09 XOR x09)) OR ((y09 XOR x09) AND ((((y07 AND x07) OR ((y07 XOR x07) AND (((y06 XOR x06) AND (((((x04 XOR y04) AND ((x03 AND y03) OR ((x03 XOR y03) AND ((y02 AND x02) OR ((x02 XOR y02) AND ((x01 AND y01) OR ((x01 XOR y01) AND (x00 AND y00)))))))) OR (x04 AND y04)) AND (y05 XOR x05)) OR (y05 AND x05))) OR (y06 AND x06)))) AND (y08 XOR x08)) OR (y08 AND x08))))))))) OR (y12 AND x12)) AND (x13 XOR y13)) OR (y13 AND x13)) AND (x14 XOR y14))) AND (x15 XOR y15)) OR (x15 AND y15)) AND (x16 XOR y16)) OR (y16 AND x16)) AND (x17 XOR y17))) AND (y18 XOR x18)) OR (y18 AND x18))) OR (x19 AND y19))) AND (y21 XOR x21))) AND (y22 XOR x22)) OR (x22 AND y22))))) OR (y24 AND x24)))) AND (y26 XOR x26)))) OR (y27 AND x27)) AND (y28 XOR x28)) OR (x28 AND y28)
# z28 is defined as: (x27 XOR y27) AND ((x26 AND y26) OR (((x25 AND y25) OR ((y25 XOR x25) AND (((y24 XOR x24) AND ((x23 AND y23) OR ((x23 XOR y23) AND ((((y21 AND x21) OR (((x20 XOR y20) XOR (((y19 XOR x19) AND ((((x17 AND y17) OR (((((((y14 AND x14) OR ((((((y12 XOR x12) AND ((y11 AND x11) OR ((y11 XOR x11) AND ((y10 AND x10) OR ((y10 XOR x10) AND ((((((y07 AND x07) OR ((y07 XOR x07) AND (((y06 XOR x06) AND (((((x04 XOR y04) AND ((x03 AND y03) OR ((x03 XOR y03) AND ((y02 AND x02) OR ((x02 XOR y02) AND ((x01 AND y01) OR ((x01 XOR y01) AND (x00 AND y00)))))))) OR (x04 AND y04)) AND (y05 XOR x05)) OR (y05 AND x05))) OR (y06 AND x06)))) AND (y08 XOR x08)) OR (y08 AND x08)) XOR (y09 XOR x09)) OR ((y09 XOR x09) AND ((((y07 AND x07) OR ((y07 XOR x07) AND (((y06 XOR x06) AND (((((x04 XOR y04) AND ((x03 AND y03) OR ((x03 XOR y03) AND ((y02 AND x02) OR ((x02 XOR y02) AND ((x01 AND y01) OR ((x01 XOR y01) AND (x00 AND y00)))))))) OR (x04 AND y04)) AND (y05 XOR x05)) OR (y05 AND x05))) OR (y06 AND x06)))) AND (y08 XOR x08)) OR (y08 AND x08))))))))) OR (y12 AND x12)) AND (x13 XOR y13)) OR (y13 AND x13)) AND (x14 XOR y14))) AND (x15 XOR y15)) OR (x15 AND y15)) AND (x16 XOR y16)) OR (y16 AND x16)) AND (x17 XOR y17))) AND (y18 XOR x18)) OR (y18 AND x18))) OR (x19 AND y19))) AND (y21 XOR x21))) AND (y22 XOR x22)) OR (x22 AND y22))))) OR (y24 AND x24)))) AND (y26 XOR x26)))) OR (y27 AND x27)
# z27 is defined as: (x26 AND y26) OR (((x25 AND y25) OR ((y25 XOR x25) AND (((y24 XOR x24) AND ((x23 AND y23) OR ((x23 XOR y23) AND ((((y21 AND x21) OR (((x20 XOR y20) XOR (((y19 XOR x19) AND ((((x17 AND y17) OR (((((((y14 AND x14) OR ((((((y12 XOR x12) AND ((y11 AND x11) OR ((y11 XOR x11) AND ((y10 AND x10) OR ((y10 XOR x10) AND ((((((y07 AND x07) OR ((y07 XOR x07) AND (((y06 XOR x06) AND (((((x04 XOR y04) AND ((x03 AND y03) OR ((x03 XOR y03) AND ((y02 AND x02) OR ((x02 XOR y02) AND ((x01 AND y01) OR ((x01 XOR y01) AND (x00 AND y00)))))))) OR (x04 AND y04)) AND (y05 XOR x05)) OR (y05 AND x05))) OR (y06 AND x06)))) AND (y08 XOR x08)) OR (y08 AND x08)) XOR (y09 XOR x09)) OR ((y09 XOR x09) AND ((((y07 AND x07) OR ((y07 XOR x07) AND (((y06 XOR x06) AND (((((x04 XOR y04) AND ((x03 AND y03) OR ((x03 XOR y03) AND ((y02 AND x02) OR ((x02 XOR y02) AND ((x01 AND y01) OR ((x01 XOR y01) AND (x00 AND y00)))))))) OR (x04 AND y04)) AND (y05 XOR x05)) OR (y05 AND x05))) OR (y06 AND x06)))) AND (y08 XOR x08)) OR (y08 AND x08))))))))) OR (y12 AND x12)) AND (x13 XOR y13)) OR (y13 AND x13)) AND (x14 XOR y14))) AND (x15 XOR y15)) OR (x15 AND y15)) AND (x16 XOR y16)) OR (y16 AND x16)) AND (x17 XOR y17))) AND (y18 XOR x18)) OR (y18 AND x18))) OR (x19 AND y19))) AND (y21 XOR x21))) AND (y22 XOR x22)) OR (x22 AND y22))))) OR (y24 AND x24)))) AND (y26 XOR x26)
# z26 is defined as: x25 AND y25) OR ((y25 XOR x25) AND (((y24 XOR x24) AND ((x23 AND y23) OR ((x23 XOR y23) AND ((((y21 AND x21) OR (((x20 XOR y20) XOR (((y19 XOR x19) AND ((((x17 AND y17) OR (((((((y14 AND x14) OR ((((((y12 XOR x12) AND ((y11 AND x11) OR ((y11 XOR x11) AND ((y10 AND x10) OR ((y10 XOR x10) AND ((((((y07 AND x07) OR ((y07 XOR x07) AND (((y06 XOR x06) AND (((((x04 XOR y04) AND ((x03 AND y03) OR ((x03 XOR y03) AND ((y02 AND x02) OR ((x02 XOR y02) AND ((x01 AND y01) OR ((x01 XOR y01) AND (x00 AND y00)))))))) OR (x04 AND y04)) AND (y05 XOR x05)) OR (y05 AND x05))) OR (y06 AND x06)))) AND (y08 XOR x08)) OR (y08 AND x08)) XOR (y09 XOR x09)) OR ((y09 XOR x09) AND ((((y07 AND x07) OR ((y07 XOR x07) AND (((y06 XOR x06) AND (((((x04 XOR y04) AND ((x03 AND y03) OR ((x03 XOR y03) AND ((y02 AND x02) OR ((x02 XOR y02) AND ((x01 AND y01) OR ((x01 XOR y01) AND (x00 AND y00)))))))) OR (x04 AND y04)) AND (y05 XOR x05)) OR (y05 AND x05))) OR (y06 AND x06)))) AND (y08 XOR x08)) OR (y08 AND x08))))))))) OR (y12 AND x12)) AND (x13 XOR y13)) OR (y13 AND x13)) AND (x14 XOR y14))) AND (x15 XOR y15)) OR (x15 AND y15)) AND (x16 XOR y16)) OR (y16 AND x16)) AND (x17 XOR y17))) AND (y18 XOR x18)) OR (y18 AND x18))) OR (x19 AND y19))) AND (y21 XOR x21))) AND (y22 XOR x22)) OR (x22 AND y22))))) OR (y24 AND x24)))
# z25 is defined as: (y24 XOR x24) AND ((x23 AND y23) OR ((x23 XOR y23) AND ((((y21 AND x21) OR (((x20 XOR y20) XOR (((y19 XOR x19) AND ((((x17 AND y17) OR (((((((y14 AND x14) OR ((((((y12 XOR x12) AND ((y11 AND x11) OR ((y11 XOR x11) AND ((y10 AND x10) OR ((y10 XOR x10) AND ((((((y07 AND x07) OR ((y07 XOR x07) AND (((y06 XOR x06) AND (((((x04 XOR y04) AND ((x03 AND y03) OR ((x03 XOR y03) AND ((y02 AND x02) OR ((x02 XOR y02) AND ((x01 AND y01) OR ((x01 XOR y01) AND (x00 AND y00)))))))) OR (x04 AND y04)) AND (y05 XOR x05)) OR (y05 AND x05))) OR (y06 AND x06)))) AND (y08 XOR x08)) OR (y08 AND x08)) XOR (y09 XOR x09)) OR ((y09 XOR x09) AND ((((y07 AND x07) OR ((y07 XOR x07) AND (((y06 XOR x06) AND (((((x04 XOR y04) AND ((x03 AND y03) OR ((x03 XOR y03) AND ((y02 AND x02) OR ((x02 XOR y02) AND ((x01 AND y01) OR ((x01 XOR y01) AND (x00 AND y00)))))))) OR (x04 AND y04)) AND (y05 XOR x05)) OR (y05 AND x05))) OR (y06 AND x06)))) AND (y08 XOR x08)) OR (y08 AND x08))))))))) OR (y12 AND x12)) AND (x13 XOR y13)) OR (y13 AND x13)) AND (x14 XOR y14))) AND (x15 XOR y15)) OR (x15 AND y15)) AND (x16 XOR y16)) OR (y16 AND x16)) AND (x17 XOR y17))) AND (y18 XOR x18)) OR (y18 AND x18))) OR (x19 AND y19))) AND (y21 XOR x21))) AND (y22 XOR x22)) OR (x22 AND y22))))) OR (y24 AND x24)
# z24 is defined as: x23 AND y23) OR ((x23 XOR y23) AND ((((y21 AND x21) OR (((x20 XOR y20) XOR (((y19 XOR x19) AND ((((x17 AND y17) OR (((((((y14 AND x14) OR ((((((y12 XOR x12) AND ((y11 AND x11) OR ((y11 XOR x11) AND ((y10 AND x10) OR ((y10 XOR x10) AND ((((((y07 AND x07) OR ((y07 XOR x07) AND (((y06 XOR x06) AND (((((x04 XOR y04) AND ((x03 AND y03) OR ((x03 XOR y03) AND ((y02 AND x02) OR ((x02 XOR y02) AND ((x01 AND y01) OR ((x01 XOR y01) AND (x00 AND y00)))))))) OR (x04 AND y04)) AND (y05 XOR x05)) OR (y05 AND x05))) OR (y06 AND x06)))) AND (y08 XOR x08)) OR (y08 AND x08)) XOR (y09 XOR x09)) OR ((y09 XOR x09) AND ((((y07 AND x07) OR ((y07 XOR x07) AND (((y06 XOR x06) AND (((((x04 XOR y04) AND ((x03 AND y03) OR ((x03 XOR y03) AND ((y02 AND x02) OR ((x02 XOR y02) AND ((x01 AND y01) OR ((x01 XOR y01) AND (x00 AND y00)))))))) OR (x04 AND y04)) AND (y05 XOR x05)) OR (y05 AND x05))) OR (y06 AND x06)))) AND (y08 XOR x08)) OR (y08 AND x08))))))))) OR (y12 AND x12)) AND (x13 XOR y13)) OR (y13 AND x13)) AND (x14 XOR y14))) AND (x15 XOR y15)) OR (x15 AND y15)) AND (x16 XOR y16)) OR (y16 AND x16)) AND (x17 XOR y17))) AND (y18 XOR x18)) OR (y18 AND x18))) OR (x19 AND y19))) AND (y21 XOR x21))) AND (y22 XOR x22)) OR (x22 AND y22)))
# z23 is defined as: ((y21 AND x21) OR (((x20 XOR y20) XOR (((y19 XOR x19) AND ((((x17 AND y17) OR (((((((y14 AND x14) OR ((((((y12 XOR x12) AND ((y11 AND x11) OR ((y11 XOR x11) AND ((y10 AND x10) OR ((y10 XOR x10) AND ((((((y07 AND x07) OR ((y07 XOR x07) AND (((y06 XOR x06) AND (((((x04 XOR y04) AND ((x03 AND y03) OR ((x03 XOR y03) AND ((y02 AND x02) OR ((x02 XOR y02) AND ((x01 AND y01) OR ((x01 XOR y01) AND (x00 AND y00)))))))) OR (x04 AND y04)) AND (y05 XOR x05)) OR (y05 AND x05))) OR (y06 AND x06)))) AND (y08 XOR x08)) OR (y08 AND x08)) XOR (y09 XOR x09)) OR ((y09 XOR x09) AND ((((y07 AND x07) OR ((y07 XOR x07) AND (((y06 XOR x06) AND (((((x04 XOR y04) AND ((x03 AND y03) OR ((x03 XOR y03) AND ((y02 AND x02) OR ((x02 XOR y02) AND ((x01 AND y01) OR ((x01 XOR y01) AND (x00 AND y00)))))))) OR (x04 AND y04)) AND (y05 XOR x05)) OR (y05 AND x05))) OR (y06 AND x06)))) AND (y08 XOR x08)) OR (y08 AND x08))))))))) OR (y12 AND x12)) AND (x13 XOR y13)) OR (y13 AND x13)) AND (x14 XOR y14))) AND (x15 XOR y15)) OR (x15 AND y15)) AND (x16 XOR y16)) OR (y16 AND x16)) AND (x17 XOR y17))) AND (y18 XOR x18)) OR (y18 AND x18))) OR (x19 AND y19))) AND (y21 XOR x21))) AND (y22 XOR x22)) OR (x22 AND y22)
# z22 is defined as: (y21 AND x21) OR (((x20 XOR y20) XOR (((y19 XOR x19) AND ((((x17 AND y17) OR (((((((y14 AND x14) OR ((((((y12 XOR x12) AND ((y11 AND x11) OR ((y11 XOR x11) AND ((y10 AND x10) OR ((y10 XOR x10) AND ((((((y07 AND x07) OR ((y07 XOR x07) AND (((y06 XOR x06) AND (((((x04 XOR y04) AND ((x03 AND y03) OR ((x03 XOR y03) AND ((y02 AND x02) OR ((x02 XOR y02) AND ((x01 AND y01) OR ((x01 XOR y01) AND (x00 AND y00)))))))) OR (x04 AND y04)) AND (y05 XOR x05)) OR (y05 AND x05))) OR (y06 AND x06)))) AND (y08 XOR x08)) OR (y08 AND x08)) XOR (y09 XOR x09)) OR ((y09 XOR x09) AND ((((y07 AND x07) OR ((y07 XOR x07) AND (((y06 XOR x06) AND (((((x04 XOR y04) AND ((x03 AND y03) OR ((x03 XOR y03) AND ((y02 AND x02) OR ((x02 XOR y02) AND ((x01 AND y01) OR ((x01 XOR y01) AND (x00 AND y00)))))))) OR (x04 AND y04)) AND (y05 XOR x05)) OR (y05 AND x05))) OR (y06 AND x06)))) AND (y08 XOR x08)) OR (y08 AND x08))))))))) OR (y12 AND x12)) AND (x13 XOR y13)) OR (y13 AND x13)) AND (x14 XOR y14))) AND (x15 XOR y15)) OR (x15 AND y15)) AND (x16 XOR y16)) OR (y16 AND x16)) AND (x17 XOR y17))) AND (y18 XOR x18)) OR (y18 AND x18))) OR (x19 AND y19))) AND (y21 XOR x21)
# z21 is defined as: x20 XOR y20) XOR (((y19 XOR x19) AND ((((x17 AND y17) OR (((((((y14 AND x14) OR ((((((y12 XOR x12) AND ((y11 AND x11) OR ((y11 XOR x11) AND ((y10 AND x10) OR ((y10 XOR x10) AND ((((((y07 AND x07) OR ((y07 XOR x07) AND (((y06 XOR x06) AND (((((x04 XOR y04) AND ((x03 AND y03) OR ((x03 XOR y03) AND ((y02 AND x02) OR ((x02 XOR y02) AND ((x01 AND y01) OR ((x01 XOR y01) AND (x00 AND y00)))))))) OR (x04 AND y04)) AND (y05 XOR x05)) OR (y05 AND x05))) OR (y06 AND x06)))) AND (y08 XOR x08)) OR (y08 AND x08)) XOR (y09 XOR x09)) OR ((y09 XOR x09) AND ((((y07 AND x07) OR ((y07 XOR x07) AND (((y06 XOR x06) AND (((((x04 XOR y04) AND ((x03 AND y03) OR ((x03 XOR y03) AND ((y02 AND x02) OR ((x02 XOR y02) AND ((x01 AND y01) OR ((x01 XOR y01) AND (x00 AND y00)))))))) OR (x04 AND y04)) AND (y05 XOR x05)) OR (y05 AND x05))) OR (y06 AND x06)))) AND (y08 XOR x08)) OR (y08 AND x08))))))))) OR (y12 AND x12)) AND (x13 XOR y13)) OR (y13 AND x13)) AND (x14 XOR y14))) AND (x15 XOR y15)) OR (x15 AND y15)) AND (x16 XOR y16)) OR (y16 AND x16)) AND (x17 XOR y17))) AND (y18 XOR x18)) OR (y18 AND x18))) OR (x19 AND y19))
# z20 is defined as: ((y19 XOR x19) AND ((((x17 AND y17) OR (((((((y14 AND x14) OR ((((((y12 XOR x12) AND ((y11 AND x11) OR ((y11 XOR x11) AND ((y10 AND x10) OR ((y10 XOR x10) AND ((((((y07 AND x07) OR ((y07 XOR x07) AND (((y06 XOR x06) AND (((((x04 XOR y04) AND ((x03 AND y03) OR ((x03 XOR y03) AND ((y02 AND x02) OR ((x02 XOR y02) AND ((x01 AND y01) OR ((x01 XOR y01) AND (x00 AND y00)))))))) OR (x04 AND y04)) AND (y05 XOR x05)) OR (y05 AND x05))) OR (y06 AND x06)))) AND (y08 XOR x08)) OR (y08 AND x08)) XOR (y09 XOR x09)) OR ((y09 XOR x09) AND ((((y07 AND x07) OR ((y07 XOR x07) AND (((y06 XOR x06) AND (((((x04 XOR y04) AND ((x03 AND y03) OR ((x03 XOR y03) AND ((y02 AND x02) OR ((x02 XOR y02) AND ((x01 AND y01) OR ((x01 XOR y01) AND (x00 AND y00)))))))) OR (x04 AND y04)) AND (y05 XOR x05)) OR (y05 AND x05))) OR (y06 AND x06)))) AND (y08 XOR x08)) OR (y08 AND x08))))))))) OR (y12 AND x12)) AND (x13 XOR y13)) OR (y13 AND x13)) AND (x14 XOR y14))) AND (x15 XOR y15)) OR (x15 AND y15)) AND (x16 XOR y16)) OR (y16 AND x16)) AND (x17 XOR y17))) AND (y18 XOR x18)) OR (y18 AND x18))) OR (x19 AND y19)) AND (x20 XOR y20)
# z19 is defined as: (((x17 AND y17) OR (((((((y14 AND x14) OR ((((((y12 XOR x12) AND ((y11 AND x11) OR ((y11 XOR x11) AND ((y10 AND x10) OR ((y10 XOR x10) AND ((((((y07 AND x07) OR ((y07 XOR x07) AND (((y06 XOR x06) AND (((((x04 XOR y04) AND ((x03 AND y03) OR ((x03 XOR y03) AND ((y02 AND x02) OR ((x02 XOR y02) AND ((x01 AND y01) OR ((x01 XOR y01) AND (x00 AND y00)))))))) OR (x04 AND y04)) AND (y05 XOR x05)) OR (y05 AND x05))) OR (y06 AND x06)))) AND (y08 XOR x08)) OR (y08 AND x08)) XOR (y09 XOR x09)) OR ((y09 XOR x09) AND ((((y07 AND x07) OR ((y07 XOR x07) AND (((y06 XOR x06) AND (((((x04 XOR y04) AND ((x03 AND y03) OR ((x03 XOR y03) AND ((y02 AND x02) OR ((x02 XOR y02) AND ((x01 AND y01) OR ((x01 XOR y01) AND (x00 AND y00)))))))) OR (x04 AND y04)) AND (y05 XOR x05)) OR (y05 AND x05))) OR (y06 AND x06)))) AND (y08 XOR x08)) OR (y08 AND x08))))))))) OR (y12 AND x12)) AND (x13 XOR y13)) OR (y13 AND x13)) AND (x14 XOR y14))) AND (x15 XOR y15)) OR (x15 AND y15)) AND (x16 XOR y16)) OR (y16 AND x16)) AND (x17 XOR y17))) AND (y18 XOR x18)) OR (y18 AND x18
# z18 is defined as: x17 AND y17) OR (((((((y14 AND x14) OR ((((((y12 XOR x12) AND ((y11 AND x11) OR ((y11 XOR x11) AND ((y10 AND x10) OR ((y10 XOR x10) AND ((((((y07 AND x07) OR ((y07 XOR x07) AND (((y06 XOR x06) AND (((((x04 XOR y04) AND ((x03 AND y03) OR ((x03 XOR y03) AND ((y02 AND x02) OR ((x02 XOR y02) AND ((x01 AND y01) OR ((x01 XOR y01) AND (x00 AND y00)))))))) OR (x04 AND y04)) AND (y05 XOR x05)) OR (y05 AND x05))) OR (y06 AND x06)))) AND (y08 XOR x08)) OR (y08 AND x08)) XOR (y09 XOR x09)) OR ((y09 XOR x09) AND ((((y07 AND x07) OR ((y07 XOR x07) AND (((y06 XOR x06) AND (((((x04 XOR y04) AND ((x03 AND y03) OR ((x03 XOR y03) AND ((y02 AND x02) OR ((x02 XOR y02) AND ((x01 AND y01) OR ((x01 XOR y01) AND (x00 AND y00)))))))) OR (x04 AND y04)) AND (y05 XOR x05)) OR (y05 AND x05))) OR (y06 AND x06)))) AND (y08 XOR x08)) OR (y08 AND x08))))))))) OR (y12 AND x12)) AND (x13 XOR y13)) OR (y13 AND x13)) AND (x14 XOR y14))) AND (x15 XOR y15)) OR (x15 AND y15)) AND (x16 XOR y16)) OR (y16 AND x16)) AND (x17 XOR y17))
# z17 is defined as: ((((y14 AND x14) OR ((((((y12 XOR x12) AND ((y11 AND x11) OR ((y11 XOR x11) AND ((y10 AND x10) OR ((y10 XOR x10) AND ((((((y07 AND x07) OR ((y07 XOR x07) AND (((y06 XOR x06) AND (((((x04 XOR y04) AND ((x03 AND y03) OR ((x03 XOR y03) AND ((y02 AND x02) OR ((x02 XOR y02) AND ((x01 AND y01) OR ((x01 XOR y01) AND (x00 AND y00)))))))) OR (x04 AND y04)) AND (y05 XOR x05)) OR (y05 AND x05))) OR (y06 AND x06)))) AND (y08 XOR x08)) OR (y08 AND x08)) XOR (y09 XOR x09)) OR ((y09 XOR x09) AND ((((y07 AND x07) OR ((y07 XOR x07) AND (((y06 XOR x06) AND (((((x04 XOR y04) AND ((x03 AND y03) OR ((x03 XOR y03) AND ((y02 AND x02) OR ((x02 XOR y02) AND ((x01 AND y01) OR ((x01 XOR y01) AND (x00 AND y00)))))))) OR (x04 AND y04)) AND (y05 XOR x05)) OR (y05 AND x05))) OR (y06 AND x06)))) AND (y08 XOR x08)) OR (y08 AND x08))))))))) OR (y12 AND x12)) AND (x13 XOR y13)) OR (y13 AND x13)) AND (x14 XOR y14))) AND (x15 XOR y15)) OR (x15 AND y15)) AND (x16 XOR y16)) OR (y16 AND x16)
# z16 is defined as: ((y14 AND x14) OR ((((((y12 XOR x12) AND ((y11 AND x11) OR ((y11 XOR x11) AND ((y10 AND x10) OR ((y10 XOR x10) AND ((((((y07 AND x07) OR ((y07 XOR x07) AND (((y06 XOR x06) AND (((((x04 XOR y04) AND ((x03 AND y03) OR ((x03 XOR y03) AND ((y02 AND x02) OR ((x02 XOR y02) AND ((x01 AND y01) OR ((x01 XOR y01) AND (x00 AND y00)))))))) OR (x04 AND y04)) AND (y05 XOR x05)) OR (y05 AND x05))) OR (y06 AND x06)))) AND (y08 XOR x08)) OR (y08 AND x08)) XOR (y09 XOR x09)) OR ((y09 XOR x09) AND ((((y07 AND x07) OR ((y07 XOR x07) AND (((y06 XOR x06) AND (((((x04 XOR y04) AND ((x03 AND y03) OR ((x03 XOR y03) AND ((y02 AND x02) OR ((x02 XOR y02) AND ((x01 AND y01) OR ((x01 XOR y01) AND (x00 AND y00)))))))) OR (x04 AND y04)) AND (y05 XOR x05)) OR (y05 AND x05))) OR (y06 AND x06)))) AND (y08 XOR x08)) OR (y08 AND x08))))))))) OR (y12 AND x12)) AND (x13 XOR y13)) OR (y13 AND x13)) AND (x14 XOR y14))) AND (x15 XOR y15)) OR (x15 AND y15)
# z15 is defined as: y14 AND x14) OR ((((((y12 XOR x12) AND ((y11 AND x11) OR ((y11 XOR x11) AND ((y10 AND x10) OR ((y10 XOR x10) AND ((((((y07 AND x07) OR ((y07 XOR x07) AND (((y06 XOR x06) AND (((((x04 XOR y04) AND ((x03 AND y03) OR ((x03 XOR y03) AND ((y02 AND x02) OR ((x02 XOR y02) AND ((x01 AND y01) OR ((x01 XOR y01) AND (x00 AND y00)))))))) OR (x04 AND y04)) AND (y05 XOR x05)) OR (y05 AND x05))) OR (y06 AND x06)))) AND (y08 XOR x08)) OR (y08 AND x08)) XOR (y09 XOR x09)) OR ((y09 XOR x09) AND ((((y07 AND x07) OR ((y07 XOR x07) AND (((y06 XOR x06) AND (((((x04 XOR y04) AND ((x03 AND y03) OR ((x03 XOR y03) AND ((y02 AND x02) OR ((x02 XOR y02) AND ((x01 AND y01) OR ((x01 XOR y01) AND (x00 AND y00)))))))) OR (x04 AND y04)) AND (y05 XOR x05)) OR (y05 AND x05))) OR (y06 AND x06)))) AND (y08 XOR x08)) OR (y08 AND x08))))))))) OR (y12 AND x12)) AND (x13 XOR y13)) OR (y13 AND x13)) AND (x14 XOR y14))
# z14 is defined as: (((y12 XOR x12) AND ((y11 AND x11) OR ((y11 XOR x11) AND ((y10 AND x10) OR ((y10 XOR x10) AND ((((((y07 AND x07) OR ((y07 XOR x07) AND (((y06 XOR x06) AND (((((x04 XOR y04) AND ((x03 AND y03) OR ((x03 XOR y03) AND ((y02 AND x02) OR ((x02 XOR y02) AND ((x01 AND y01) OR ((x01 XOR y01) AND (x00 AND y00)))))))) OR (x04 AND y04)) AND (y05 XOR x05)) OR (y05 AND x05))) OR (y06 AND x06)))) AND (y08 XOR x08)) OR (y08 AND x08)) XOR (y09 XOR x09)) OR ((y09 XOR x09) AND ((((y07 AND x07) OR ((y07 XOR x07) AND (((y06 XOR x06) AND (((((x04 XOR y04) AND ((x03 AND y03) OR ((x03 XOR y03) AND ((y02 AND x02) OR ((x02 XOR y02) AND ((x01 AND y01) OR ((x01 XOR y01) AND (x00 AND y00)))))))) OR (x04 AND y04)) AND (y05 XOR x05)) OR (y05 AND x05))) OR (y06 AND x06)))) AND (y08 XOR x08)) OR (y08 AND x08))))))))) OR (y12 AND x12)) AND (x13 XOR y13)) OR (y13 AND x13)
# z13 is defined as: (y12 XOR x12) AND ((y11 AND x11) OR ((y11 XOR x11) AND ((y10 AND x10) OR ((y10 XOR x10) AND ((((((y07 AND x07) OR ((y07 XOR x07) AND (((y06 XOR x06) AND (((((x04 XOR y04) AND ((x03 AND y03) OR ((x03 XOR y03) AND ((y02 AND x02) OR ((x02 XOR y02) AND ((x01 AND y01) OR ((x01 XOR y01) AND (x00 AND y00)))))))) OR (x04 AND y04)) AND (y05 XOR x05)) OR (y05 AND x05))) OR (y06 AND x06)))) AND (y08 XOR x08)) OR (y08 AND x08)) XOR (y09 XOR x09)) OR ((y09 XOR x09) AND ((((y07 AND x07) OR ((y07 XOR x07) AND (((y06 XOR x06) AND (((((x04 XOR y04) AND ((x03 AND y03) OR ((x03 XOR y03) AND ((y02 AND x02) OR ((x02 XOR y02) AND ((x01 AND y01) OR ((x01 XOR y01) AND (x00 AND y00)))))))) OR (x04 AND y04)) AND (y05 XOR x05)) OR (y05 AND x05))) OR (y06 AND x06)))) AND (y08 XOR x08)) OR (y08 AND x08))))))))) OR (y12 AND x12)
# z12 is defined as: y11 AND x11) OR ((y11 XOR x11) AND ((y10 AND x10) OR ((y10 XOR x10) AND ((((((y07 AND x07) OR ((y07 XOR x07) AND (((y06 XOR x06) AND (((((x04 XOR y04) AND ((x03 AND y03) OR ((x03 XOR y03) AND ((y02 AND x02) OR ((x02 XOR y02) AND ((x01 AND y01) OR ((x01 XOR y01) AND (x00 AND y00)))))))) OR (x04 AND y04)) AND (y05 XOR x05)) OR (y05 AND x05))) OR (y06 AND x06)))) AND (y08 XOR x08)) OR (y08 AND x08)) XOR (y09 XOR x09)) OR ((y09 XOR x09) AND ((((y07 AND x07) OR ((y07 XOR x07) AND (((y06 XOR x06) AND (((((x04 XOR y04) AND ((x03 AND y03) OR ((x03 XOR y03) AND ((y02 AND x02) OR ((x02 XOR y02) AND ((x01 AND y01) OR ((x01 XOR y01) AND (x00 AND y00)))))))) OR (x04 AND y04)) AND (y05 XOR x05)) OR (y05 AND x05))) OR (y06 AND x06)))) AND (y08 XOR x08)) OR (y08 AND x08)))))))
# z11 is defined as: (y10 AND x10) OR ((y10 XOR x10) AND ((((((y07 AND x07) OR ((y07 XOR x07) AND (((y06 XOR x06) AND (((((x04 XOR y04) AND ((x03 AND y03) OR ((x03 XOR y03) AND ((y02 AND x02) OR ((x02 XOR y02) AND ((x01 AND y01) OR ((x01 XOR y01) AND (x00 AND y00)))))))) OR (x04 AND y04)) AND (y05 XOR x05)) OR (y05 AND x05))) OR (y06 AND x06)))) AND (y08 XOR x08)) OR (y08 AND x08)) XOR (y09 XOR x09)) OR ((y09 XOR x09) AND ((((y07 AND x07) OR ((y07 XOR x07) AND (((y06 XOR x06) AND (((((x04 XOR y04) AND ((x03 AND y03) OR ((x03 XOR y03) AND ((y02 AND x02) OR ((x02 XOR y02) AND ((x01 AND y01) OR ((x01 XOR y01) AND (x00 AND y00)))))))) OR (x04 AND y04)) AND (y05 XOR x05)) OR (y05 AND x05))) OR (y06 AND x06)))) AND (y08 XOR x08)) OR (y08 AND x08))))
# z10 is defined as: ((((y07 AND x07) OR ((y07 XOR x07) AND (((y06 XOR x06) AND (((((x04 XOR y04) AND ((x03 AND y03) OR ((x03 XOR y03) AND ((y02 AND x02) OR ((x02 XOR y02) AND ((x01 AND y01) OR ((x01 XOR y01) AND (x00 AND y00)))))))) OR (x04 AND y04)) AND (y05 XOR x05)) OR (y05 AND x05))) OR (y06 AND x06)))) AND (y08 XOR x08)) OR (y08 AND x08)) XOR (y09 XOR x09)) OR ((y09 XOR x09) AND ((((y07 AND x07) OR ((y07 XOR x07) AND (((y06 XOR x06) AND (((((x04 XOR y04) AND ((x03 AND y03) OR ((x03 XOR y03) AND ((y02 AND x02) OR ((x02 XOR y02) AND ((x01 AND y01) OR ((x01 XOR y01) AND (x00 AND y00)))))))) OR (x04 AND y04)) AND (y05 XOR x05)) OR (y05 AND x05))) OR (y06 AND x06)))) AND (y08 XOR x08)) OR (y08 AND x08)))
# z09 is defined as:
# z08 is defined as: y07 AND x07) OR ((y07 XOR x07) AND (((y06 XOR x06) AND (((((x04 XOR y04) AND ((x03 AND y03) OR ((x03 XOR y03) AND ((y02 AND x02) OR ((x02 XOR y02) AND ((x01 AND y01) OR ((x01 XOR y01) AND (x00 AND y00)))))))) OR (x04 AND y04)) AND (y05 XOR x05)) OR (y05 AND x05))) OR (y06 AND x06)))
# z07 is defined as: ((y06 XOR x06) AND (((((x04 XOR y04) AND ((x03 AND y03) OR ((x03 XOR y03) AND ((y02 AND x02) OR ((x02 XOR y02) AND ((x01 AND y01) OR ((x01 XOR y01) AND (x00 AND y00)))))))) OR (x04 AND y04)) AND (y05 XOR x05)) OR (y05 AND x05))) OR (y06 AND x06
# z06 is defined as: ((((x04 XOR y04) AND ((x03 AND y03) OR ((x03 XOR y03) AND ((y02 AND x02) OR ((x02 XOR y02) AND ((x01 AND y01) OR ((x01 XOR y01) AND (x00 AND y00)))))))) OR (x04 AND y04)) AND (y05 XOR x05)) OR (y05 AND x05
# z05 is defined as: (x04 XOR y04) AND ((x03 AND y03) OR ((x03 XOR y03) AND ((y02 AND x02) OR ((x02 XOR y02) AND ((x01 AND y01) OR ((x01 XOR y01) AND (x00 AND y00)))))))) OR (x04 AND y04)
# z04 is defined as: (x03 AND y03) OR ((x03 XOR y03) AND ((y02 AND x02) OR ((x02 XOR y02) AND ((x01 AND y01) OR ((x01 XOR y01) AND (x00 AND y00)))))
# z03 is defined as: (y02 AND x02) OR ((x02 XOR y02) AND ((x01 AND y01) OR ((x01 XOR y01) AND (x00 AND y00)))
# z02 is defined as: x01 AND y01) OR ((x01 XOR y01) AND (x00 AND y00))
# z01 is defined as:
# z00 is defined as:

# %%
# Fix 1 pair: z09 with nnf
fixed_dict = swap_gates(gate_dict,'z09', 'nnf')
fixed_dict = swap_gates(fixed_dict,'z20', 'nhs')
fixed_dict = swap_gates(fixed_dict,'ddn', 'kqh')
fixed_dict = swap_gates(fixed_dict,'z34', 'wrc')
for output in output_list:
    print(f"{output} is defined as: {define_output_recursively(fixed_dict, output)}")
# Out:
# z45 is defined as: (((x44 XOR y44) AND (((y43 XOR x43) AND ((x42 AND y42) OR ((((((x40 XOR y40) AND (((y39 XOR x39) AND ((((((y36 AND x36) OR ((y36 XOR x36) AND (((y35 XOR x35) AND (((x34 XOR y34) AND (((x33 XOR y33) AND ((y32 AND x32) OR ((y32 XOR x32) AND ((y31 AND x31) OR ((((y30 XOR x30) AND (((x29 XOR y29) AND (((((x27 XOR y27) AND ((x26 AND y26) OR (((x25 AND y25) OR ((y25 XOR x25) AND (((y24 XOR x24) AND ((x23 AND y23) OR ((x23 XOR y23) AND ((((y21 AND x21) OR ((((((y19 XOR x19) AND ((((x17 AND y17) OR (((((((y14 AND x14) OR ((((((y12 XOR x12) AND ((y11 AND x11) OR ((y11 XOR x11) AND ((y10 AND x10) OR ((y10 XOR x10) AND ((y09 AND x09) OR ((y09 XOR x09) AND ((((y07 AND x07) OR ((y07 XOR x07) AND (((y06 XOR x06) AND (((((x04 XOR y04) AND ((x03 AND y03) OR ((x03 XOR y03) AND ((y02 AND x02) OR ((x02 XOR y02) AND ((x01 AND y01) OR ((x01 XOR y01) AND (x00 AND y00)))))))) OR (x04 AND y04)) AND (y05 XOR x05)) OR (y05 AND x05))) OR (y06 AND x06)))) AND (y08 XOR x08)) OR (y08 AND x08))))))))) OR (y12 AND x12)) AND (x13 XOR y13)) OR (y13 AND x13)) AND (x14 XOR y14))) AND (x15 XOR y15)) OR (x15 AND y15)) AND (x16 XOR y16)) OR (y16 AND x16)) AND (x17 XOR y17))) AND (y18 XOR x18)) OR (y18 AND x18))) OR (x19 AND y19)) AND (x20 XOR y20)) OR (y20 AND x20)) AND (y21 XOR x21))) AND (y22 XOR x22)) OR (x22 AND y22))))) OR (y24 AND x24)))) AND (y26 XOR x26)))) OR (y27 AND x27)) AND (y28 XOR x28)) OR (x28 AND y28))) OR (x29 AND y29))) OR (x30 AND y30)) AND (y31 XOR x31)))))) OR (y33 AND x33))) OR (x34 AND y34))) OR (y35 AND x35)))) AND (y37 XOR x37)) OR (x37 AND y37)) AND (y38 XOR x38)) OR (y38 AND x38))) OR (y39 AND x39))) OR (y40 AND x40)) AND (y41 XOR x41)) OR (y41 AND x41)) AND (x42 XOR y42)))) OR (y43 AND x43))) OR (y44 AND x44))
# z44 is defined as: ((((y43 XOR x43) AND ((x42 AND y42) OR ((((((x40 XOR y40) AND (((y39 XOR x39) AND ((((((y36 AND x36) OR ((y36 XOR x36) AND (((y35 XOR x35) AND (((x34 XOR y34) AND (((x33 XOR y33) AND ((y32 AND x32) OR ((y32 XOR x32) AND ((y31 AND x31) OR ((((y30 XOR x30) AND (((x29 XOR y29) AND (((((x27 XOR y27) AND ((x26 AND y26) OR (((x25 AND y25) OR ((y25 XOR x25) AND (((y24 XOR x24) AND ((x23 AND y23) OR ((x23 XOR y23) AND ((((y21 AND x21) OR ((((((y19 XOR x19) AND ((((x17 AND y17) OR (((((((y14 AND x14) OR ((((((y12 XOR x12) AND ((y11 AND x11) OR ((y11 XOR x11) AND ((y10 AND x10) OR ((y10 XOR x10) AND ((y09 AND x09) OR ((y09 XOR x09) AND ((((y07 AND x07) OR ((y07 XOR x07) AND (((y06 XOR x06) AND (((((x04 XOR y04) AND ((x03 AND y03) OR ((x03 XOR y03) AND ((y02 AND x02) OR ((x02 XOR y02) AND ((x01 AND y01) OR ((x01 XOR y01) AND (x00 AND y00)))))))) OR (x04 AND y04)) AND (y05 XOR x05)) OR (y05 AND x05))) OR (y06 AND x06)))) AND (y08 XOR x08)) OR (y08 AND x08))))))))) OR (y12 AND x12)) AND (x13 XOR y13)) OR (y13 AND x13)) AND (x14 XOR y14))) AND (x15 XOR y15)) OR (x15 AND y15)) AND (x16 XOR y16)) OR (y16 AND x16)) AND (x17 XOR y17))) AND (y18 XOR x18)) OR (y18 AND x18))) OR (x19 AND y19)) AND (x20 XOR y20)) OR (y20 AND x20)) AND (y21 XOR x21))) AND (y22 XOR x22)) OR (x22 AND y22))))) OR (y24 AND x24)))) AND (y26 XOR x26)))) OR (y27 AND x27)) AND (y28 XOR x28)) OR (x28 AND y28))) OR (x29 AND y29))) OR (x30 AND y30)) AND (y31 XOR x31)))))) OR (y33 AND x33))) OR (x34 AND y34))) OR (y35 AND x35)))) AND (y37 XOR x37)) OR (x37 AND y37)) AND (y38 XOR x38)) OR (y38 AND x38))) OR (y39 AND x39))) OR (y40 AND x40)) AND (y41 XOR x41)) OR (y41 AND x41)) AND (x42 XOR y42)))) OR (y43 AND x43)) XOR (x44 XOR y44))
# z43 is defined as: ((y43 XOR x43) XOR ((x42 AND y42) OR ((((((x40 XOR y40) AND (((y39 XOR x39) AND ((((((y36 AND x36) OR ((y36 XOR x36) AND (((y35 XOR x35) AND (((x34 XOR y34) AND (((x33 XOR y33) AND ((y32 AND x32) OR ((y32 XOR x32) AND ((y31 AND x31) OR ((((y30 XOR x30) AND (((x29 XOR y29) AND (((((x27 XOR y27) AND ((x26 AND y26) OR (((x25 AND y25) OR ((y25 XOR x25) AND (((y24 XOR x24) AND ((x23 AND y23) OR ((x23 XOR y23) AND ((((y21 AND x21) OR ((((((y19 XOR x19) AND ((((x17 AND y17) OR (((((((y14 AND x14) OR ((((((y12 XOR x12) AND ((y11 AND x11) OR ((y11 XOR x11) AND ((y10 AND x10) OR ((y10 XOR x10) AND ((y09 AND x09) OR ((y09 XOR x09) AND ((((y07 AND x07) OR ((y07 XOR x07) AND (((y06 XOR x06) AND (((((x04 XOR y04) AND ((x03 AND y03) OR ((x03 XOR y03) AND ((y02 AND x02) OR ((x02 XOR y02) AND ((x01 AND y01) OR ((x01 XOR y01) AND (x00 AND y00)))))))) OR (x04 AND y04)) AND (y05 XOR x05)) OR (y05 AND x05))) OR (y06 AND x06)))) AND (y08 XOR x08)) OR (y08 AND x08))))))))) OR (y12 AND x12)) AND (x13 XOR y13)) OR (y13 AND x13)) AND (x14 XOR y14))) AND (x15 XOR y15)) OR (x15 AND y15)) AND (x16 XOR y16)) OR (y16 AND x16)) AND (x17 XOR y17))) AND (y18 XOR x18)) OR (y18 AND x18))) OR (x19 AND y19)) AND (x20 XOR y20)) OR (y20 AND x20)) AND (y21 XOR x21))) AND (y22 XOR x22)) OR (x22 AND y22))))) OR (y24 AND x24)))) AND (y26 XOR x26)))) OR (y27 AND x27)) AND (y28 XOR x28)) OR (x28 AND y28))) OR (x29 AND y29))) OR (x30 AND y30)) AND (y31 XOR x31)))))) OR (y33 AND x33))) OR (x34 AND y34))) OR (y35 AND x35)))) AND (y37 XOR x37)) OR (x37 AND y37)) AND (y38 XOR x38)) OR (y38 AND x38))) OR (y39 AND x39))) OR (y40 AND x40)) AND (y41 XOR x41)) OR (y41 AND x41)) AND (x42 XOR y42))))
# z42 is defined as: ((x42 XOR y42) XOR (((((x40 XOR y40) AND (((y39 XOR x39) AND ((((((y36 AND x36) OR ((y36 XOR x36) AND (((y35 XOR x35) AND (((x34 XOR y34) AND (((x33 XOR y33) AND ((y32 AND x32) OR ((y32 XOR x32) AND ((y31 AND x31) OR ((((y30 XOR x30) AND (((x29 XOR y29) AND (((((x27 XOR y27) AND ((x26 AND y26) OR (((x25 AND y25) OR ((y25 XOR x25) AND (((y24 XOR x24) AND ((x23 AND y23) OR ((x23 XOR y23) AND ((((y21 AND x21) OR ((((((y19 XOR x19) AND ((((x17 AND y17) OR (((((((y14 AND x14) OR ((((((y12 XOR x12) AND ((y11 AND x11) OR ((y11 XOR x11) AND ((y10 AND x10) OR ((y10 XOR x10) AND ((y09 AND x09) OR ((y09 XOR x09) AND ((((y07 AND x07) OR ((y07 XOR x07) AND (((y06 XOR x06) AND (((((x04 XOR y04) AND ((x03 AND y03) OR ((x03 XOR y03) AND ((y02 AND x02) OR ((x02 XOR y02) AND ((x01 AND y01) OR ((x01 XOR y01) AND (x00 AND y00)))))))) OR (x04 AND y04)) AND (y05 XOR x05)) OR (y05 AND x05))) OR (y06 AND x06)))) AND (y08 XOR x08)) OR (y08 AND x08))))))))) OR (y12 AND x12)) AND (x13 XOR y13)) OR (y13 AND x13)) AND (x14 XOR y14))) AND (x15 XOR y15)) OR (x15 AND y15)) AND (x16 XOR y16)) OR (y16 AND x16)) AND (x17 XOR y17))) AND (y18 XOR x18)) OR (y18 AND x18))) OR (x19 AND y19)) AND (x20 XOR y20)) OR (y20 AND x20)) AND (y21 XOR x21))) AND (y22 XOR x22)) OR (x22 AND y22))))) OR (y24 AND x24)))) AND (y26 XOR x26)))) OR (y27 AND x27)) AND (y28 XOR x28)) OR (x28 AND y28))) OR (x29 AND y29))) OR (x30 AND y30)) AND (y31 XOR x31)))))) OR (y33 AND x33))) OR (x34 AND y34))) OR (y35 AND x35)))) AND (y37 XOR x37)) OR (x37 AND y37)) AND (y38 XOR x38)) OR (y38 AND x38))) OR (y39 AND x39))) OR (y40 AND x40)) AND (y41 XOR x41)) OR (y41 AND x41)))
# z41 is defined as: ((((x40 XOR y40) AND (((y39 XOR x39) AND ((((((y36 AND x36) OR ((y36 XOR x36) AND (((y35 XOR x35) AND (((x34 XOR y34) AND (((x33 XOR y33) AND ((y32 AND x32) OR ((y32 XOR x32) AND ((y31 AND x31) OR ((((y30 XOR x30) AND (((x29 XOR y29) AND (((((x27 XOR y27) AND ((x26 AND y26) OR (((x25 AND y25) OR ((y25 XOR x25) AND (((y24 XOR x24) AND ((x23 AND y23) OR ((x23 XOR y23) AND ((((y21 AND x21) OR ((((((y19 XOR x19) AND ((((x17 AND y17) OR (((((((y14 AND x14) OR ((((((y12 XOR x12) AND ((y11 AND x11) OR ((y11 XOR x11) AND ((y10 AND x10) OR ((y10 XOR x10) AND ((y09 AND x09) OR ((y09 XOR x09) AND ((((y07 AND x07) OR ((y07 XOR x07) AND (((y06 XOR x06) AND (((((x04 XOR y04) AND ((x03 AND y03) OR ((x03 XOR y03) AND ((y02 AND x02) OR ((x02 XOR y02) AND ((x01 AND y01) OR ((x01 XOR y01) AND (x00 AND y00)))))))) OR (x04 AND y04)) AND (y05 XOR x05)) OR (y05 AND x05))) OR (y06 AND x06)))) AND (y08 XOR x08)) OR (y08 AND x08))))))))) OR (y12 AND x12)) AND (x13 XOR y13)) OR (y13 AND x13)) AND (x14 XOR y14))) AND (x15 XOR y15)) OR (x15 AND y15)) AND (x16 XOR y16)) OR (y16 AND x16)) AND (x17 XOR y17))) AND (y18 XOR x18)) OR (y18 AND x18))) OR (x19 AND y19)) AND (x20 XOR y20)) OR (y20 AND x20)) AND (y21 XOR x21))) AND (y22 XOR x22)) OR (x22 AND y22))))) OR (y24 AND x24)))) AND (y26 XOR x26)))) OR (y27 AND x27)) AND (y28 XOR x28)) OR (x28 AND y28))) OR (x29 AND y29))) OR (x30 AND y30)) AND (y31 XOR x31)))))) OR (y33 AND x33))) OR (x34 AND y34))) OR (y35 AND x35)))) AND (y37 XOR x37)) OR (x37 AND y37)) AND (y38 XOR x38)) OR (y38 AND x38))) OR (y39 AND x39))) OR (y40 AND x40)) XOR (y41 XOR x41))
# z40 is defined as: ((x40 XOR y40) XOR (((y39 XOR x39) AND ((((((y36 AND x36) OR ((y36 XOR x36) AND (((y35 XOR x35) AND (((x34 XOR y34) AND (((x33 XOR y33) AND ((y32 AND x32) OR ((y32 XOR x32) AND ((y31 AND x31) OR ((((y30 XOR x30) AND (((x29 XOR y29) AND (((((x27 XOR y27) AND ((x26 AND y26) OR (((x25 AND y25) OR ((y25 XOR x25) AND (((y24 XOR x24) AND ((x23 AND y23) OR ((x23 XOR y23) AND ((((y21 AND x21) OR ((((((y19 XOR x19) AND ((((x17 AND y17) OR (((((((y14 AND x14) OR ((((((y12 XOR x12) AND ((y11 AND x11) OR ((y11 XOR x11) AND ((y10 AND x10) OR ((y10 XOR x10) AND ((y09 AND x09) OR ((y09 XOR x09) AND ((((y07 AND x07) OR ((y07 XOR x07) AND (((y06 XOR x06) AND (((((x04 XOR y04) AND ((x03 AND y03) OR ((x03 XOR y03) AND ((y02 AND x02) OR ((x02 XOR y02) AND ((x01 AND y01) OR ((x01 XOR y01) AND (x00 AND y00)))))))) OR (x04 AND y04)) AND (y05 XOR x05)) OR (y05 AND x05))) OR (y06 AND x06)))) AND (y08 XOR x08)) OR (y08 AND x08))))))))) OR (y12 AND x12)) AND (x13 XOR y13)) OR (y13 AND x13)) AND (x14 XOR y14))) AND (x15 XOR y15)) OR (x15 AND y15)) AND (x16 XOR y16)) OR (y16 AND x16)) AND (x17 XOR y17))) AND (y18 XOR x18)) OR (y18 AND x18))) OR (x19 AND y19)) AND (x20 XOR y20)) OR (y20 AND x20)) AND (y21 XOR x21))) AND (y22 XOR x22)) OR (x22 AND y22))))) OR (y24 AND x24)))) AND (y26 XOR x26)))) OR (y27 AND x27)) AND (y28 XOR x28)) OR (x28 AND y28))) OR (x29 AND y29))) OR (x30 AND y30)) AND (y31 XOR x31)))))) OR (y33 AND x33))) OR (x34 AND y34))) OR (y35 AND x35)))) AND (y37 XOR x37)) OR (x37 AND y37)) AND (y38 XOR x38)) OR (y38 AND x38))) OR (y39 AND x39)))
# z39 is defined as: ((y39 XOR x39) XOR ((((((y36 AND x36) OR ((y36 XOR x36) AND (((y35 XOR x35) AND (((x34 XOR y34) AND (((x33 XOR y33) AND ((y32 AND x32) OR ((y32 XOR x32) AND ((y31 AND x31) OR ((((y30 XOR x30) AND (((x29 XOR y29) AND (((((x27 XOR y27) AND ((x26 AND y26) OR (((x25 AND y25) OR ((y25 XOR x25) AND (((y24 XOR x24) AND ((x23 AND y23) OR ((x23 XOR y23) AND ((((y21 AND x21) OR ((((((y19 XOR x19) AND ((((x17 AND y17) OR (((((((y14 AND x14) OR ((((((y12 XOR x12) AND ((y11 AND x11) OR ((y11 XOR x11) AND ((y10 AND x10) OR ((y10 XOR x10) AND ((y09 AND x09) OR ((y09 XOR x09) AND ((((y07 AND x07) OR ((y07 XOR x07) AND (((y06 XOR x06) AND (((((x04 XOR y04) AND ((x03 AND y03) OR ((x03 XOR y03) AND ((y02 AND x02) OR ((x02 XOR y02) AND ((x01 AND y01) OR ((x01 XOR y01) AND (x00 AND y00)))))))) OR (x04 AND y04)) AND (y05 XOR x05)) OR (y05 AND x05))) OR (y06 AND x06)))) AND (y08 XOR x08)) OR (y08 AND x08))))))))) OR (y12 AND x12)) AND (x13 XOR y13)) OR (y13 AND x13)) AND (x14 XOR y14))) AND (x15 XOR y15)) OR (x15 AND y15)) AND (x16 XOR y16)) OR (y16 AND x16)) AND (x17 XOR y17))) AND (y18 XOR x18)) OR (y18 AND x18))) OR (x19 AND y19)) AND (x20 XOR y20)) OR (y20 AND x20)) AND (y21 XOR x21))) AND (y22 XOR x22)) OR (x22 AND y22))))) OR (y24 AND x24)))) AND (y26 XOR x26)))) OR (y27 AND x27)) AND (y28 XOR x28)) OR (x28 AND y28))) OR (x29 AND y29))) OR (x30 AND y30)) AND (y31 XOR x31)))))) OR (y33 AND x33))) OR (x34 AND y34))) OR (y35 AND x35)))) AND (y37 XOR x37)) OR (x37 AND y37)) AND (y38 XOR x38)) OR (y38 AND x38)))
# z38 is defined as: (((((y36 AND x36) OR ((y36 XOR x36) AND (((y35 XOR x35) AND (((x34 XOR y34) AND (((x33 XOR y33) AND ((y32 AND x32) OR ((y32 XOR x32) AND ((y31 AND x31) OR ((((y30 XOR x30) AND (((x29 XOR y29) AND (((((x27 XOR y27) AND ((x26 AND y26) OR (((x25 AND y25) OR ((y25 XOR x25) AND (((y24 XOR x24) AND ((x23 AND y23) OR ((x23 XOR y23) AND ((((y21 AND x21) OR ((((((y19 XOR x19) AND ((((x17 AND y17) OR (((((((y14 AND x14) OR ((((((y12 XOR x12) AND ((y11 AND x11) OR ((y11 XOR x11) AND ((y10 AND x10) OR ((y10 XOR x10) AND ((y09 AND x09) OR ((y09 XOR x09) AND ((((y07 AND x07) OR ((y07 XOR x07) AND (((y06 XOR x06) AND (((((x04 XOR y04) AND ((x03 AND y03) OR ((x03 XOR y03) AND ((y02 AND x02) OR ((x02 XOR y02) AND ((x01 AND y01) OR ((x01 XOR y01) AND (x00 AND y00)))))))) OR (x04 AND y04)) AND (y05 XOR x05)) OR (y05 AND x05))) OR (y06 AND x06)))) AND (y08 XOR x08)) OR (y08 AND x08))))))))) OR (y12 AND x12)) AND (x13 XOR y13)) OR (y13 AND x13)) AND (x14 XOR y14))) AND (x15 XOR y15)) OR (x15 AND y15)) AND (x16 XOR y16)) OR (y16 AND x16)) AND (x17 XOR y17))) AND (y18 XOR x18)) OR (y18 AND x18))) OR (x19 AND y19)) AND (x20 XOR y20)) OR (y20 AND x20)) AND (y21 XOR x21))) AND (y22 XOR x22)) OR (x22 AND y22))))) OR (y24 AND x24)))) AND (y26 XOR x26)))) OR (y27 AND x27)) AND (y28 XOR x28)) OR (x28 AND y28))) OR (x29 AND y29))) OR (x30 AND y30)) AND (y31 XOR x31)))))) OR (y33 AND x33))) OR (x34 AND y34))) OR (y35 AND x35)))) AND (y37 XOR x37)) OR (x37 AND y37)) XOR (y38 XOR x38))
# z37 is defined as: ((y37 XOR x37) XOR ((y36 AND x36) OR ((y36 XOR x36) AND (((y35 XOR x35) AND (((x34 XOR y34) AND (((x33 XOR y33) AND ((y32 AND x32) OR ((y32 XOR x32) AND ((y31 AND x31) OR ((((y30 XOR x30) AND (((x29 XOR y29) AND (((((x27 XOR y27) AND ((x26 AND y26) OR (((x25 AND y25) OR ((y25 XOR x25) AND (((y24 XOR x24) AND ((x23 AND y23) OR ((x23 XOR y23) AND ((((y21 AND x21) OR ((((((y19 XOR x19) AND ((((x17 AND y17) OR (((((((y14 AND x14) OR ((((((y12 XOR x12) AND ((y11 AND x11) OR ((y11 XOR x11) AND ((y10 AND x10) OR ((y10 XOR x10) AND ((y09 AND x09) OR ((y09 XOR x09) AND ((((y07 AND x07) OR ((y07 XOR x07) AND (((y06 XOR x06) AND (((((x04 XOR y04) AND ((x03 AND y03) OR ((x03 XOR y03) AND ((y02 AND x02) OR ((x02 XOR y02) AND ((x01 AND y01) OR ((x01 XOR y01) AND (x00 AND y00)))))))) OR (x04 AND y04)) AND (y05 XOR x05)) OR (y05 AND x05))) OR (y06 AND x06)))) AND (y08 XOR x08)) OR (y08 AND x08))))))))) OR (y12 AND x12)) AND (x13 XOR y13)) OR (y13 AND x13)) AND (x14 XOR y14))) AND (x15 XOR y15)) OR (x15 AND y15)) AND (x16 XOR y16)) OR (y16 AND x16)) AND (x17 XOR y17))) AND (y18 XOR x18)) OR (y18 AND x18))) OR (x19 AND y19)) AND (x20 XOR y20)) OR (y20 AND x20)) AND (y21 XOR x21))) AND (y22 XOR x22)) OR (x22 AND y22))))) OR (y24 AND x24)))) AND (y26 XOR x26)))) OR (y27 AND x27)) AND (y28 XOR x28)) OR (x28 AND y28))) OR (x29 AND y29))) OR (x30 AND y30)) AND (y31 XOR x31)))))) OR (y33 AND x33))) OR (x34 AND y34))) OR (y35 AND x35)))))
# z36 is defined as: ((y36 XOR x36) XOR (((y35 XOR x35) AND (((x34 XOR y34) AND (((x33 XOR y33) AND ((y32 AND x32) OR ((y32 XOR x32) AND ((y31 AND x31) OR ((((y30 XOR x30) AND (((x29 XOR y29) AND (((((x27 XOR y27) AND ((x26 AND y26) OR (((x25 AND y25) OR ((y25 XOR x25) AND (((y24 XOR x24) AND ((x23 AND y23) OR ((x23 XOR y23) AND ((((y21 AND x21) OR ((((((y19 XOR x19) AND ((((x17 AND y17) OR (((((((y14 AND x14) OR ((((((y12 XOR x12) AND ((y11 AND x11) OR ((y11 XOR x11) AND ((y10 AND x10) OR ((y10 XOR x10) AND ((y09 AND x09) OR ((y09 XOR x09) AND ((((y07 AND x07) OR ((y07 XOR x07) AND (((y06 XOR x06) AND (((((x04 XOR y04) AND ((x03 AND y03) OR ((x03 XOR y03) AND ((y02 AND x02) OR ((x02 XOR y02) AND ((x01 AND y01) OR ((x01 XOR y01) AND (x00 AND y00)))))))) OR (x04 AND y04)) AND (y05 XOR x05)) OR (y05 AND x05))) OR (y06 AND x06)))) AND (y08 XOR x08)) OR (y08 AND x08))))))))) OR (y12 AND x12)) AND (x13 XOR y13)) OR (y13 AND x13)) AND (x14 XOR y14))) AND (x15 XOR y15)) OR (x15 AND y15)) AND (x16 XOR y16)) OR (y16 AND x16)) AND (x17 XOR y17))) AND (y18 XOR x18)) OR (y18 AND x18))) OR (x19 AND y19)) AND (x20 XOR y20)) OR (y20 AND x20)) AND (y21 XOR x21))) AND (y22 XOR x22)) OR (x22 AND y22))))) OR (y24 AND x24)))) AND (y26 XOR x26)))) OR (y27 AND x27)) AND (y28 XOR x28)) OR (x28 AND y28))) OR (x29 AND y29))) OR (x30 AND y30)) AND (y31 XOR x31)))))) OR (y33 AND x33))) OR (x34 AND y34))) OR (y35 AND x35)))
# z35 is defined as: ((((x34 XOR y34) AND (((x33 XOR y33) AND ((y32 AND x32) OR ((y32 XOR x32) AND ((y31 AND x31) OR ((((y30 XOR x30) AND (((x29 XOR y29) AND (((((x27 XOR y27) AND ((x26 AND y26) OR (((x25 AND y25) OR ((y25 XOR x25) AND (((y24 XOR x24) AND ((x23 AND y23) OR ((x23 XOR y23) AND ((((y21 AND x21) OR ((((((y19 XOR x19) AND ((((x17 AND y17) OR (((((((y14 AND x14) OR ((((((y12 XOR x12) AND ((y11 AND x11) OR ((y11 XOR x11) AND ((y10 AND x10) OR ((y10 XOR x10) AND ((y09 AND x09) OR ((y09 XOR x09) AND ((((y07 AND x07) OR ((y07 XOR x07) AND (((y06 XOR x06) AND (((((x04 XOR y04) AND ((x03 AND y03) OR ((x03 XOR y03) AND ((y02 AND x02) OR ((x02 XOR y02) AND ((x01 AND y01) OR ((x01 XOR y01) AND (x00 AND y00)))))))) OR (x04 AND y04)) AND (y05 XOR x05)) OR (y05 AND x05))) OR (y06 AND x06)))) AND (y08 XOR x08)) OR (y08 AND x08))))))))) OR (y12 AND x12)) AND (x13 XOR y13)) OR (y13 AND x13)) AND (x14 XOR y14))) AND (x15 XOR y15)) OR (x15 AND y15)) AND (x16 XOR y16)) OR (y16 AND x16)) AND (x17 XOR y17))) AND (y18 XOR x18)) OR (y18 AND x18))) OR (x19 AND y19)) AND (x20 XOR y20)) OR (y20 AND x20)) AND (y21 XOR x21))) AND (y22 XOR x22)) OR (x22 AND y22))))) OR (y24 AND x24)))) AND (y26 XOR x26)))) OR (y27 AND x27)) AND (y28 XOR x28)) OR (x28 AND y28))) OR (x29 AND y29))) OR (x30 AND y30)) AND (y31 XOR x31)))))) OR (y33 AND x33))) OR (x34 AND y34)) XOR (y35 XOR x35))
# z34 is defined as: ((((x33 XOR y33) AND ((y32 AND x32) OR ((y32 XOR x32) AND ((y31 AND x31) OR ((((y30 XOR x30) AND (((x29 XOR y29) AND (((((x27 XOR y27) AND ((x26 AND y26) OR (((x25 AND y25) OR ((y25 XOR x25) AND (((y24 XOR x24) AND ((x23 AND y23) OR ((x23 XOR y23) AND ((((y21 AND x21) OR ((((((y19 XOR x19) AND ((((x17 AND y17) OR (((((((y14 AND x14) OR ((((((y12 XOR x12) AND ((y11 AND x11) OR ((y11 XOR x11) AND ((y10 AND x10) OR ((y10 XOR x10) AND ((y09 AND x09) OR ((y09 XOR x09) AND ((((y07 AND x07) OR ((y07 XOR x07) AND (((y06 XOR x06) AND (((((x04 XOR y04) AND ((x03 AND y03) OR ((x03 XOR y03) AND ((y02 AND x02) OR ((x02 XOR y02) AND ((x01 AND y01) OR ((x01 XOR y01) AND (x00 AND y00)))))))) OR (x04 AND y04)) AND (y05 XOR x05)) OR (y05 AND x05))) OR (y06 AND x06)))) AND (y08 XOR x08)) OR (y08 AND x08))))))))) OR (y12 AND x12)) AND (x13 XOR y13)) OR (y13 AND x13)) AND (x14 XOR y14))) AND (x15 XOR y15)) OR (x15 AND y15)) AND (x16 XOR y16)) OR (y16 AND x16)) AND (x17 XOR y17))) AND (y18 XOR x18)) OR (y18 AND x18))) OR (x19 AND y19)) AND (x20 XOR y20)) OR (y20 AND x20)) AND (y21 XOR x21))) AND (y22 XOR x22)) OR (x22 AND y22))))) OR (y24 AND x24)))) AND (y26 XOR x26)))) OR (y27 AND x27)) AND (y28 XOR x28)) OR (x28 AND y28))) OR (x29 AND y29))) OR (x30 AND y30)) AND (y31 XOR x31)))))) OR (y33 AND x33)) XOR (x34 XOR y34))
# z33 is defined as: (((y32 AND x32) OR ((y32 XOR x32) AND ((y31 AND x31) OR ((((y30 XOR x30) AND (((x29 XOR y29) AND (((((x27 XOR y27) AND ((x26 AND y26) OR (((x25 AND y25) OR ((y25 XOR x25) AND (((y24 XOR x24) AND ((x23 AND y23) OR ((x23 XOR y23) AND ((((y21 AND x21) OR ((((((y19 XOR x19) AND ((((x17 AND y17) OR (((((((y14 AND x14) OR ((((((y12 XOR x12) AND ((y11 AND x11) OR ((y11 XOR x11) AND ((y10 AND x10) OR ((y10 XOR x10) AND ((y09 AND x09) OR ((y09 XOR x09) AND ((((y07 AND x07) OR ((y07 XOR x07) AND (((y06 XOR x06) AND (((((x04 XOR y04) AND ((x03 AND y03) OR ((x03 XOR y03) AND ((y02 AND x02) OR ((x02 XOR y02) AND ((x01 AND y01) OR ((x01 XOR y01) AND (x00 AND y00)))))))) OR (x04 AND y04)) AND (y05 XOR x05)) OR (y05 AND x05))) OR (y06 AND x06)))) AND (y08 XOR x08)) OR (y08 AND x08))))))))) OR (y12 AND x12)) AND (x13 XOR y13)) OR (y13 AND x13)) AND (x14 XOR y14))) AND (x15 XOR y15)) OR (x15 AND y15)) AND (x16 XOR y16)) OR (y16 AND x16)) AND (x17 XOR y17))) AND (y18 XOR x18)) OR (y18 AND x18))) OR (x19 AND y19)) AND (x20 XOR y20)) OR (y20 AND x20)) AND (y21 XOR x21))) AND (y22 XOR x22)) OR (x22 AND y22))))) OR (y24 AND x24)))) AND (y26 XOR x26)))) OR (y27 AND x27)) AND (y28 XOR x28)) OR (x28 AND y28))) OR (x29 AND y29))) OR (x30 AND y30)) AND (y31 XOR x31))))) XOR (x33 XOR y33))
# z32 is defined as: (((y31 AND x31) OR ((((y30 XOR x30) AND (((x29 XOR y29) AND (((((x27 XOR y27) AND ((x26 AND y26) OR (((x25 AND y25) OR ((y25 XOR x25) AND (((y24 XOR x24) AND ((x23 AND y23) OR ((x23 XOR y23) AND ((((y21 AND x21) OR ((((((y19 XOR x19) AND ((((x17 AND y17) OR (((((((y14 AND x14) OR ((((((y12 XOR x12) AND ((y11 AND x11) OR ((y11 XOR x11) AND ((y10 AND x10) OR ((y10 XOR x10) AND ((y09 AND x09) OR ((y09 XOR x09) AND ((((y07 AND x07) OR ((y07 XOR x07) AND (((y06 XOR x06) AND (((((x04 XOR y04) AND ((x03 AND y03) OR ((x03 XOR y03) AND ((y02 AND x02) OR ((x02 XOR y02) AND ((x01 AND y01) OR ((x01 XOR y01) AND (x00 AND y00)))))))) OR (x04 AND y04)) AND (y05 XOR x05)) OR (y05 AND x05))) OR (y06 AND x06)))) AND (y08 XOR x08)) OR (y08 AND x08))))))))) OR (y12 AND x12)) AND (x13 XOR y13)) OR (y13 AND x13)) AND (x14 XOR y14))) AND (x15 XOR y15)) OR (x15 AND y15)) AND (x16 XOR y16)) OR (y16 AND x16)) AND (x17 XOR y17))) AND (y18 XOR x18)) OR (y18 AND x18))) OR (x19 AND y19)) AND (x20 XOR y20)) OR (y20 AND x20)) AND (y21 XOR x21))) AND (y22 XOR x22)) OR (x22 AND y22))))) OR (y24 AND x24)))) AND (y26 XOR x26)))) OR (y27 AND x27)) AND (y28 XOR x28)) OR (x28 AND y28))) OR (x29 AND y29))) OR (x30 AND y30)) AND (y31 XOR x31))) XOR (y32 XOR x32))
# z31 is defined as: ((y31 XOR x31) XOR (((y30 XOR x30) AND (((x29 XOR y29) AND (((((x27 XOR y27) AND ((x26 AND y26) OR (((x25 AND y25) OR ((y25 XOR x25) AND (((y24 XOR x24) AND ((x23 AND y23) OR ((x23 XOR y23) AND ((((y21 AND x21) OR ((((((y19 XOR x19) AND ((((x17 AND y17) OR (((((((y14 AND x14) OR ((((((y12 XOR x12) AND ((y11 AND x11) OR ((y11 XOR x11) AND ((y10 AND x10) OR ((y10 XOR x10) AND ((y09 AND x09) OR ((y09 XOR x09) AND ((((y07 AND x07) OR ((y07 XOR x07) AND (((y06 XOR x06) AND (((((x04 XOR y04) AND ((x03 AND y03) OR ((x03 XOR y03) AND ((y02 AND x02) OR ((x02 XOR y02) AND ((x01 AND y01) OR ((x01 XOR y01) AND (x00 AND y00)))))))) OR (x04 AND y04)) AND (y05 XOR x05)) OR (y05 AND x05))) OR (y06 AND x06)))) AND (y08 XOR x08)) OR (y08 AND x08))))))))) OR (y12 AND x12)) AND (x13 XOR y13)) OR (y13 AND x13)) AND (x14 XOR y14))) AND (x15 XOR y15)) OR (x15 AND y15)) AND (x16 XOR y16)) OR (y16 AND x16)) AND (x17 XOR y17))) AND (y18 XOR x18)) OR (y18 AND x18))) OR (x19 AND y19)) AND (x20 XOR y20)) OR (y20 AND x20)) AND (y21 XOR x21))) AND (y22 XOR x22)) OR (x22 AND y22))))) OR (y24 AND x24)))) AND (y26 XOR x26)))) OR (y27 AND x27)) AND (y28 XOR x28)) OR (x28 AND y28))) OR (x29 AND y29))) OR (x30 AND y30)))
# z30 is defined as: ((((x29 XOR y29) AND (((((x27 XOR y27) AND ((x26 AND y26) OR (((x25 AND y25) OR ((y25 XOR x25) AND (((y24 XOR x24) AND ((x23 AND y23) OR ((x23 XOR y23) AND ((((y21 AND x21) OR ((((((y19 XOR x19) AND ((((x17 AND y17) OR (((((((y14 AND x14) OR ((((((y12 XOR x12) AND ((y11 AND x11) OR ((y11 XOR x11) AND ((y10 AND x10) OR ((y10 XOR x10) AND ((y09 AND x09) OR ((y09 XOR x09) AND ((((y07 AND x07) OR ((y07 XOR x07) AND (((y06 XOR x06) AND (((((x04 XOR y04) AND ((x03 AND y03) OR ((x03 XOR y03) AND ((y02 AND x02) OR ((x02 XOR y02) AND ((x01 AND y01) OR ((x01 XOR y01) AND (x00 AND y00)))))))) OR (x04 AND y04)) AND (y05 XOR x05)) OR (y05 AND x05))) OR (y06 AND x06)))) AND (y08 XOR x08)) OR (y08 AND x08))))))))) OR (y12 AND x12)) AND (x13 XOR y13)) OR (y13 AND x13)) AND (x14 XOR y14))) AND (x15 XOR y15)) OR (x15 AND y15)) AND (x16 XOR y16)) OR (y16 AND x16)) AND (x17 XOR y17))) AND (y18 XOR x18)) OR (y18 AND x18))) OR (x19 AND y19)) AND (x20 XOR y20)) OR (y20 AND x20)) AND (y21 XOR x21))) AND (y22 XOR x22)) OR (x22 AND y22))))) OR (y24 AND x24)))) AND (y26 XOR x26)))) OR (y27 AND x27)) AND (y28 XOR x28)) OR (x28 AND y28))) OR (x29 AND y29)) XOR (y30 XOR x30))
# z29 is defined as: ((((((x27 XOR y27) AND ((x26 AND y26) OR (((x25 AND y25) OR ((y25 XOR x25) AND (((y24 XOR x24) AND ((x23 AND y23) OR ((x23 XOR y23) AND ((((y21 AND x21) OR ((((((y19 XOR x19) AND ((((x17 AND y17) OR (((((((y14 AND x14) OR ((((((y12 XOR x12) AND ((y11 AND x11) OR ((y11 XOR x11) AND ((y10 AND x10) OR ((y10 XOR x10) AND ((y09 AND x09) OR ((y09 XOR x09) AND ((((y07 AND x07) OR ((y07 XOR x07) AND (((y06 XOR x06) AND (((((x04 XOR y04) AND ((x03 AND y03) OR ((x03 XOR y03) AND ((y02 AND x02) OR ((x02 XOR y02) AND ((x01 AND y01) OR ((x01 XOR y01) AND (x00 AND y00)))))))) OR (x04 AND y04)) AND (y05 XOR x05)) OR (y05 AND x05))) OR (y06 AND x06)))) AND (y08 XOR x08)) OR (y08 AND x08))))))))) OR (y12 AND x12)) AND (x13 XOR y13)) OR (y13 AND x13)) AND (x14 XOR y14))) AND (x15 XOR y15)) OR (x15 AND y15)) AND (x16 XOR y16)) OR (y16 AND x16)) AND (x17 XOR y17))) AND (y18 XOR x18)) OR (y18 AND x18))) OR (x19 AND y19)) AND (x20 XOR y20)) OR (y20 AND x20)) AND (y21 XOR x21))) AND (y22 XOR x22)) OR (x22 AND y22))))) OR (y24 AND x24)))) AND (y26 XOR x26)))) OR (y27 AND x27)) AND (y28 XOR x28)) OR (x28 AND y28)) XOR (x29 XOR y29))
# z28 is defined as: ((((x27 XOR y27) AND ((x26 AND y26) OR (((x25 AND y25) OR ((y25 XOR x25) AND (((y24 XOR x24) AND ((x23 AND y23) OR ((x23 XOR y23) AND ((((y21 AND x21) OR ((((((y19 XOR x19) AND ((((x17 AND y17) OR (((((((y14 AND x14) OR ((((((y12 XOR x12) AND ((y11 AND x11) OR ((y11 XOR x11) AND ((y10 AND x10) OR ((y10 XOR x10) AND ((y09 AND x09) OR ((y09 XOR x09) AND ((((y07 AND x07) OR ((y07 XOR x07) AND (((y06 XOR x06) AND (((((x04 XOR y04) AND ((x03 AND y03) OR ((x03 XOR y03) AND ((y02 AND x02) OR ((x02 XOR y02) AND ((x01 AND y01) OR ((x01 XOR y01) AND (x00 AND y00)))))))) OR (x04 AND y04)) AND (y05 XOR x05)) OR (y05 AND x05))) OR (y06 AND x06)))) AND (y08 XOR x08)) OR (y08 AND x08))))))))) OR (y12 AND x12)) AND (x13 XOR y13)) OR (y13 AND x13)) AND (x14 XOR y14))) AND (x15 XOR y15)) OR (x15 AND y15)) AND (x16 XOR y16)) OR (y16 AND x16)) AND (x17 XOR y17))) AND (y18 XOR x18)) OR (y18 AND x18))) OR (x19 AND y19)) AND (x20 XOR y20)) OR (y20 AND x20)) AND (y21 XOR x21))) AND (y22 XOR x22)) OR (x22 AND y22))))) OR (y24 AND x24)))) AND (y26 XOR x26)))) OR (y27 AND x27)) XOR (y28 XOR x28))
# z27 is defined as: ((x27 XOR y27) XOR ((x26 AND y26) OR (((x25 AND y25) OR ((y25 XOR x25) AND (((y24 XOR x24) AND ((x23 AND y23) OR ((x23 XOR y23) AND ((((y21 AND x21) OR ((((((y19 XOR x19) AND ((((x17 AND y17) OR (((((((y14 AND x14) OR ((((((y12 XOR x12) AND ((y11 AND x11) OR ((y11 XOR x11) AND ((y10 AND x10) OR ((y10 XOR x10) AND ((y09 AND x09) OR ((y09 XOR x09) AND ((((y07 AND x07) OR ((y07 XOR x07) AND (((y06 XOR x06) AND (((((x04 XOR y04) AND ((x03 AND y03) OR ((x03 XOR y03) AND ((y02 AND x02) OR ((x02 XOR y02) AND ((x01 AND y01) OR ((x01 XOR y01) AND (x00 AND y00)))))))) OR (x04 AND y04)) AND (y05 XOR x05)) OR (y05 AND x05))) OR (y06 AND x06)))) AND (y08 XOR x08)) OR (y08 AND x08))))))))) OR (y12 AND x12)) AND (x13 XOR y13)) OR (y13 AND x13)) AND (x14 XOR y14))) AND (x15 XOR y15)) OR (x15 AND y15)) AND (x16 XOR y16)) OR (y16 AND x16)) AND (x17 XOR y17))) AND (y18 XOR x18)) OR (y18 AND x18))) OR (x19 AND y19)) AND (x20 XOR y20)) OR (y20 AND x20)) AND (y21 XOR x21))) AND (y22 XOR x22)) OR (x22 AND y22))))) OR (y24 AND x24)))) AND (y26 XOR x26))))
# z26 is defined as: (((x25 AND y25) OR ((y25 XOR x25) AND (((y24 XOR x24) AND ((x23 AND y23) OR ((x23 XOR y23) AND ((((y21 AND x21) OR ((((((y19 XOR x19) AND ((((x17 AND y17) OR (((((((y14 AND x14) OR ((((((y12 XOR x12) AND ((y11 AND x11) OR ((y11 XOR x11) AND ((y10 AND x10) OR ((y10 XOR x10) AND ((y09 AND x09) OR ((y09 XOR x09) AND ((((y07 AND x07) OR ((y07 XOR x07) AND (((y06 XOR x06) AND (((((x04 XOR y04) AND ((x03 AND y03) OR ((x03 XOR y03) AND ((y02 AND x02) OR ((x02 XOR y02) AND ((x01 AND y01) OR ((x01 XOR y01) AND (x00 AND y00)))))))) OR (x04 AND y04)) AND (y05 XOR x05)) OR (y05 AND x05))) OR (y06 AND x06)))) AND (y08 XOR x08)) OR (y08 AND x08))))))))) OR (y12 AND x12)) AND (x13 XOR y13)) OR (y13 AND x13)) AND (x14 XOR y14))) AND (x15 XOR y15)) OR (x15 AND y15)) AND (x16 XOR y16)) OR (y16 AND x16)) AND (x17 XOR y17))) AND (y18 XOR x18)) OR (y18 AND x18))) OR (x19 AND y19)) AND (x20 XOR y20)) OR (y20 AND x20)) AND (y21 XOR x21))) AND (y22 XOR x22)) OR (x22 AND y22))))) OR (y24 AND x24)))) XOR (y26 XOR x26))
# z25 is defined as: ((((y24 XOR x24) AND ((x23 AND y23) OR ((x23 XOR y23) AND ((((y21 AND x21) OR ((((((y19 XOR x19) AND ((((x17 AND y17) OR (((((((y14 AND x14) OR ((((((y12 XOR x12) AND ((y11 AND x11) OR ((y11 XOR x11) AND ((y10 AND x10) OR ((y10 XOR x10) AND ((y09 AND x09) OR ((y09 XOR x09) AND ((((y07 AND x07) OR ((y07 XOR x07) AND (((y06 XOR x06) AND (((((x04 XOR y04) AND ((x03 AND y03) OR ((x03 XOR y03) AND ((y02 AND x02) OR ((x02 XOR y02) AND ((x01 AND y01) OR ((x01 XOR y01) AND (x00 AND y00)))))))) OR (x04 AND y04)) AND (y05 XOR x05)) OR (y05 AND x05))) OR (y06 AND x06)))) AND (y08 XOR x08)) OR (y08 AND x08))))))))) OR (y12 AND x12)) AND (x13 XOR y13)) OR (y13 AND x13)) AND (x14 XOR y14))) AND (x15 XOR y15)) OR (x15 AND y15)) AND (x16 XOR y16)) OR (y16 AND x16)) AND (x17 XOR y17))) AND (y18 XOR x18)) OR (y18 AND x18))) OR (x19 AND y19)) AND (x20 XOR y20)) OR (y20 AND x20)) AND (y21 XOR x21))) AND (y22 XOR x22)) OR (x22 AND y22))))) OR (y24 AND x24)) XOR (y25 XOR x25))
# z24 is defined as: (((x23 AND y23) OR ((x23 XOR y23) AND ((((y21 AND x21) OR ((((((y19 XOR x19) AND ((((x17 AND y17) OR (((((((y14 AND x14) OR ((((((y12 XOR x12) AND ((y11 AND x11) OR ((y11 XOR x11) AND ((y10 AND x10) OR ((y10 XOR x10) AND ((y09 AND x09) OR ((y09 XOR x09) AND ((((y07 AND x07) OR ((y07 XOR x07) AND (((y06 XOR x06) AND (((((x04 XOR y04) AND ((x03 AND y03) OR ((x03 XOR y03) AND ((y02 AND x02) OR ((x02 XOR y02) AND ((x01 AND y01) OR ((x01 XOR y01) AND (x00 AND y00)))))))) OR (x04 AND y04)) AND (y05 XOR x05)) OR (y05 AND x05))) OR (y06 AND x06)))) AND (y08 XOR x08)) OR (y08 AND x08))))))))) OR (y12 AND x12)) AND (x13 XOR y13)) OR (y13 AND x13)) AND (x14 XOR y14))) AND (x15 XOR y15)) OR (x15 AND y15)) AND (x16 XOR y16)) OR (y16 AND x16)) AND (x17 XOR y17))) AND (y18 XOR x18)) OR (y18 AND x18))) OR (x19 AND y19)) AND (x20 XOR y20)) OR (y20 AND x20)) AND (y21 XOR x21))) AND (y22 XOR x22)) OR (x22 AND y22)))) XOR (y24 XOR x24))
# z23 is defined as: (((((y21 AND x21) OR ((((((y19 XOR x19) AND ((((x17 AND y17) OR (((((((y14 AND x14) OR ((((((y12 XOR x12) AND ((y11 AND x11) OR ((y11 XOR x11) AND ((y10 AND x10) OR ((y10 XOR x10) AND ((y09 AND x09) OR ((y09 XOR x09) AND ((((y07 AND x07) OR ((y07 XOR x07) AND (((y06 XOR x06) AND (((((x04 XOR y04) AND ((x03 AND y03) OR ((x03 XOR y03) AND ((y02 AND x02) OR ((x02 XOR y02) AND ((x01 AND y01) OR ((x01 XOR y01) AND (x00 AND y00)))))))) OR (x04 AND y04)) AND (y05 XOR x05)) OR (y05 AND x05))) OR (y06 AND x06)))) AND (y08 XOR x08)) OR (y08 AND x08))))))))) OR (y12 AND x12)) AND (x13 XOR y13)) OR (y13 AND x13)) AND (x14 XOR y14))) AND (x15 XOR y15)) OR (x15 AND y15)) AND (x16 XOR y16)) OR (y16 AND x16)) AND (x17 XOR y17))) AND (y18 XOR x18)) OR (y18 AND x18))) OR (x19 AND y19)) AND (x20 XOR y20)) OR (y20 AND x20)) AND (y21 XOR x21))) AND (y22 XOR x22)) OR (x22 AND y22)) XOR (x23 XOR y23))
# z22 is defined as: ((y22 XOR x22) XOR ((y21 AND x21) OR ((((((y19 XOR x19) AND ((((x17 AND y17) OR (((((((y14 AND x14) OR ((((((y12 XOR x12) AND ((y11 AND x11) OR ((y11 XOR x11) AND ((y10 AND x10) OR ((y10 XOR x10) AND ((y09 AND x09) OR ((y09 XOR x09) AND ((((y07 AND x07) OR ((y07 XOR x07) AND (((y06 XOR x06) AND (((((x04 XOR y04) AND ((x03 AND y03) OR ((x03 XOR y03) AND ((y02 AND x02) OR ((x02 XOR y02) AND ((x01 AND y01) OR ((x01 XOR y01) AND (x00 AND y00)))))))) OR (x04 AND y04)) AND (y05 XOR x05)) OR (y05 AND x05))) OR (y06 AND x06)))) AND (y08 XOR x08)) OR (y08 AND x08))))))))) OR (y12 AND x12)) AND (x13 XOR y13)) OR (y13 AND x13)) AND (x14 XOR y14))) AND (x15 XOR y15)) OR (x15 AND y15)) AND (x16 XOR y16)) OR (y16 AND x16)) AND (x17 XOR y17))) AND (y18 XOR x18)) OR (y18 AND x18))) OR (x19 AND y19)) AND (x20 XOR y20)) OR (y20 AND x20)) AND (y21 XOR x21))))
# z21 is defined as: ((((((y19 XOR x19) AND ((((x17 AND y17) OR (((((((y14 AND x14) OR ((((((y12 XOR x12) AND ((y11 AND x11) OR ((y11 XOR x11) AND ((y10 AND x10) OR ((y10 XOR x10) AND ((y09 AND x09) OR ((y09 XOR x09) AND ((((y07 AND x07) OR ((y07 XOR x07) AND (((y06 XOR x06) AND (((((x04 XOR y04) AND ((x03 AND y03) OR ((x03 XOR y03) AND ((y02 AND x02) OR ((x02 XOR y02) AND ((x01 AND y01) OR ((x01 XOR y01) AND (x00 AND y00)))))))) OR (x04 AND y04)) AND (y05 XOR x05)) OR (y05 AND x05))) OR (y06 AND x06)))) AND (y08 XOR x08)) OR (y08 AND x08))))))))) OR (y12 AND x12)) AND (x13 XOR y13)) OR (y13 AND x13)) AND (x14 XOR y14))) AND (x15 XOR y15)) OR (x15 AND y15)) AND (x16 XOR y16)) OR (y16 AND x16)) AND (x17 XOR y17))) AND (y18 XOR x18)) OR (y18 AND x18))) OR (x19 AND y19)) AND (x20 XOR y20)) OR (y20 AND x20)) XOR (y21 XOR x21))
# z20 is defined as: ((x20 XOR y20) XOR (((y19 XOR x19) AND ((((x17 AND y17) OR (((((((y14 AND x14) OR ((((((y12 XOR x12) AND ((y11 AND x11) OR ((y11 XOR x11) AND ((y10 AND x10) OR ((y10 XOR x10) AND ((y09 AND x09) OR ((y09 XOR x09) AND ((((y07 AND x07) OR ((y07 XOR x07) AND (((y06 XOR x06) AND (((((x04 XOR y04) AND ((x03 AND y03) OR ((x03 XOR y03) AND ((y02 AND x02) OR ((x02 XOR y02) AND ((x01 AND y01) OR ((x01 XOR y01) AND (x00 AND y00)))))))) OR (x04 AND y04)) AND (y05 XOR x05)) OR (y05 AND x05))) OR (y06 AND x06)))) AND (y08 XOR x08)) OR (y08 AND x08))))))))) OR (y12 AND x12)) AND (x13 XOR y13)) OR (y13 AND x13)) AND (x14 XOR y14))) AND (x15 XOR y15)) OR (x15 AND y15)) AND (x16 XOR y16)) OR (y16 AND x16)) AND (x17 XOR y17))) AND (y18 XOR x18)) OR (y18 AND x18))) OR (x19 AND y19)))
# z19 is defined as: ((y19 XOR x19) XOR ((((x17 AND y17) OR (((((((y14 AND x14) OR ((((((y12 XOR x12) AND ((y11 AND x11) OR ((y11 XOR x11) AND ((y10 AND x10) OR ((y10 XOR x10) AND ((y09 AND x09) OR ((y09 XOR x09) AND ((((y07 AND x07) OR ((y07 XOR x07) AND (((y06 XOR x06) AND (((((x04 XOR y04) AND ((x03 AND y03) OR ((x03 XOR y03) AND ((y02 AND x02) OR ((x02 XOR y02) AND ((x01 AND y01) OR ((x01 XOR y01) AND (x00 AND y00)))))))) OR (x04 AND y04)) AND (y05 XOR x05)) OR (y05 AND x05))) OR (y06 AND x06)))) AND (y08 XOR x08)) OR (y08 AND x08))))))))) OR (y12 AND x12)) AND (x13 XOR y13)) OR (y13 AND x13)) AND (x14 XOR y14))) AND (x15 XOR y15)) OR (x15 AND y15)) AND (x16 XOR y16)) OR (y16 AND x16)) AND (x17 XOR y17))) AND (y18 XOR x18)) OR (y18 AND x18)))
# z18 is defined as: (((x17 AND y17) OR (((((((y14 AND x14) OR ((((((y12 XOR x12) AND ((y11 AND x11) OR ((y11 XOR x11) AND ((y10 AND x10) OR ((y10 XOR x10) AND ((y09 AND x09) OR ((y09 XOR x09) AND ((((y07 AND x07) OR ((y07 XOR x07) AND (((y06 XOR x06) AND (((((x04 XOR y04) AND ((x03 AND y03) OR ((x03 XOR y03) AND ((y02 AND x02) OR ((x02 XOR y02) AND ((x01 AND y01) OR ((x01 XOR y01) AND (x00 AND y00)))))))) OR (x04 AND y04)) AND (y05 XOR x05)) OR (y05 AND x05))) OR (y06 AND x06)))) AND (y08 XOR x08)) OR (y08 AND x08))))))))) OR (y12 AND x12)) AND (x13 XOR y13)) OR (y13 AND x13)) AND (x14 XOR y14))) AND (x15 XOR y15)) OR (x15 AND y15)) AND (x16 XOR y16)) OR (y16 AND x16)) AND (x17 XOR y17))) XOR (y18 XOR x18))
# z17 is defined as: (((((((y14 AND x14) OR ((((((y12 XOR x12) AND ((y11 AND x11) OR ((y11 XOR x11) AND ((y10 AND x10) OR ((y10 XOR x10) AND ((y09 AND x09) OR ((y09 XOR x09) AND ((((y07 AND x07) OR ((y07 XOR x07) AND (((y06 XOR x06) AND (((((x04 XOR y04) AND ((x03 AND y03) OR ((x03 XOR y03) AND ((y02 AND x02) OR ((x02 XOR y02) AND ((x01 AND y01) OR ((x01 XOR y01) AND (x00 AND y00)))))))) OR (x04 AND y04)) AND (y05 XOR x05)) OR (y05 AND x05))) OR (y06 AND x06)))) AND (y08 XOR x08)) OR (y08 AND x08))))))))) OR (y12 AND x12)) AND (x13 XOR y13)) OR (y13 AND x13)) AND (x14 XOR y14))) AND (x15 XOR y15)) OR (x15 AND y15)) AND (x16 XOR y16)) OR (y16 AND x16)) XOR (x17 XOR y17))
# z16 is defined as: (((((y14 AND x14) OR ((((((y12 XOR x12) AND ((y11 AND x11) OR ((y11 XOR x11) AND ((y10 AND x10) OR ((y10 XOR x10) AND ((y09 AND x09) OR ((y09 XOR x09) AND ((((y07 AND x07) OR ((y07 XOR x07) AND (((y06 XOR x06) AND (((((x04 XOR y04) AND ((x03 AND y03) OR ((x03 XOR y03) AND ((y02 AND x02) OR ((x02 XOR y02) AND ((x01 AND y01) OR ((x01 XOR y01) AND (x00 AND y00)))))))) OR (x04 AND y04)) AND (y05 XOR x05)) OR (y05 AND x05))) OR (y06 AND x06)))) AND (y08 XOR x08)) OR (y08 AND x08))))))))) OR (y12 AND x12)) AND (x13 XOR y13)) OR (y13 AND x13)) AND (x14 XOR y14))) AND (x15 XOR y15)) OR (x15 AND y15)) XOR (x16 XOR y16))
# z15 is defined as: (((y14 AND x14) OR ((((((y12 XOR x12) AND ((y11 AND x11) OR ((y11 XOR x11) AND ((y10 AND x10) OR ((y10 XOR x10) AND ((y09 AND x09) OR ((y09 XOR x09) AND ((((y07 AND x07) OR ((y07 XOR x07) AND (((y06 XOR x06) AND (((((x04 XOR y04) AND ((x03 AND y03) OR ((x03 XOR y03) AND ((y02 AND x02) OR ((x02 XOR y02) AND ((x01 AND y01) OR ((x01 XOR y01) AND (x00 AND y00)))))))) OR (x04 AND y04)) AND (y05 XOR x05)) OR (y05 AND x05))) OR (y06 AND x06)))) AND (y08 XOR x08)) OR (y08 AND x08))))))))) OR (y12 AND x12)) AND (x13 XOR y13)) OR (y13 AND x13)) AND (x14 XOR y14))) XOR (x15 XOR y15))
# z14 is defined as: ((((((y12 XOR x12) AND ((y11 AND x11) OR ((y11 XOR x11) AND ((y10 AND x10) OR ((y10 XOR x10) AND ((y09 AND x09) OR ((y09 XOR x09) AND ((((y07 AND x07) OR ((y07 XOR x07) AND (((y06 XOR x06) AND (((((x04 XOR y04) AND ((x03 AND y03) OR ((x03 XOR y03) AND ((y02 AND x02) OR ((x02 XOR y02) AND ((x01 AND y01) OR ((x01 XOR y01) AND (x00 AND y00)))))))) OR (x04 AND y04)) AND (y05 XOR x05)) OR (y05 AND x05))) OR (y06 AND x06)))) AND (y08 XOR x08)) OR (y08 AND x08))))))))) OR (y12 AND x12)) AND (x13 XOR y13)) OR (y13 AND x13)) XOR (x14 XOR y14))
# z13 is defined as: ((((y12 XOR x12) AND ((y11 AND x11) OR ((y11 XOR x11) AND ((y10 AND x10) OR ((y10 XOR x10) AND ((y09 AND x09) OR ((y09 XOR x09) AND ((((y07 AND x07) OR ((y07 XOR x07) AND (((y06 XOR x06) AND (((((x04 XOR y04) AND ((x03 AND y03) OR ((x03 XOR y03) AND ((y02 AND x02) OR ((x02 XOR y02) AND ((x01 AND y01) OR ((x01 XOR y01) AND (x00 AND y00)))))))) OR (x04 AND y04)) AND (y05 XOR x05)) OR (y05 AND x05))) OR (y06 AND x06)))) AND (y08 XOR x08)) OR (y08 AND x08))))))))) OR (y12 AND x12)) XOR (x13 XOR y13))
# z12 is defined as: (((y11 AND x11) OR ((y11 XOR x11) AND ((y10 AND x10) OR ((y10 XOR x10) AND ((y09 AND x09) OR ((y09 XOR x09) AND ((((y07 AND x07) OR ((y07 XOR x07) AND (((y06 XOR x06) AND (((((x04 XOR y04) AND ((x03 AND y03) OR ((x03 XOR y03) AND ((y02 AND x02) OR ((x02 XOR y02) AND ((x01 AND y01) OR ((x01 XOR y01) AND (x00 AND y00)))))))) OR (x04 AND y04)) AND (y05 XOR x05)) OR (y05 AND x05))) OR (y06 AND x06)))) AND (y08 XOR x08)) OR (y08 AND x08)))))))) XOR (y12 XOR x12))
# z11 is defined as: ((y11 XOR x11) XOR ((y10 AND x10) OR ((y10 XOR x10) AND ((y09 AND x09) OR ((y09 XOR x09) AND ((((y07 AND x07) OR ((y07 XOR x07) AND (((y06 XOR x06) AND (((((x04 XOR y04) AND ((x03 AND y03) OR ((x03 XOR y03) AND ((y02 AND x02) OR ((x02 XOR y02) AND ((x01 AND y01) OR ((x01 XOR y01) AND (x00 AND y00)))))))) OR (x04 AND y04)) AND (y05 XOR x05)) OR (y05 AND x05))) OR (y06 AND x06)))) AND (y08 XOR x08)) OR (y08 AND x08)))))))
# z10 is defined as: (((y09 AND x09) OR ((y09 XOR x09) AND ((((y07 AND x07) OR ((y07 XOR x07) AND (((y06 XOR x06) AND (((((x04 XOR y04) AND ((x03 AND y03) OR ((x03 XOR y03) AND ((y02 AND x02) OR ((x02 XOR y02) AND ((x01 AND y01) OR ((x01 XOR y01) AND (x00 AND y00)))))))) OR (x04 AND y04)) AND (y05 XOR x05)) OR (y05 AND x05))) OR (y06 AND x06)))) AND (y08 XOR x08)) OR (y08 AND x08)))) XOR (y10 XOR x10))
# z09 is defined as: (((((y07 AND x07) OR ((y07 XOR x07) AND (((y06 XOR x06) AND (((((x04 XOR y04) AND ((x03 AND y03) OR ((x03 XOR y03) AND ((y02 AND x02) OR ((x02 XOR y02) AND ((x01 AND y01) OR ((x01 XOR y01) AND (x00 AND y00)))))))) OR (x04 AND y04)) AND (y05 XOR x05)) OR (y05 AND x05))) OR (y06 AND x06)))) AND (y08 XOR x08)) OR (y08 AND x08)) XOR (y09 XOR x09))
# z08 is defined as: (((y07 AND x07) OR ((y07 XOR x07) AND (((y06 XOR x06) AND (((((x04 XOR y04) AND ((x03 AND y03) OR ((x03 XOR y03) AND ((y02 AND x02) OR ((x02 XOR y02) AND ((x01 AND y01) OR ((x01 XOR y01) AND (x00 AND y00)))))))) OR (x04 AND y04)) AND (y05 XOR x05)) OR (y05 AND x05))) OR (y06 AND x06)))) XOR (y08 XOR x08))
# z07 is defined as: ((y07 XOR x07) XOR (((y06 XOR x06) AND (((((x04 XOR y04) AND ((x03 AND y03) OR ((x03 XOR y03) AND ((y02 AND x02) OR ((x02 XOR y02) AND ((x01 AND y01) OR ((x01 XOR y01) AND (x00 AND y00)))))))) OR (x04 AND y04)) AND (y05 XOR x05)) OR (y05 AND x05))) OR (y06 AND x06)))
# z06 is defined as: ((y06 XOR x06) XOR (((((x04 XOR y04) AND ((x03 AND y03) OR ((x03 XOR y03) AND ((y02 AND x02) OR ((x02 XOR y02) AND ((x01 AND y01) OR ((x01 XOR y01) AND (x00 AND y00)))))))) OR (x04 AND y04)) AND (y05 XOR x05)) OR (y05 AND x05)))
# z05 is defined as: ((((x04 XOR y04) AND ((x03 AND y03) OR ((x03 XOR y03) AND ((y02 AND x02) OR ((x02 XOR y02) AND ((x01 AND y01) OR ((x01 XOR y01) AND (x00 AND y00)))))))) OR (x04 AND y04)) XOR (y05 XOR x05))
# z04 is defined as: ((x04 XOR y04) XOR ((x03 AND y03) OR ((x03 XOR y03) AND ((y02 AND x02) OR ((x02 XOR y02) AND ((x01 AND y01) OR ((x01 XOR y01) AND (x00 AND y00))))))))
# z03 is defined as: ((x03 XOR y03) XOR ((y02 AND x02) OR ((x02 XOR y02) AND ((x01 AND y01) OR ((x01 XOR y01) AND (x00 AND y00))))))
# z02 is defined as: (((x01 AND y01) OR ((x01 XOR y01) AND (x00 AND y00))) XOR (x02 XOR y02))
# z01 is defined as: ((x01 XOR y01) XOR (x00 AND y00))
# z00 is defined as: (x00 XOR y00)

# %%
print(f"{output} is defined as: {define_output_recursively(fixed_dict, 'dtk')}")
print(f"{output} is defined as: {define_output_recursively(fixed_dict, 'ddn')}")
# Out:
# z00 is defined as: ((y30 XOR x30) AND (((x29 XOR y29) AND (((((x27 XOR y27) AND ((x26 AND y26) OR (((x25 AND y25) OR ((y25 XOR x25) AND (((y24 XOR x24) AND ((x23 AND y23) OR ((x23 XOR y23) AND ((((y21 AND x21) OR ((((((y19 XOR x19) AND ((((x17 AND y17) OR (((((((y14 AND x14) OR ((((((y12 XOR x12) AND ((y11 AND x11) OR ((y11 XOR x11) AND ((y10 AND x10) OR ((y10 XOR x10) AND ((y09 AND x09) OR ((y09 XOR x09) AND ((((y07 AND x07) OR ((y07 XOR x07) AND (((y06 XOR x06) AND (((((x04 XOR y04) AND ((x03 AND y03) OR ((x03 XOR y03) AND ((y02 AND x02) OR ((x02 XOR y02) AND ((x01 AND y01) OR ((x01 XOR y01) AND (x00 AND y00)))))))) OR (x04 AND y04)) AND (y05 XOR x05)) OR (y05 AND x05))) OR (y06 AND x06)))) AND (y08 XOR x08)) OR (y08 AND x08))))))))) OR (y12 AND x12)) AND (x13 XOR y13)) OR (y13 AND x13)) AND (x14 XOR y14))) AND (x15 XOR y15)) OR (x15 AND y15)) AND (x16 XOR y16)) OR (y16 AND x16)) AND (x17 XOR y17))) AND (y18 XOR x18)) OR (y18 AND x18))) OR (x19 AND y19)) AND (x20 XOR y20)) OR (y20 AND x20)) AND (y21 XOR x21))) AND (y22 XOR x22)) OR (x22 AND y22))))) OR (y24 AND x24)))) AND (y26 XOR x26)))) OR (y27 AND x27)) AND (y28 XOR x28)) OR (x28 AND y28))) OR (x29 AND y29)))
# z00 is defined as: (x30 AND y30)

# %%
#Manual solution:
swapped = ['z09', 'nnf', 'z20', 'nhs', 'ddn', 'kqh', 'z34', 'wrc']
print(','.join(sorted(swapped)))
# Out:
# ddn,kqh,nhs,nnf,wrc,z09,z20,z34
