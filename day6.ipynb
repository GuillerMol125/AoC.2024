# %%
import sys, os
import numpy as np
import pandas as pd
from utils.utils import read_txt, read_txt_np_int, read_txt_split

# %% [markdown]
# # INPUT

# %%
inputfilename = './inputs/day6A.txt'

inputdata = read_txt(inputfilename)

# %%
map_matrix = np.array([list(x) for x in inputdata])
map_matrix
# Out:
# array([['.', '.', '.', ..., '.', '.', '.'],
#        ['.', '.', '.', ..., '.', '.', '.'],
#        ['.', '.', '.', ..., '.', '.', '.'],
#        ...,
#        ['.', '.', '.', ..., '.', '#', '.'],
#        ['.', '.', '.', ..., '.', '.', '.'],
#        ['.', '.', '.', ..., '.', '.', '.']], dtype='<U1')

# %%
map_matrix[0,1]
# Out:
# np.str_('.')

# %% [markdown]
# ## PART 1

# %%
# Find guard postion
starting_guard_position = np.where(map_matrix == '^')
guard_position = (starting_guard_position[0][0], starting_guard_position[1][0])
print(map_matrix[guard_position])

# Map size
map_size = map_matrix.shape
print(map_size)
# Out:
# ^
# (130, 130)

# %%
guard_direction_shift = {'^': '>', 'v': '<', '<': '^', '>': 'v'}
movement_map = {'^': (-1, 0), 'v': (1, 0), '<': (0, -1), '>': (0, 1)}

def next_guard_position_direction(current_position, current_direction, map_size, map_matrix):
    movement = np.array(movement_map[current_direction])
    next_position = current_position + movement
    # Check if next position is within map bounds
    if (0 <= next_position[0] < map_size[0]) and (0 <= next_position[1] < map_size[1]):
        # Check map cell content
        if map_matrix[tuple(next_position)] == '#':
            # Change direction instead of moving
            new_direction = guard_direction_shift[current_direction]
            return current_position, new_direction  # Stay in place but change direction
        return next_position, current_direction  # Move to next position
    else:
        return None, None  # Out of bounds

# %%
visited_map = map_matrix.copy()
current_position = np.array(guard_position)
current_direction = '^'
while current_position is not None:
    # Mark the position as visited
    visited_map[tuple(current_position)] = 'X'
    current_position, current_direction = next_guard_position_direction(current_position, current_direction, map_size, map_matrix)

# %%
np.sum(visited_map == 'X')
# Out:
# np.int64(5199)

# %% [markdown]
# ## PART 2

# %%
blocks_pos = np.where(map_matrix == '#')
len(blocks_pos[0]), len(blocks_pos[1])
# Out:
# (815, 815)

# %%
def get_first_block_in_direction(start_position, direction, map_size, blocks_pos):
    if direction == '^':
        # Get all in the same column and above the start position
        candidates = np.where((blocks_pos[1] == start_position[1]) & (blocks_pos[0] < start_position[0]))[0]
        if len(candidates) == 0:
            return None
        return candidates[-1]
    elif direction == 'v':
        # Get all in the same column and below the start position
        candidates = np.where((blocks_pos[1] == start_position[1]) & (blocks_pos[0] > start_position[0]))[0]
        if len(candidates) == 0:
            return None
        return candidates[0]
    elif direction == '<':
        # Get all in the same row and to the left of the start position
        candidates = np.where((blocks_pos[0] == start_position[0]) & (blocks_pos[1] < start_position[1]))[0]
        if len(candidates) == 0:
            return None
        return candidates[-1]
    elif direction == '>':
        # Get all in the same row and to the right of the start position
        candidates = np.where((blocks_pos[0] == start_position[0]) & (blocks_pos[1] > start_position[1]))[0]
        if len(candidates) == 0:
            return None
        return candidates[0]
    return None

# %%
def create_blocks_dict(blocks_pos):
    blocks_dict = {i: {'position': (blocks_pos[0][i], blocks_pos[1][i])}  for i in range(len(blocks_pos[0]))}
    for i, block in blocks_dict.items():
        block_position = block['position']
        visible_blocks = 0
        for direction in ['^', 'v', '<', '>']:
            previous_position = block_position - np.array(movement_map[direction])
            if (0 <= previous_position[0] < map_size[0]) and (0 <= previous_position[1] < map_size[1]):
                new_direction = guard_direction_shift[direction]
                next_block = get_first_block_in_direction(previous_position, new_direction, map_size, blocks_pos)
                block[direction] = next_block
    return blocks_dict

# %%
candidates = get_first_block_in_direction((40,40), '<', map_size, blocks_pos)
print(candidates)
print(blocks_pos[0][candidates], blocks_pos[1][candidates] )
# Out:
# 265
# 40 14

# %%
blocks_dict = create_blocks_dict(blocks_pos)

# %%
map_size, blocks_dict
# Out:
# ((130, 130),
#  {0: {'position': (np.int64(0), np.int64(7)),
#    '^': np.int64(9),
#    '<': None,
#    '>': np.int64(214)},
#   1: {'position': (np.int64(0), np.int64(17)),
#    '^': np.int64(9),
#    '<': None,
#    '>': np.int64(325)},
#   2: {'position': (np.int64(0), np.int64(32)),
#    '^': np.int64(10),
#    '<': None,
#    '>': np.int64(118)},
#   3: {'position': (np.int64(0), np.int64(57)),
#    '^': np.int64(10),
#    '<': None,
#    '>': np.int64(49)},
#   4: {'position': (np.int64(0), np.int64(64)),
#    '^': np.int64(10),
#    '<': None,
#    '>': np.int64(27)},
#   5: {'position': (np.int64(0), np.int64(69)),
#    '^': np.int64(11),
#    '<': None,
#    '>': np.int64(212)},
#   6: {'position': (np.int64(0), np.int64(98)),
#    '^': np.int64(11),
#    '<': None,
#    '>': np.int64(22)},
#   7: {'position': (np.int64(0), np.int64(101)),
#    '^': None,
#    '<': None,
#    '>': np.int64(52)},
#   8: {'position': (np.int64(0), np.int64(117)),
#    '^': None,
#    '<': None,
#    '>': np.int64(23)},
#   9: {'position': (np.int64(1), np.int64(19)),
#    '^': np.int64(13),
#    'v': np.int64(1),
#    '<': None,
#    '>': np.int64(66)},
#   10: {'position': (np.int64(1), np.int64(65)),
#    '^': np.int64(16),
#    'v': np.int64(4),
#    '<': None,
#    '>': np.int64(34)},
#   11: {'position': (np.int64(1), np.int64(101)),
#    '^': np.int64(23),
#    'v': np.int64(6),
#    '<': None,
#    '>': np.int64(52)},
#   12: {'position': (np.int64(2), np.int64(15)),
#    '^': np.int64(25),
#    'v': None,
#    '<': None,
#    '>': np.int64(265)},
#   13: {'position': (np.int64(2), np.int64(49)),
#    '^': np.int64(27),
#    'v': np.int64(9),
#    '<': None,
#    '>': np.int64(549)},
#   14: {'position': (np.int64(2), np.int64(50)),
#    '^': np.int64(27),
#    'v': np.int64(9),
#    '<': None,
#    '>': np.int64(26)},
#   15: {'position': (np.int64(2), np.int64(60)),
#    '^': np.int64(27),
#    'v': np.int64(9),
#    '<': None,
#    '>': np.int64(50)},
#   16: {'position': (np.int64(2), np.int64(71)),
#    '^': np.int64(28),
#    'v': np.int64(10),
#    '<': None,
#    '>': np.int64(488)},
#   17: {'position': (np.int64(2), np.int64(77)),
#    '^': np.int64(31),
#    'v': np.int64(10),
#    '<': None,
#    '>': np.int64(29)},
#   18: {'position': (np.int64(2), np.int64(78)),
#    '^': np.int64(31),
#    'v': np.int64(10),
#    '<': None,
#    '>': np.int64(30)},
#   19: {'position': (np.int64(2), np.int64(82)),
#    '^': np.int64(31),
#    'v': np.int64(10),
#    '<': None,
#    '>': np.int64(213)},
#   20: {'position': (np.int64(2), np.int64(86)),
#    '^': np.int64(31),
#    'v': np.int64(10),
#    '<': None,
#    '>': np.int64(70)},
#   21: {'position': (np.int64(2), np.int64(92)),
#    '^': np.int64(31),
#    'v': np.int64(10),
#    '<': None,
#    '>': np.int64(727)},
#   22: {'position': (np.int64(2), np.int64(97)),
#    '^': np.int64(31),
#    'v': np.int64(10),
#    '<': np.int64(6),
#    '>': np.int64(123)},
#   23: {'position': (np.int64(2), np.int64(116)),
#    '^': np.int64(31),
#    'v': np.int64(11),
#    '<': np.int64(8),
#    '>': np.int64(46)},
#   24: {'position': (np.int64(3), np.int64(0)),
#    '^': np.int64(33),
#    'v': None,
#    '<': None},
#   25: {'position': (np.int64(3), np.int64(46)),
#    '^': np.int64(33),
#    'v': np.int64(12),
#    '<': None,
#    '>': np.int64(98)},
#   26: {'position': (np.int64(3), np.int64(49)),
#    '^': np.int64(33),
#    'v': np.int64(12),
#    '<': np.int64(14),
#    '>': np.int64(549)},
#   27: {'position': (np.int64(3), np.int64(63)),
#    '^': np.int64(34),
#    'v': np.int64(15),
#    '<': np.int64(4),
#    '>': np.int64(78)},
#   28: {'position': (np.int64(3), np.int64(74)),
#    '^': np.int64(35),
#    'v': np.int64(16),
#    '<': None,
#    '>': np.int64(147)},
#   29: {'position': (np.int64(3), np.int64(76)),
#    '^': np.int64(35),
#    'v': np.int64(16),
#    '<': np.int64(17),
#    '>': np.int64(293)},
#   30: {'position': (np.int64(3), np.int64(77)),
#    '^': np.int64(35),
#    'v': np.int64(16),
#    '<': np.int64(18),
#    '>': np.int64(393)},
#   31: {'position': (np.int64(3), np.int64(123)),
#    '^': None,
#    'v': np.int64(23),
#    '<': None,
#    '>': np.int64(54)},
#   32: {'position': (np.int64(4), np.int64(0)),
#    '^': np.int64(37),
#    'v': None,
#    '<': None},
#   33: {'position': (np.int64(4), np.int64(58)),
#    '^': np.int64(44),
#    'v': np.int64(26),
#    '<': None,
#    '>': np.int64(138)},
#   34: {'position': (np.int64(4), np.int64(64)),
#    '^': np.int64(44),
#    'v': np.int64(27),
#    '<': np.int64(10),
#    '>': np.int64(239)},
#   35: {'position': (np.int64(4), np.int64(105)),
#    '^': np.int64(45),
#    'v': np.int64(30),
#    '<': None,
#    '>': np.int64(141)},
#   36: {'position': (np.int64(4), np.int64(106)),
#    '^': np.int64(45),
#    'v': np.int64(30),
#    '<': None,
#    '>': np.int64(295)},
#   37: {'position': (np.int64(5), np.int64(11)),
#    '^': np.int64(49),
#    'v': np.int64(32),
#    '<': None,
#    '>': np.int64(128)},
#   38: {'position': (np.int64(5), np.int64(19)),
#    '^': np.int64(49),
#    'v': np.int64(32),
#    '<': None,
#    '>': np.int64(66)},
#   39: {'position': (np.int64(5), np.int64(21)),
#    '^': np.int64(49),
#    'v': np.int64(32),
#    '<': None,
#    '>': np.int64(187)},
#   40: {'position': (np.int64(5), np.int64(33)),
#    '^': np.int64(49),
#    'v': np.int64(32),
#    '<': None,
#    '>': np.int64(280)},
#   41: {'position': (np.int64(5), np.int64(38)),
#    '^': np.int64(49),
#    'v': np.int64(32),
#    '<': None,
#    '>': np.int64(122)},
#   42: {'position': (np.int64(5), np.int64(40)),
#    '^': np.int64(49),
#    'v': np.int64(32),
#    '<': None,
#    '>': np.int64(411)},
#   43: {'position': (np.int64(5), np.int64(44)),
#    '^': np.int64(49),
#    'v': np.int64(32),
#    '<': None,
#    '>': np.int64(145)},
#   44: {'position': (np.int64(5), np.int64(83)),
#    '^': np.int64(51),
#    'v': np.int64(34),
#    '<': None,
#    '>': np.int64(438)},
#   45: {'position': (np.int64(5), np.int64(111)),
#    '^': np.int64(53),
#    'v': np.int64(36),
#    '<': None,
#    '>': np.int64(406)},
#   46: {'position': (np.int64(5), np.int64(115)),
#    '^': np.int64(53),
#    'v': np.int64(36),
#    '<': np.int64(23),
#    '>': np.int64(120)},
#   47: {'position': (np.int64(5), np.int64(116)),
#    '^': np.int64(53),
#    'v': np.int64(36),
#    '<': np.int64(8),
#    '>': np.int64(244)},
#   48: {'position': (np.int64(5), np.int64(129)),
#    '^': None,
#    'v': np.int64(36),
#    '>': np.int64(562)},
#   49: {'position': (np.int64(6), np.int64(56)),
#    '^': np.int64(61),
#    'v': np.int64(43),
#    '<': np.int64(3),
#    '>': np.int64(190)},
#   50: {'position': (np.int64(6), np.int64(59)),
#    '^': np.int64(61),
#    'v': np.int64(43),
#    '<': np.int64(15),
#    '>': np.int64(86)},
#   51: {'position': (np.int64(6), np.int64(97)),
#    '^': np.int64(63),
#    'v': np.int64(44),
#    '<': np.int64(6),
#    '>': np.int64(123)},
#   52: {'position': (np.int64(6), np.int64(100)),
#    '^': np.int64(63),
#    'v': np.int64(44),
#    '<': np.int64(11),
#    '>': np.int64(155)},
#   53: {'position': (np.int64(6), np.int64(117)),
#    '^': None,
#    'v': np.int64(47),
#    '<': None,
#    '>': np.int64(63)},
#   54: {'position': (np.int64(6), np.int64(122)),
#    '^': None,
#    'v': np.int64(47),
#    '<': np.int64(31),
#    '>': np.int64(116)},
#   55: {'position': (np.int64(6), np.int64(126)),
#    '^': None,
#    'v': np.int64(47),
#    '<': None,
#    '>': np.int64(83)},
#   56: {'position': (np.int64(7), np.int64(0)),
#    '^': np.int64(65),
#    'v': None,
#    '<': None},
#   57: {'position': (np.int64(7), np.int64(2)),
#    '^': np.int64(65),
#    'v': None,
#    '<': None,
#    '>': np.int64(205)},
#   58: {'position': (np.int64(7), np.int64(8)),
#    '^': np.int64(66),
#    'v': None,
#    '<': None,
#    '>': np.int64(65)},
#   59: {'position': (np.int64(7), np.int64(34)),
#    '^': np.int64(70),
#    'v': None,
#    '<': None,
#    '>': np.int64(391)},
#   60: {'position': (np.int64(7), np.int64(46)),
#    '^': np.int64(70),
#    'v': None,
#    '<': None,
#    '>': np.int64(98)},
#   61: {'position': (np.int64(7), np.int64(86)),
#    '^': np.int64(71),
#    'v': np.int64(50),
#    '<': None,
#    '>': np.int64(70)},
#   62: {'position': (np.int64(7), np.int64(94)),
#    '^': np.int64(71),
#    'v': np.int64(50),
#    '<': None,
#    '>': np.int64(601)},
#   63: {'position': (np.int64(7), np.int64(116)),
#    '^': np.int64(71),
#    'v': np.int64(52),
#    '<': np.int64(53),
#    '>': np.int64(244)},
#   64: {'position': (np.int64(7), np.int64(117)),
#    '^': np.int64(71),
#    'v': np.int64(52),
#    '<': None,
#    '>': np.int64(102)},
#   65: {'position': (np.int64(8), np.int64(7)),
#    '^': np.int64(75),
#    'v': np.int64(57),
#    '<': np.int64(58),
#    '>': np.int64(214)},
#   66: {'position': (np.int64(8), np.int64(18)),
#    '^': np.int64(76),
#    'v': np.int64(58),
#    '<': np.int64(38),
#    '>': np.int64(75)},
#   67: {'position': (np.int64(8), np.int64(19)),
#    '^': np.int64(77),
#    'v': np.int64(58),
#    '<': None,
#    '>': np.int64(113)},
#   68: {'position': (np.int64(8), np.int64(25)),
#    '^': np.int64(77),
#    'v': np.int64(58),
#    '<': None,
#    '>': np.int64(160)},
#   69: {'position': (np.int64(8), np.int64(34)),
#    '^': np.int64(77),
#    'v': np.int64(58),
#    '<': None,
#    '>': np.int64(391)},
#   70: {'position': (np.int64(8), np.int64(85)),
#    '^': np.int64(81),
#    'v': np.int64(60),
#    '<': np.int64(61),
#    '>': np.int64(149)},
#   71: {'position': (np.int64(8), np.int64(127)),
#    '^': np.int64(85),
#    'v': np.int64(64),
#    '<': None,
#    '>': np.int64(112)},
#   72: {'position': (np.int64(8), np.int64(129)),
#    '^': None,
#    'v': np.int64(64),
#    '>': np.int64(562)},
#   73: {'position': (np.int64(9), np.int64(0)),
#    '^': np.int64(86),
#    'v': None,
#    '<': None},
#   74: {'position': (np.int64(9), np.int64(2)),
#    '^': np.int64(86),
#    'v': None,
#    '<': None,
#    '>': np.int64(205)},
#   75: {'position': (np.int64(9), np.int64(17)),
#    '^': np.int64(86),
#    'v': np.int64(65),
#    '<': np.int64(66),
#    '>': np.int64(325)},
#   76: {'position': (np.int64(9), np.int64(19)),
#    '^': np.int64(86),
#    'v': np.int64(66),
#    '<': None,
#    '>': np.int64(113)},
#   77: {'position': (np.int64(9), np.int64(49)),
#    '^': np.int64(86),
#    'v': np.int64(69),
#    '<': np.int64(14),
#    '>': np.int64(549)},
#   78: {'position': (np.int64(9), np.int64(62)),
#    '^': np.int64(87),
#    'v': np.int64(69),
#    '<': np.int64(27),
#    '>': np.int64(154)},
#   79: {'position': (np.int64(9), np.int64(67)),
#    '^': np.int64(87),
#    'v': np.int64(69),
#    '<': None,
#    '>': np.int64(115)},
#   80: {'position': (np.int64(9), np.int64(83)),
#    '^': np.int64(87),
#    'v': np.int64(69),
#    '<': None,
#    '>': np.int64(438)},
#   81: {'position': (np.int64(9), np.int64(109)),
#    '^': np.int64(87),
#    'v': np.int64(70),
#    '<': None,
#    '>': np.int64(111)},
#   82: {'position': (np.int64(9), np.int64(122)),
#    '^': None,
#    'v': np.int64(70),
#    '<': np.int64(31),
#    '>': np.int64(116)},
#   83: {'position': (np.int64(9), np.int64(125)),
#    '^': None,
#    'v': np.int64(70),
#    '<': np.int64(55),
#    '>': np.int64(159)},
#   84: {'position': (np.int64(9), np.int64(127)),
#    '^': None,
#    'v': np.int64(70),
#    '<': None,
#    '>': np.int64(112)},
#   85: {'position': (np.int64(9), np.int64(129)),
#    '^': None,
#    'v': np.int64(71),
#    '>': np.int64(562)},
#   86: {'position': (np.int64(10), np.int64(58)),
#    '^': np.int64(91),
#    'v': np.int64(77),
#    '<': np.int64(50),
#    '>': np.int64(138)},
#   87: {'position': (np.int64(10), np.int64(111)),
#    '^': np.int64(96),
#    'v': np.int64(81),
#    '<': None,
#    '>': np.int64(406)},
#   88: {'position': (np.int64(11), np.int64(23)),
#    '^': np.int64(97),
#    'v': None,
#    '<': None,
#    '>': np.int64(176)},
#   89: {'position': (np.int64(11), np.int64(28)),
#    '^': np.int64(97),
#    'v': None,
#    '<': None,
#    '>': np.int64(189)},
#   90: {'position': (np.int64(11), np.int64(40)),
#    '^': np.int64(98),
#    'v': None,
#    '<': None,
#    '>': np.int64(411)},
#   91: {'position': (np.int64(11), np.int64(62)),
#    '^': np.int64(100),
#    'v': np.int64(86),
#    '<': np.int64(27),
#    '>': np.int64(154)},
#   92: {'position': (np.int64(11), np.int64(67)),
#    '^': np.int64(100),
#    'v': np.int64(86),
#    '<': None,
#    '>': np.int64(115)},
#   93: {'position': (np.int64(11), np.int64(71)),
#    '^': np.int64(100),
#    'v': np.int64(86),
#    '<': None,
#    '>': np.int64(488)},
#   94: {'position': (np.int64(11), np.int64(79)),
#    '^': np.int64(100),
#    'v': np.int64(86),
#    '<': None,
#    '>': np.int64(129)},
#   95: {'position': (np.int64(11), np.int64(94)),
#    '^': np.int64(101),
#    'v': np.int64(86),
#    '<': None,
#    '>': np.int64(601)},
#   96: {'position': (np.int64(11), np.int64(118)),
#    '^': np.int64(103),
#    'v': np.int64(87),
#    '<': None,
#    '>': np.int64(127)},
#   97: {'position': (np.int64(12), np.int64(30)),
#    '^': np.int64(107),
#    'v': np.int64(89),
#    '<': None,
#    '>': np.int64(152)},
#   98: {'position': (np.int64(12), np.int64(45)),
#    '^': np.int64(109),
#    'v': np.int64(90),
#    '<': np.int64(60),
#    '>': np.int64(332)},
#   99: {'position': (np.int64(12), np.int64(53)),
#    '^': np.int64(110),
#    'v': np.int64(90),
#    '<': None,
#    '>': np.int64(146)},
#   100: {'position': (np.int64(12), np.int64(90)),
#    '^': np.int64(111),
#    'v': np.int64(94),
#    '<': None,
#    '>': np.int64(131)},
#   101: {'position': (np.int64(12), np.int64(112)),
#    '^': np.int64(112),
#    'v': np.int64(95),
#    '<': None,
#    '>': np.int64(178)},
#   102: {'position': (np.int64(12), np.int64(116)),
#    '^': np.int64(112),
#    'v': np.int64(95),
#    '<': np.int64(64),
#    '>': np.int64(244)},
#   103: {'position': (np.int64(12), np.int64(120)),
#    '^': np.int64(112),
#    'v': np.int64(96),
#    '<': None,
#    '>': np.int64(220)},
#   104: {'position': (np.int64(13), np.int64(8)),
#    '^': np.int64(113),
#    'v': None,
#    '<': None,
#    '>': np.int64(342)},
#   105: {'position': (np.int64(13), np.int64(26)),
#    '^': np.int64(114),
#    'v': None,
#    '<': None,
#    '>': np.int64(188)},
#   106: {'position': (np.int64(13), np.int64(30)),
#    '^': np.int64(114),
#    'v': None,
#    '<': None,
#    '>': np.int64(152)},
#   107: {'position': (np.int64(13), np.int64(35)),
#    '^': np.int64(114),
#    'v': np.int64(97),
#    '<': None,
#    '>': np.int64(228)},
#   108: {'position': (np.int64(13), np.int64(36)),
#    '^': np.int64(114),
#    'v': np.int64(97),
#    '<': None,
#    '>': np.int64(119)},
#   109: {'position': (np.int64(13), np.int64(51)),
#    '^': np.int64(114),
#    'v': np.int64(98),
#    '<': None,
#    '>': np.int64(153)},
#   110: {'position': (np.int64(13), np.int64(79)),
#    '^': np.int64(116),
#    'v': np.int64(99),
#    '<': None,
#    '>': np.int64(129)},
#   111: {'position': (np.int64(13), np.int64(108)),
#    '^': np.int64(116),
#    'v': np.int64(100),
#    '<': np.int64(81),
#    '>': np.int64(126)},
#   112: {'position': (np.int64(13), np.int64(126)),
#    '^': None,
#    'v': np.int64(103),
#    '<': np.int64(84),
#    '>': np.int64(637)},
#   113: {'position': (np.int64(14), np.int64(18)),
#    '^': np.int64(118),
#    'v': np.int64(104),
#    '<': np.int64(76),
#    '>': np.int64(175)},
#   114: {'position': (np.int64(14), np.int64(59)),
#    '^': np.int64(120),
#    'v': np.int64(109),
#    '<': np.int64(15),
#    '>': np.int64(266)},
#   115: {'position': (np.int64(14), np.int64(66)),
#    '^': np.int64(120),
#    'v': np.int64(109),
#    '<': np.int64(92),
#    '>': np.int64(211)},
#   116: {'position': (np.int64(14), np.int64(121)),
#    '^': None,
#    'v': np.int64(111),
#    '<': np.int64(82),
#    '>': np.int64(184)},
#   117: {'position': (np.int64(15), np.int64(13)),
#    '^': np.int64(122),
#    'v': None,
#    '<': None,
#    '>': np.int64(236)},
#   118: {'position': (np.int64(15), np.int64(31)),
#    '^': np.int64(122),
#    'v': np.int64(113),
#    '<': np.int64(2),
#    '>': np.int64(199)},
#   119: {'position': (np.int64(15), np.int64(35)),
#    '^': np.int64(122),
#    'v': np.int64(113),
#    '<': np.int64(108),
#    '>': np.int64(228)},
#   120: {'position': (np.int64(15), np.int64(114)),
#    '^': np.int64(127),
#    'v': np.int64(115),
#    '<': np.int64(46),
#    '>': np.int64(139)},
#   121: {'position': (np.int64(15), np.int64(118)),
#    '^': None,
#    'v': np.int64(115),
#    '<': None,
#    '>': np.int64(127)},
#   122: {'position': (np.int64(16), np.int64(37)),
#    '^': np.int64(129),
#    'v': np.int64(119),
#    '<': np.int64(41),
#    '>': np.int64(274)},
#   123: {'position': (np.int64(16), np.int64(96)),
#    '^': np.int64(132),
#    'v': np.int64(119),
#    '<': np.int64(51),
#    '>': np.int64(173)},
#   124: {'position': (np.int64(16), np.int64(98)),
#    '^': np.int64(133),
#    'v': np.int64(119),
#    '<': None,
#    '>': np.int64(132)},
#   125: {'position': (np.int64(16), np.int64(100)),
#    '^': None,
#    'v': np.int64(119),
#    '<': np.int64(11),
#    '>': np.int64(155)},
#   126: {'position': (np.int64(16), np.int64(107)),
#    '^': None,
#    'v': np.int64(119),
#    '<': np.int64(111),
#    '>': np.int64(156)},
#   127: {'position': (np.int64(16), np.int64(117)),
#    '^': None,
#    'v': np.int64(120),
#    '<': np.int64(121),
#    '>': np.int64(272)},
#   128: {'position': (np.int64(17), np.int64(10)),
#    '^': np.int64(136),
#    'v': None,
#    '<': np.int64(37),
#    '>': np.int64(142)},
#   129: {'position': (np.int64(17), np.int64(78)),
#    '^': np.int64(139),
#    'v': np.int64(122),
#    '<': np.int64(110),
#    '>': np.int64(148)},
#   130: {'position': (np.int64(17), np.int64(88)),
#    '^': np.int64(139),
#    'v': np.int64(122),
#    '<': None,
#    '>': np.int64(569)},
#   131: {'position': (np.int64(17), np.int64(89)),
#    '^': np.int64(139),
#    'v': np.int64(122),
#    '<': np.int64(100),
#    '>': np.int64(218)},
#   132: {'position': (np.int64(17), np.int64(97)),
#    '^': np.int64(139),
#    'v': np.int64(123),
#    '<': np.int64(124),
#    '>': np.int64(650)},
#   133: {'position': (np.int64(17), np.int64(100)),
#    '^': np.int64(139),
#    'v': np.int64(124),
#    '<': np.int64(11),
#    '>': np.int64(155)},
#   134: {'position': (np.int64(18), np.int64(3)),
#    '^': np.int64(141),
#    'v': None,
#    '<': None,
#    '>': np.int64(185)},
#   135: {'position': (np.int64(18), np.int64(5)),
#    '^': np.int64(141),
#    'v': None,
#    '<': None,
#    '>': np.int64(233)},
#   136: {'position': (np.int64(18), np.int64(42)),
#    '^': np.int64(141),
#    'v': np.int64(128),
#    '<': None,
#    '>': np.int64(171)},
#   137: {'position': (np.int64(18), np.int64(45)),
#    '^': np.int64(141),
#    'v': np.int64(128),
#    '<': np.int64(60),
#    '>': np.int64(332)},
#   138: {'position': (np.int64(18), np.int64(57)),
#    '^': np.int64(141),
#    'v': np.int64(128),
#    '<': np.int64(86),
#    '>': np.int64(216)},
#   139: {'position': (np.int64(18), np.int64(113)),
#    '^': None,
#    'v': np.int64(133),
#    '<': np.int64(120),
#    '>': np.int64(297)},
#   140: {'position': (np.int64(18), np.int64(114)),
#    '^': None,
#    'v': np.int64(133),
#    '<': np.int64(46),
#    '>': np.int64(157)},
#   141: {'position': (np.int64(19), np.int64(104)),
#    '^': None,
#    'v': np.int64(138),
#    '<': np.int64(35),
#    '>': np.int64(304)},
#   142: {'position': (np.int64(20), np.int64(9)),
#    '^': np.int64(151),
#    'v': None,
#    '<': np.int64(128),
#    '>': np.int64(150)},
#   143: {'position': (np.int64(20), np.int64(21)),
#    '^': np.int64(152),
#    'v': None,
#    '<': None,
#    '>': np.int64(187)},
#   144: {'position': (np.int64(20), np.int64(28)),
#    '^': np.int64(152),
#    'v': None,
#    '<': None,
#    '>': np.int64(189)},
#   145: {'position': (np.int64(20), np.int64(43)),
#    '^': np.int64(153),
#    'v': None,
#    '<': np.int64(43),
#    '>': np.int64(222)},
#   146: {'position': (np.int64(20), np.int64(52)),
#    '^': np.int64(154),
#    'v': None,
#    '<': np.int64(99),
#    '>': np.int64(161)},
#   147: {'position': (np.int64(20), np.int64(73)),
#    '^': np.int64(155),
#    'v': None,
#    '<': np.int64(28),
#    '>': np.int64(260)},
#   148: {'position': (np.int64(20), np.int64(77)),
#    '^': np.int64(155),
#    'v': None,
#    '<': np.int64(129),
#    '>': np.int64(393)},
#   149: {'position': (np.int64(20), np.int64(84)),
#    '^': np.int64(155),
#    'v': None,
#    '<': np.int64(70),
#    '>': np.int64(401)},
#   150: {'position': (np.int64(21), np.int64(8)),
#    '^': np.int64(160),
#    'v': None,
#    '<': np.int64(142),
#    '>': np.int64(342)},
#   151: {'position': (np.int64(21), np.int64(13)),
#    '^': np.int64(160),
#    'v': np.int64(142),
#    '<': None,
#    '>': np.int64(236)},
#   152: {'position': (np.int64(21), np.int64(29)),
#    '^': np.int64(161),
#    'v': np.int64(144),
#    '<': np.int64(106),
#    '>': np.int64(208)},
#   153: {'position': (np.int64(21), np.int64(50)),
#    '^': np.int64(161),
#    'v': np.int64(145),
#    '<': np.int64(109),
#    '>': np.int64(210)},
#   154: {'position': (np.int64(21), np.int64(61)),
#    '^': np.int64(163),
#    'v': np.int64(146),
#    '<': np.int64(91),
#    '>': np.int64(315)},
#   155: {'position': (np.int64(21), np.int64(99)),
#    '^': np.int64(164),
#    'v': np.int64(149),
#    '<': np.int64(133),
#    '>': np.int64(414)},
#   156: {'position': (np.int64(21), np.int64(106)),
#    '^': np.int64(165),
#    'v': np.int64(149),
#    '<': np.int64(126),
#    '>': np.int64(295)},
#   157: {'position': (np.int64(21), np.int64(113)),
#    '^': None,
#    'v': np.int64(149),
#    '<': np.int64(140),
#    '>': np.int64(297)},
#   158: {'position': (np.int64(21), np.int64(122)),
#    '^': None,
#    'v': np.int64(149),
#    '<': np.int64(31),
#    '>': np.int64(179)},
#   159: {'position': (np.int64(21), np.int64(124)),
#    '^': None,
#    'v': np.int64(149),
#    '<': np.int64(83),
#    '>': np.int64(235)},
#   160: {'position': (np.int64(22), np.int64(24)),
#    '^': np.int64(166),
#    'v': np.int64(151),
#    '<': np.int64(68),
#    '>': np.int64(418)},
#   161: {'position': (np.int64(22), np.int64(51)),
#    '^': np.int64(167),
#    'v': np.int64(153),
#    '<': np.int64(146),
#    '>': np.int64(290)},
#   162: {'position': (np.int64(22), np.int64(59)),
#    '^': np.int64(167),
#    'v': np.int64(153),
#    '<': np.int64(15),
#    '>': np.int64(266)},
#   163: {'position': (np.int64(22), np.int64(84)),
#    '^': np.int64(168),
#    'v': np.int64(154),
#    '<': np.int64(70),
#    '>': np.int64(401)},
#   164: {'position': (np.int64(22), np.int64(101)),
#    '^': np.int64(168),
#    'v': np.int64(155),
#    '<': None,
#    '>': np.int64(224)},
#   165: {'position': (np.int64(22), np.int64(108)),
#    '^': np.int64(168),
#    'v': np.int64(156),
#    '<': np.int64(81),
#    '>': np.int64(282)},
#   166: {'position': (np.int64(23), np.int64(38)),
#    '^': np.int64(171),
#    'v': np.int64(160),
#    '<': None,
#    '>': np.int64(170)},
#   167: {'position': (np.int64(23), np.int64(80)),
#    '^': np.int64(173),
#    'v': np.int64(162),
#    '<': None,
#    '>': np.int64(345)},
#   168: {'position': (np.int64(23), np.int64(109)),
#    '^': np.int64(174),
#    'v': np.int64(165),
#    '<': None,
#    '>': np.int64(243)},
#   169: {'position': (np.int64(24), np.int64(35)),
#    '^': np.int64(177),
#    'v': None,
#    '<': np.int64(108),
#    '>': np.int64(228)},
#   170: {'position': (np.int64(24), np.int64(37)),
#    '^': np.int64(177),
#    'v': None,
#    '<': np.int64(166),
#    '>': np.int64(274)},
#   171: {'position': (np.int64(24), np.int64(41)),
#    '^': np.int64(177),
#    'v': np.int64(166),
#    '<': np.int64(136),
#    '>': np.int64(202)},
#   172: {'position': (np.int64(24), np.int64(53)),
#    '^': np.int64(177),
#    'v': np.int64(166),
#    '<': None,
#    '>': np.int64(589)},
#   173: {'position': (np.int64(24), np.int64(95)),
#    '^': np.int64(178),
#    'v': np.int64(167),
#    '<': np.int64(123),
#    '>': np.int64(223)},
#   174: {'position': (np.int64(24), np.int64(117)),
#    '^': np.int64(179),
#    'v': np.int64(168),
#    '<': np.int64(121),
#    '>': np.int64(272)},
#   175: {'position': (np.int64(25), np.int64(17)),
#    '^': np.int64(181),
#    'v': None,
#    '<': np.int64(113),
#    '>': np.int64(325)},
#   176: {'position': (np.int64(25), np.int64(22)),
#    '^': np.int64(181),
#    'v': None,
#    '<': np.int64(88),
#    '>': np.int64(424)},
#   177: {'position': (np.int64(25), np.int64(92)),
#    '^': np.int64(182),
#    'v': np.int64(172),
#    '<': None,
#    '>': np.int64(727)},
#   178: {'position': (np.int64(25), np.int64(111)),
#    '^': np.int64(183),
#    'v': np.int64(173),
#    '<': np.int64(101),
#    '>': np.int64(406)},
#   179: {'position': (np.int64(25), np.int64(121)),
#    '^': None,
#    'v': np.int64(174),
#    '<': np.int64(158),
#    '>': np.int64(184)},
#   180: {'position': (np.int64(26), np.int64(11)),
#    '^': np.int64(186),
#    'v': None,
#    '<': None,
#    '>': np.int64(227)},
#   181: {'position': (np.int64(26), np.int64(71)),
#    '^': None,
#    'v': np.int64(176),
#    '<': None,
#    '>': np.int64(488)},
#   182: {'position': (np.int64(26), np.int64(101)),
#    '^': None,
#    'v': np.int64(177),
#    '<': None,
#    '>': np.int64(224)},
#   183: {'position': (np.int64(26), np.int64(117)),
#    '^': None,
#    'v': np.int64(178),
#    '<': np.int64(121),
#    '>': np.int64(272)},
#   184: {'position': (np.int64(26), np.int64(120)),
#    '^': None,
#    'v': np.int64(178),
#    '<': np.int64(179),
#    '>': np.int64(220)},
#   185: {'position': (np.int64(27), np.int64(2)),
#    '^': np.int64(187),
#    'v': None,
#    '<': np.int64(134),
#    '>': np.int64(205)},
#   186: {'position': (np.int64(27), np.int64(24)),
#    '^': np.int64(188),
#    'v': np.int64(180),
#    '<': np.int64(68),
#    '>': np.int64(418)},
#   187: {'position': (np.int64(28), np.int64(20)),
#    '^': np.int64(194),
#    'v': np.int64(185),
#    '<': np.int64(143),
#    '>': np.int64(409)},
#   188: {'position': (np.int64(28), np.int64(25)),
#    '^': np.int64(194),
#    'v': np.int64(186),
#    '<': np.int64(105),
#    '>': np.int64(299)},
#   189: {'position': (np.int64(28), np.int64(27)),
#    '^': np.int64(194),
#    'v': np.int64(186),
#    '<': np.int64(144),
#    '>': np.int64(237)},
#   190: {'position': (np.int64(28), np.int64(55)),
#    '^': np.int64(195),
#    'v': np.int64(186),
#    '<': np.int64(49),
#    '>': np.int64(215)},
#   191: {'position': (np.int64(28), np.int64(99)),
#    '^': np.int64(195),
#    'v': np.int64(186),
#    '<': np.int64(133),
#    '>': np.int64(414)},
#   192: {'position': (np.int64(28), np.int64(114)),
#    '^': np.int64(197),
#    'v': np.int64(186),
#    '<': np.int64(46),
#    '>': np.int64(283)},
#   193: {'position': (np.int64(29), np.int64(3)),
#    '^': np.int64(198),
#    'v': None,
#    '<': None,
#    '>': np.int64(284)},
#   194: {'position': (np.int64(29), np.int64(55)),
#    '^': None,
#    'v': np.int64(189),
#    '<': np.int64(49),
#    '>': np.int64(215)},
#   195: {'position': (np.int64(29), np.int64(101)),
#    '^': None,
#    'v': np.int64(191),
#    '<': None,
#    '>': np.int64(224)},
#   196: {'position': (np.int64(29), np.int64(111)),
#    '^': None,
#    'v': np.int64(191),
#    '<': np.int64(101),
#    '>': np.int64(406)},
#   197: {'position': (np.int64(29), np.int64(122)),
#    '^': None,
#    'v': np.int64(192),
#    '<': np.int64(31),
#    '>': np.int64(416)},
#   198: {'position': (np.int64(30), np.int64(29)),
#    '^': np.int64(209),
#    'v': np.int64(193),
#    '<': np.int64(106),
#    '>': np.int64(208)},
#   199: {'position': (np.int64(30), np.int64(30)),
#    '^': np.int64(209),
#    'v': np.int64(193),
#    '<': np.int64(118),
#    '>': np.int64(255)},
#   200: {'position': (np.int64(30), np.int64(31)),
#    '^': np.int64(209),
#    'v': np.int64(193),
#    '<': np.int64(2),
#    '>': np.int64(430)},
#   201: {'position': (np.int64(30), np.int64(37)),
#    '^': np.int64(209),
#    'v': np.int64(193),
#    '<': np.int64(166),
#    '>': np.int64(274)},
#   202: {'position': (np.int64(30), np.int64(40)),
#    '^': np.int64(209),
#    'v': np.int64(193),
#    '<': np.int64(171),
#    '>': np.int64(411)},
#   203: {'position': (np.int64(30), np.int64(43)),
#    '^': np.int64(210),
#    'v': np.int64(193),
#    '<': np.int64(43),
#    '>': np.int64(222)},
#   204: {'position': (np.int64(31), np.int64(0)),
#    '^': np.int64(214),
#    'v': None,
#    '<': None},
#   205: {'position': (np.int64(31), np.int64(1)),
#    '^': np.int64(214),
#    'v': None,
#    '<': np.int64(185),
#    '>': np.int64(225)},
#   206: {'position': (np.int64(31), np.int64(18)),
#    '^': np.int64(215),
#    'v': None,
#    '<': np.int64(76),
#    '>': np.int64(253)},
#   207: {'position': (np.int64(31), np.int64(20)),
#    '^': np.int64(215),
#    'v': None,
#    '<': np.int64(143),
#    '>': np.int64(409)},
#   208: {'position': (np.int64(31), np.int64(28)),
#    '^': np.int64(215),
#    'v': None,
#    '<': np.int64(198),
#    '>': np.int64(350)},
#   209: {'position': (np.int64(31), np.int64(43)),
#    '^': np.int64(215),
#    'v': np.int64(202),
#    '<': np.int64(43),
#    '>': np.int64(222)},
#   210: {'position': (np.int64(31), np.int64(49)),
#    '^': np.int64(215),
#    'v': np.int64(203),
#    '<': np.int64(153),
#    '>': np.int64(549)},
#   211: {'position': (np.int64(31), np.int64(65)),
#    '^': np.int64(218),
#    'v': np.int64(203),
#    '<': np.int64(115),
#    '>': np.int64(258)},
#   212: {'position': (np.int64(31), np.int64(68)),
#    '^': np.int64(218),
#    'v': np.int64(203),
#    '<': np.int64(5),
#    '>': np.int64(287)},
#   213: {'position': (np.int64(31), np.int64(81)),
#    '^': np.int64(218),
#    'v': np.int64(203),
#    '<': np.int64(19),
#    '>': np.int64(338)},
#   214: {'position': (np.int64(32), np.int64(6)),
#    '^': np.int64(221),
#    'v': np.int64(205),
#    '<': np.int64(65),
#    '>': np.int64(415)},
#   215: {'position': (np.int64(32), np.int64(54)),
#    '^': np.int64(223),
#    'v': np.int64(210),
#    '<': np.int64(194),
#    '>': np.int64(477)},
#   216: {'position': (np.int64(32), np.int64(56)),
#    '^': np.int64(223),
#    'v': np.int64(210),
#    '<': np.int64(138),
#    '>': np.int64(276)},
#   217: {'position': (np.int64(32), np.int64(59)),
#    '^': np.int64(223),
#    'v': np.int64(210),
#    '<': np.int64(15),
#    '>': np.int64(266)},
#   218: {'position': (np.int64(32), np.int64(88)),
#    '^': np.int64(223),
#    'v': np.int64(213),
#    '<': np.int64(131),
#    '>': np.int64(569)},
#   219: {'position': (np.int64(32), np.int64(101)),
#    '^': None,
#    'v': np.int64(213),
#    '<': None,
#    '>': np.int64(224)},
#   220: {'position': (np.int64(32), np.int64(119)),
#    '^': None,
#    'v': np.int64(213),
#    '<': np.int64(184),
#    '>': np.int64(367)},
#   221: {'position': (np.int64(33), np.int64(40)),
#    '^': np.int64(230),
#    'v': np.int64(214),
#    '<': np.int64(171),
#    '>': np.int64(411)},
#   222: {'position': (np.int64(33), np.int64(42)),
#    '^': np.int64(230),
#    'v': np.int64(214),
#    '<': np.int64(209),
#    '>': np.int64(482)},
#   223: {'position': (np.int64(33), np.int64(94)),
#    '^': np.int64(231),
#    'v': np.int64(218),
#    '<': np.int64(173),
#    '>': np.int64(601)},
#   224: {'position': (np.int64(33), np.int64(100)),
#    '^': None,
#    'v': np.int64(218),
#    '<': np.int64(219),
#    '>': np.int64(313)},
#   225: {'position': (np.int64(34), np.int64(0)),
#    '^': np.int64(232),
#    'v': None,
#    '<': np.int64(205)},
#   226: {'position': (np.int64(34), np.int64(8)),
#    '^': np.int64(234),
#    'v': None,
#    '<': np.int64(142),
#    '>': np.int64(342)},
#   227: {'position': (np.int64(34), np.int64(10)),
#    '^': np.int64(234),
#    'v': None,
#    '<': np.int64(180),
#    '>': np.int64(309)},
#   228: {'position': (np.int64(34), np.int64(34)),
#    '^': np.int64(234),
#    'v': None,
#    '<': np.int64(169),
#    '>': np.int64(391)},
#   229: {'position': (np.int64(34), np.int64(40)),
#    '^': np.int64(234),
#    'v': None,
#    '<': np.int64(171),
#    '>': np.int64(411)},
#   230: {'position': (np.int64(34), np.int64(77)),
#    '^': np.int64(234),
#    'v': np.int64(222),
#    '<': np.int64(129),
#    '>': np.int64(393)},
#   231: {'position': (np.int64(34), np.int64(97)),
#    '^': np.int64(234),
#    'v': np.int64(223),
#    '<': np.int64(124),
#    '>': np.int64(650)},
#   232: {'position': (np.int64(35), np.int64(3)),
#    '^': np.int64(236),
#    'v': np.int64(225),
#    '<': None,
#    '>': np.int64(284)},
#   233: {'position': (np.int64(35), np.int64(4)),
#    '^': np.int64(236),
#    'v': np.int64(225),
#    '<': np.int64(135),
#    '>': np.int64(240)},
#   234: {'position': (np.int64(35), np.int64(101)),
#    '^': None,
#    'v': np.int64(231),
#    '<': None,
#    '>': np.int64(268)},
#   235: {'position': (np.int64(35), np.int64(123)),
#    '^': None,
#    'v': np.int64(231),
#    '<': np.int64(159),
#    '>': np.int64(273)},
#   236: {'position': (np.int64(36), np.int64(12)),
#    '^': np.int64(241),
#    'v': np.int64(233),
#    '<': np.int64(151),
#    '>': np.int64(369)},
#   237: {'position': (np.int64(36), np.int64(26)),
#    '^': np.int64(242),
#    'v': np.int64(233),
#    '<': np.int64(189),
#    '>': np.int64(319)},
#   238: {'position': (np.int64(36), np.int64(45)),
#    '^': np.int64(242),
#    'v': np.int64(233),
#    '<': np.int64(60),
#    '>': np.int64(332)},
#   239: {'position': (np.int64(36), np.int64(63)),
#    '^': np.int64(242),
#    'v': np.int64(233),
#    '<': np.int64(34),
#    '>': np.int64(675)},
#   240: {'position': (np.int64(37), np.int64(3)),
#    '^': np.int64(246),
#    'v': None,
#    '<': np.int64(233),
#    '>': np.int64(284)},
#   241: {'position': (np.int64(37), np.int64(18)),
#    '^': np.int64(248),
#    'v': np.int64(236),
#    '<': np.int64(76),
#    '>': np.int64(253)},
#   242: {'position': (np.int64(37), np.int64(97)),
#    '^': np.int64(251),
#    'v': np.int64(239),
#    '<': np.int64(124),
#    '>': np.int64(650)},
#   243: {'position': (np.int64(37), np.int64(108)),
#    '^': np.int64(251),
#    'v': np.int64(239),
#    '<': np.int64(168),
#    '>': np.int64(282)},
#   244: {'position': (np.int64(37), np.int64(115)),
#    '^': np.int64(252),
#    'v': np.int64(239),
#    '<': np.int64(102),
#    '>': np.int64(684)},
#   245: {'position': (np.int64(38), np.int64(3)),
#    '^': np.int64(253),
#    'v': None,
#    '<': np.int64(233),
#    '>': np.int64(284)},
#   246: {'position': (np.int64(38), np.int64(6)),
#    '^': np.int64(253),
#    'v': np.int64(240),
#    '<': np.int64(65),
#    '>': np.int64(415)},
#   247: {'position': (np.int64(38), np.int64(10)),
#    '^': np.int64(253),
#    'v': np.int64(240),
#    '<': np.int64(180),
#    '>': np.int64(309)},
#   248: {'position': (np.int64(38), np.int64(59)),
#    '^': np.int64(258),
#    'v': np.int64(241),
#    '<': np.int64(15),
#    '>': np.int64(266)},
#   249: {'position': (np.int64(38), np.int64(81)),
#    '^': np.int64(261),
#    'v': np.int64(241),
#    '<': np.int64(19),
#    '>': np.int64(338)},
#   250: {'position': (np.int64(38), np.int64(88)),
#    '^': np.int64(261),
#    'v': np.int64(241),
#    '<': np.int64(131),
#    '>': np.int64(569)},
#   251: {'position': (np.int64(38), np.int64(111)),
#    '^': np.int64(262),
#    'v': np.int64(243),
#    '<': np.int64(101),
#    '>': np.int64(406)},
#   252: {'position': (np.int64(38), np.int64(119)),
#    '^': np.int64(262),
#    'v': np.int64(244),
#    '<': np.int64(184),
#    '>': np.int64(367)},
#   253: {'position': (np.int64(39), np.int64(17)),
#    '^': np.int64(266),
#    'v': np.int64(247),
#    '<': np.int64(241),
#    '>': np.int64(325)},
#   254: {'position': (np.int64(39), np.int64(20)),
#    '^': np.int64(266),
#    'v': np.int64(247),
#    '<': np.int64(143),
#    '>': np.int64(409)},
#   255: {'position': (np.int64(39), np.int64(29)),
#    '^': np.int64(266),
#    'v': np.int64(247),
#    '<': np.int64(199),
#    '>': np.int64(660)},
#   256: {'position': (np.int64(39), np.int64(45)),
#    '^': np.int64(266),
#    'v': np.int64(247),
#    '<': np.int64(60),
#    '>': np.int64(332)},
#   257: {'position': (np.int64(39), np.int64(47)),
#    '^': np.int64(266),
#    'v': np.int64(247),
#    '<': None,
#    '>': np.int64(275)},
#   258: {'position': (np.int64(39), np.int64(64)),
#    '^': np.int64(267),
#    'v': np.int64(248),
#    '<': np.int64(211),
#    '>': np.int64(321)},
#   259: {'position': (np.int64(39), np.int64(71)),
#    '^': np.int64(268),
#    'v': np.int64(248),
#    '<': None,
#    '>': np.int64(488)},
#   260: {'position': (np.int64(39), np.int64(72)),
#    '^': np.int64(268),
#    'v': np.int64(248),
#    '<': np.int64(147),
#    '>': np.int64(628)},
#   261: {'position': (np.int64(39), np.int64(90)),
#    '^': np.int64(268),
#    'v': np.int64(250),
#    '<': None,
#    '>': np.int64(323)},
#   262: {'position': (np.int64(39), np.int64(124)),
#    '^': None,
#    'v': np.int64(252),
#    '<': np.int64(83),
#    '>': np.int64(541)},
#   263: {'position': (np.int64(40), np.int64(0)),
#    '^': np.int64(274),
#    'v': None,
#    '<': np.int64(205)},
#   264: {'position': (np.int64(40), np.int64(6)),
#    '^': np.int64(274),
#    'v': None,
#    '<': np.int64(65),
#    '>': np.int64(415)},
#   265: {'position': (np.int64(40), np.int64(14)),
#    '^': np.int64(274),
#    'v': None,
#    '<': np.int64(12),
#    '>': np.int64(298)},
#   266: {'position': (np.int64(40), np.int64(58)),
#    '^': np.int64(277),
#    'v': np.int64(257),
#    '<': np.int64(248),
#    '>': np.int64(281)},
#   267: {'position': (np.int64(40), np.int64(69)),
#    '^': np.int64(277),
#    'v': np.int64(258),
#    '<': None,
#    '>': np.int64(469)},
#   268: {'position': (np.int64(40), np.int64(100)),
#    '^': np.int64(278),
#    'v': np.int64(261),
#    '<': np.int64(234),
#    '>': np.int64(313)},
#   269: {'position': (np.int64(40), np.int64(104)),
#    '^': np.int64(278),
#    'v': np.int64(261),
#    '<': np.int64(35),
#    '>': np.int64(304)},
#   270: {'position': (np.int64(40), np.int64(106)),
#    '^': np.int64(278),
#    'v': np.int64(261),
#    '<': np.int64(126),
#    '>': np.int64(295)},
#   271: {'position': (np.int64(40), np.int64(109)),
#    '^': np.int64(278),
#    'v': np.int64(261),
#    '<': None,
#    '>': np.int64(308)},
#   272: {'position': (np.int64(40), np.int64(116)),
#    '^': np.int64(278),
#    'v': np.int64(261),
#    '<': np.int64(183),
#    '>': np.int64(445)},
#   273: {'position': (np.int64(40), np.int64(122)),
#    '^': None,
#    'v': np.int64(261),
#    '<': np.int64(235),
#    '>': np.int64(416)},
#   274: {'position': (np.int64(41), np.int64(36)),
#    '^': np.int64(281),
#    'v': np.int64(265),
#    '<': np.int64(201),
#    '>': np.int64(419)},
#   275: {'position': (np.int64(41), np.int64(46)),
#    '^': np.int64(281),
#    'v': np.int64(265),
#    '<': np.int64(257),
#    '>': np.int64(286)},
#   276: {'position': (np.int64(41), np.int64(55)),
#    '^': np.int64(281),
#    'v': np.int64(265),
#    '<': np.int64(216),
#    '>': np.int64(302)},
#   277: {'position': (np.int64(41), np.int64(74)),
#    '^': np.int64(282),
#    'v': np.int64(267),
#    '<': None,
#    '>': None},
#   278: {'position': (np.int64(41), np.int64(120)),
#    '^': None,
#    'v': np.int64(272),
#    '<': np.int64(179),
#    '>': np.int64(720)},
#   279: {'position': (np.int64(42), np.int64(0)),
#    '^': np.int64(284),
#    'v': None,
#    '<': np.int64(205)},
#   280: {'position': (np.int64(42), np.int64(32)),
#    '^': np.int64(285),
#    'v': None,
#    '<': np.int64(40),
#    '>': np.int64(331)},
#   281: {'position': (np.int64(42), np.int64(57)),
#    '^': np.int64(287),
#    'v': np.int64(276),
#    '<': np.int64(266),
#    '>': np.int64(449)},
#   282: {'position': (np.int64(42), np.int64(107)),
#    '^': None,
#    'v': np.int64(277),
#    '<': np.int64(243),
#    '>': np.int64(456)},
#   283: {'position': (np.int64(42), np.int64(113)),
#    '^': None,
#    'v': np.int64(277),
#    '<': np.int64(192),
#    '>': np.int64(297)},
#   284: {'position': (np.int64(43), np.int64(2)),
#    '^': np.int64(288),
#    'v': np.int64(279),
#    '<': np.int64(245),
#    '>': np.int64(354)},
#   285: {'position': (np.int64(43), np.int64(37)),
#    '^': np.int64(290),
#    'v': np.int64(280),
#    '<': np.int64(166),
#    '>': np.int64(314)},
#   286: {'position': (np.int64(43), np.int64(45)),
#    '^': np.int64(290),
#    'v': np.int64(280),
#    '<': np.int64(275),
#    '>': np.int64(332)},
#   287: {'position': (np.int64(43), np.int64(67)),
#    '^': np.int64(292),
#    'v': np.int64(281),
#    '<': np.int64(212),
#    '>': np.int64(400)},
#   288: {'position': (np.int64(44), np.int64(8)),
#    '^': np.int64(298),
#    'v': np.int64(284),
#    '<': np.int64(142),
#    '>': np.int64(342)},
#   289: {'position': (np.int64(44), np.int64(12)),
#    '^': np.int64(298),
#    'v': np.int64(284),
#    '<': np.int64(151),
#    '>': np.int64(369)},
#   290: {'position': (np.int64(44), np.int64(50)),
#    '^': np.int64(302),
#    'v': np.int64(286),
#    '<': np.int64(161),
#    '>': np.int64(568)},
#   291: {'position': (np.int64(44), np.int64(57)),
#    '^': np.int64(303),
#    'v': np.int64(286),
#    '<': np.int64(266),
#    '>': np.int64(449)},
#   292: {'position': (np.int64(44), np.int64(72)),
#    '^': np.int64(303),
#    'v': np.int64(287),
#    '<': np.int64(147),
#    '>': np.int64(628)},
#   293: {'position': (np.int64(44), np.int64(75)),
#    '^': np.int64(303),
#    'v': np.int64(287),
#    '<': np.int64(29),
#    '>': np.int64(584)},
#   294: {'position': (np.int64(44), np.int64(78)),
#    '^': np.int64(303),
#    'v': np.int64(287),
#    '<': np.int64(110),
#    '>': np.int64(413)},
#   295: {'position': (np.int64(44), np.int64(105)),
#    '^': None,
#    'v': np.int64(287),
#    '<': np.int64(270),
#    '>': np.int64(307)},
#   296: {'position': (np.int64(44), np.int64(107)),
#    '^': None,
#    'v': np.int64(287),
#    '<': np.int64(243),
#    '>': np.int64(456)},
#   297: {'position': (np.int64(44), np.int64(112)),
#    '^': None,
#    'v': np.int64(287),
#    '<': np.int64(283),
#    '>': np.int64(329)},
#   298: {'position': (np.int64(45), np.int64(13)),
#    '^': np.int64(305),
#    'v': np.int64(289),
#    '<': np.int64(265),
#    '>': np.int64(388)},
#   299: {'position': (np.int64(45), np.int64(24)),
#    '^': np.int64(305),
#    'v': np.int64(289),
#    '<': np.int64(188),
#    '>': np.int64(418)},
#   300: {'position': (np.int64(45), np.int64(29)),
#    '^': np.int64(305),
#    'v': np.int64(289),
#    '<': np.int64(199),
#    '>': np.int64(660)},
#   301: {'position': (np.int64(45), np.int64(46)),
#    '^': np.int64(306),
#    'v': np.int64(289),
#    '<': np.int64(257),
#    '>': np.int64(305)},
#   302: {'position': (np.int64(45), np.int64(54)),
#    '^': np.int64(306),
#    'v': np.int64(290),
#    '<': np.int64(276),
#    '>': np.int64(477)},
#   303: {'position': (np.int64(45), np.int64(97)),
#    '^': np.int64(307),
#    'v': np.int64(294),
#    '<': np.int64(124),
#    '>': np.int64(650)},
#   304: {'position': (np.int64(45), np.int64(103)),
#    '^': np.int64(307),
#    'v': np.int64(294),
#    '<': np.int64(269),
#    '>': np.int64(522)},
#   305: {'position': (np.int64(46), np.int64(45)),
#    '^': np.int64(311),
#    'v': np.int64(300),
#    '<': np.int64(301),
#    '>': np.int64(332)},
#   306: {'position': (np.int64(46), np.int64(78)),
#    '^': np.int64(311),
#    'v': np.int64(302),
#    '<': np.int64(110),
#    '>': np.int64(413)},
#   307: {'position': (np.int64(46), np.int64(104)),
#    '^': None,
#    'v': np.int64(304),
#    '<': np.int64(295),
#    '>': np.int64(434)},
#   308: {'position': (np.int64(46), np.int64(108)),
#    '^': None,
#    'v': np.int64(304),
#    '<': np.int64(271),
#    '>': np.int64(317)},
#   309: {'position': (np.int64(47), np.int64(9)),
#    '^': np.int64(314),
#    'v': None,
#    '<': np.int64(247),
#    '>': np.int64(374)},
#   310: {'position': (np.int64(47), np.int64(18)),
#    '^': np.int64(314),
#    'v': None,
#    '<': np.int64(76),
#    '>': np.int64(443)},
#   311: {'position': (np.int64(47), np.int64(86)),
#    '^': np.int64(317),
#    'v': np.int64(306),
#    '<': None,
#    '>': np.int64(360)},
#   312: {'position': (np.int64(47), np.int64(94)),
#    '^': np.int64(317),
#    'v': np.int64(306),
#    '<': np.int64(173),
#    '>': np.int64(601)},
#   313: {'position': (np.int64(47), np.int64(99)),
#    '^': np.int64(317),
#    'v': np.int64(306),
#    '<': np.int64(268),
#    '>': np.int64(414)},
#   314: {'position': (np.int64(48), np.int64(36)),
#    '^': np.int64(320),
#    'v': np.int64(310),
#    '<': np.int64(285),
#    '>': np.int64(419)},
#   315: {'position': (np.int64(48), np.int64(60)),
#    '^': np.int64(321),
#    'v': np.int64(310),
#    '<': np.int64(154),
#    '>': np.int64(336)},
#   316: {'position': (np.int64(48), np.int64(75)),
#    '^': np.int64(323),
#    'v': np.int64(310),
#    '<': np.int64(29),
#    '>': np.int64(584)},
#   317: {'position': (np.int64(48), np.int64(107)),
#    '^': None,
#    'v': np.int64(313),
#    '<': np.int64(308),
#    '>': np.int64(456)},
#   318: {'position': (np.int64(49), np.int64(4)),
#    '^': np.int64(325),
#    'v': None,
#    '<': np.int64(135),
#    '>': np.int64(652)},
#   319: {'position': (np.int64(49), np.int64(25)),
#    '^': np.int64(326),
#    'v': None,
#    '<': np.int64(237),
#    '>': np.int64(363)},
#   320: {'position': (np.int64(49), np.int64(58)),
#    '^': np.int64(328),
#    'v': np.int64(314),
#    '<': np.int64(248),
#    '>': np.int64(468)},
#   321: {'position': (np.int64(49), np.int64(63)),
#    '^': np.int64(328),
#    'v': np.int64(315),
#    '<': np.int64(258),
#    '>': np.int64(675)},
#   322: {'position': (np.int64(49), np.int64(75)),
#    '^': np.int64(328),
#    'v': np.int64(315),
#    '<': np.int64(29),
#    '>': np.int64(584)},
#   323: {'position': (np.int64(49), np.int64(89)),
#    '^': np.int64(329),
#    'v': np.int64(316),
#    '<': np.int64(261),
#    '>': np.int64(471)},
#   324: {'position': (np.int64(50), np.int64(4)),
#    '^': np.int64(330),
#    'v': None,
#    '<': np.int64(135),
#    '>': np.int64(652)},
#   325: {'position': (np.int64(50), np.int64(16)),
#    '^': np.int64(331),
#    'v': np.int64(318),
#    '<': np.int64(253),
#    '>': np.int64(442)},
#   326: {'position': (np.int64(50), np.int64(36)),
#    '^': np.int64(332),
#    'v': np.int64(319),
#    '<': np.int64(285),
#    '>': np.int64(419)},
#   327: {'position': (np.int64(50), np.int64(38)),
#    '^': np.int64(332),
#    'v': np.int64(319),
#    '<': None,
#    '>': np.int64(466)},
#   328: {'position': (np.int64(50), np.int64(89)),
#    '^': np.int64(340),
#    'v': np.int64(322),
#    '<': np.int64(261),
#    '>': np.int64(471)},
#   329: {'position': (np.int64(50), np.int64(111)),
#    '^': np.int64(341),
#    'v': np.int64(323),
#    '<': np.int64(297),
#    '>': np.int64(406)},
#   330: {'position': (np.int64(51), np.int64(10)),
#    '^': np.int64(343),
#    'v': np.int64(324),
#    '<': np.int64(180),
#    '>': np.int64(450)},
#   331: {'position': (np.int64(51), np.int64(31)),
#    '^': np.int64(343),
#    'v': np.int64(325),
#    '<': np.int64(280),
#    '>': np.int64(430)},
#   332: {'position': (np.int64(51), np.int64(44)),
#    '^': np.int64(343),
#    'v': np.int64(327),
#    '<': np.int64(305),
#    '>': np.int64(379)},
#   333: {'position': (np.int64(51), np.int64(46)),
#    '^': np.int64(343),
#    'v': np.int64(327),
#    '<': np.int64(257),
#    '>': np.int64(616)},
#   334: {'position': (np.int64(51), np.int64(47)),
#    '^': np.int64(343),
#    'v': np.int64(327),
#    '<': None,
#    '>': np.int64(459)},
#   335: {'position': (np.int64(51), np.int64(51)),
#    '^': np.int64(343),
#    'v': np.int64(327),
#    '<': np.int64(146),
#    '>': np.int64(357)},
#   336: {'position': (np.int64(51), np.int64(59)),
#    '^': np.int64(343),
#    'v': np.int64(327),
#    '<': np.int64(315),
#    '>': np.int64(444)},
#   337: {'position': (np.int64(51), np.int64(64)),
#    '^': np.int64(343),
#    'v': np.int64(327),
#    '<': np.int64(211),
#    '>': np.int64(370)},
#   338: {'position': (np.int64(51), np.int64(80)),
#    '^': np.int64(343),
#    'v': np.int64(327),
#    '<': np.int64(249),
#    '>': np.int64(345)},
#   339: {'position': (np.int64(51), np.int64(86)),
#    '^': np.int64(343),
#    'v': np.int64(327),
#    '<': None,
#    '>': np.int64(360)},
#   340: {'position': (np.int64(51), np.int64(90)),
#    '^': np.int64(343),
#    'v': np.int64(328),
#    '<': None,
#    '>': np.int64(624)},
#   341: {'position': (np.int64(51), np.int64(116)),
#    '^': np.int64(344),
#    'v': np.int64(329),
#    '<': np.int64(183),
#    '>': np.int64(445)},
#   342: {'position': (np.int64(52), np.int64(7)),
#    '^': np.int64(345),
#    'v': None,
#    '<': np.int64(288),
#    '>': np.int64(408)},
#   343: {'position': (np.int64(52), np.int64(108)),
#    '^': None,
#    'v': np.int64(340),
#    '<': np.int64(271),
#    '>': np.int64(428)},
#   344: {'position': (np.int64(52), np.int64(126)),
#    '^': None,
#    'v': np.int64(341),
#    '<': np.int64(84),
#    '>': np.int64(637)},
#   345: {'position': (np.int64(53), np.int64(79)),
#    '^': np.int64(352),
#    'v': np.int64(342),
#    '<': np.int64(338),
#    '>': np.int64(394)},
#   346: {'position': (np.int64(53), np.int64(86)),
#    '^': np.int64(352),
#    'v': np.int64(342),
#    '<': None,
#    '>': np.int64(360)},
#   347: {'position': (np.int64(53), np.int64(104)),
#    '^': np.int64(352),
#    'v': np.int64(342),
#    '<': np.int64(295),
#    '>': np.int64(434)},
#   348: {'position': (np.int64(53), np.int64(108)),
#    '^': np.int64(352),
#    'v': np.int64(342),
#    '<': np.int64(271),
#    '>': np.int64(428)},
#   349: {'position': (np.int64(54), np.int64(18)),
#    '^': np.int64(353),
#    'v': None,
#    '<': np.int64(76),
#    '>': np.int64(443)},
#   350: {'position': (np.int64(54), np.int64(27)),
#    '^': np.int64(353),
#    'v': None,
#    '<': np.int64(208),
#    '>': np.int64(514)},
#   351: {'position': (np.int64(54), np.int64(38)),
#    '^': np.int64(353),
#    'v': None,
#    '<': None,
#    '>': np.int64(466)},
#   352: {'position': (np.int64(54), np.int64(113)),
#    '^': None,
#    'v': np.int64(348),
#    '<': np.int64(192),
#    '>': np.int64(384)},
#   353: {'position': (np.int64(55), np.int64(90)),
#    '^': np.int64(361),
#    'v': np.int64(351),
#    '<': None,
#    '>': np.int64(624)},
#   354: {'position': (np.int64(56), np.int64(1)),
#    '^': np.int64(363),
#    'v': None,
#    '<': np.int64(284),
#    '>': np.int64(572)},
#   355: {'position': (np.int64(56), np.int64(4)),
#    '^': np.int64(363),
#    'v': None,
#    '<': np.int64(135),
#    '>': np.int64(652)},
#   356: {'position': (np.int64(56), np.int64(16)),
#    '^': np.int64(363),
#    'v': None,
# ...
#    '^': np.int64(703),
#    'v': None,
#    '<': np.int64(652),
#    '>': None},
#   696: {'position': (np.int64(113), np.int64(10)),
#    '^': np.int64(703),
#    'v': None,
#    '<': np.int64(653),
#    '>': None},
#   697: {'position': (np.int64(113), np.int64(20)),
#    '^': np.int64(703),
#    'v': None,
#    '<': np.int64(578),
#    '>': np.int64(729)},
#   698: {'position': (np.int64(113), np.int64(21)),
#    '^': np.int64(703),
#    'v': None,
#    '<': np.int64(688),
#    '>': np.int64(707)},
#   699: {'position': (np.int64(113), np.int64(24)),
#    '^': np.int64(703),
#    'v': np.int64(688),
#    '<': np.int64(484),
#    '>': None},
#   700: {'position': (np.int64(113), np.int64(26)),
#    '^': np.int64(703),
#    'v': np.int64(688),
#    '<': np.int64(364),
#    '>': np.int64(776)},
#   701: {'position': (np.int64(113), np.int64(107)),
#    '^': np.int64(705),
#    'v': np.int64(693),
#    '<': np.int64(664),
#    '>': np.int64(808)},
#   702: {'position': (np.int64(113), np.int64(117)),
#    '^': None,
#    'v': np.int64(694),
#    '<': np.int64(518),
#    '>': np.int64(772)},
#   703: {'position': (np.int64(114), np.int64(88)),
#    '^': np.int64(713),
#    'v': np.int64(700),
#    '<': np.int64(624),
#    '>': np.int64(788)},
#   704: {'position': (np.int64(114), np.int64(101)),
#    '^': np.int64(713),
#    'v': np.int64(700),
#    '<': np.int64(693),
#    '>': None},
#   705: {'position': (np.int64(114), np.int64(113)),
#    '^': np.int64(713),
#    'v': np.int64(701),
#    '<': np.int64(694),
#    '>': np.int64(771)},
#   706: {'position': (np.int64(115), np.int64(16)),
#    '^': np.int64(716),
#    'v': None,
#    '<': np.int64(658),
#    '>': np.int64(752)},
#   707: {'position': (np.int64(115), np.int64(20)),
#    '^': np.int64(716),
#    'v': None,
#    '<': np.int64(698),
#    '>': np.int64(729)},
#   708: {'position': (np.int64(115), np.int64(41)),
#    '^': np.int64(717),
#    'v': None,
#    '<': np.int64(614),
#    '>': None},
#   709: {'position': (np.int64(115), np.int64(44)),
#    '^': np.int64(717),
#    'v': None,
#    '<': np.int64(616),
#    '>': np.int64(732)},
#   710: {'position': (np.int64(115), np.int64(45)),
#    '^': np.int64(718),
#    'v': None,
#    '<': np.int64(668),
#    '>': None},
#   711: {'position': (np.int64(115), np.int64(48)),
#    '^': np.int64(718),
#    'v': None,
#    '<': np.int64(669),
#    '>': np.int64(781)},
#   712: {'position': (np.int64(115), np.int64(64)),
#    '^': np.int64(718),
#    'v': None,
#    '<': np.int64(211),
#    '>': np.int64(733)},
#   713: {'position': (np.int64(115), np.int64(126)),
#    '^': np.int64(721),
#    'v': np.int64(705),
#    '<': np.int64(625),
#    '>': None},
#   714: {'position': (np.int64(116), np.int64(3)),
#    '^': np.int64(723),
#    'v': None,
#    '<': np.int64(631),
#    '>': np.int64(763)},
#   715: {'position': (np.int64(116), np.int64(12)),
#    '^': np.int64(723),
#    'v': None,
#    '<': np.int64(440),
#    '>': np.int64(765)},
#   716: {'position': (np.int64(116), np.int64(39)),
#    '^': np.int64(724),
#    'v': np.int64(707),
#    '<': np.int64(579),
#    '>': None},
#   717: {'position': (np.int64(116), np.int64(45)),
#    '^': np.int64(725),
#    'v': np.int64(709),
#    '<': np.int64(668),
#    '>': None},
#   718: {'position': (np.int64(116), np.int64(72)),
#    '^': np.int64(727),
#    'v': np.int64(712),
#    '<': np.int64(147),
#    '>': np.int64(757)},
#   719: {'position': (np.int64(116), np.int64(109)),
#    '^': np.int64(728),
#    'v': np.int64(712),
#    '<': np.int64(665),
#    '>': None},
#   720: {'position': (np.int64(116), np.int64(119)),
#    '^': None,
#    'v': np.int64(712),
#    '<': np.int64(685),
#    '>': None},
#   721: {'position': (np.int64(116), np.int64(127)),
#    '^': None,
#    'v': np.int64(713),
#    '<': np.int64(630),
#    '>': np.int64(742)},
#   722: {'position': (np.int64(116), np.int64(128)),
#    '^': None,
#    'v': np.int64(713),
#    '<': np.int64(543),
#    '>': np.int64(743)},
#   723: {'position': (np.int64(117), np.int64(17)),
#    '^': np.int64(729),
#    'v': np.int64(715),
#    '<': np.int64(659),
#    '>': None},
#   724: {'position': (np.int64(117), np.int64(45)),
#    '^': np.int64(733),
#    'v': np.int64(716),
#    '<': np.int64(668),
#    '>': None},
#   725: {'position': (np.int64(117), np.int64(55)),
#    '^': np.int64(733),
#    'v': np.int64(717),
#    '<': np.int64(516),
#    '>': np.int64(768)},
#   726: {'position': (np.int64(117), np.int64(62)),
#    '^': np.int64(733),
#    'v': np.int64(717),
#    '<': np.int64(689),
#    '>': None},
#   727: {'position': (np.int64(117), np.int64(91)),
#    '^': np.int64(734),
#    'v': np.int64(718),
#    '<': np.int64(670),
#    '>': np.int64(784)},
#   728: {'position': (np.int64(117), np.int64(113)),
#    '^': None,
#    'v': np.int64(719),
#    '<': np.int64(694),
#    '>': np.int64(771)},
#   729: {'position': (np.int64(118), np.int64(19)),
#    '^': np.int64(737),
#    'v': np.int64(723),
#    '<': np.int64(707),
#    '>': None},
#   730: {'position': (np.int64(118), np.int64(30)),
#    '^': np.int64(738),
#    'v': np.int64(723),
#    '<': np.int64(511),
#    '>': None},
#   731: {'position': (np.int64(118), np.int64(35)),
#    '^': np.int64(738),
#    'v': np.int64(723),
#    '<': np.int64(526),
#    '>': np.int64(745)},
#   732: {'position': (np.int64(118), np.int64(43)),
#    '^': np.int64(738),
#    'v': np.int64(723),
#    '<': np.int64(709),
#    '>': np.int64(755)},
#   733: {'position': (np.int64(118), np.int64(63)),
#    '^': np.int64(739),
#    'v': np.int64(726),
#    '<': np.int64(712),
#    '>': None},
#   734: {'position': (np.int64(118), np.int64(93)),
#    '^': np.int64(740),
#    'v': np.int64(727),
#    '<': np.int64(432),
#    '>': np.int64(749)},
#   735: {'position': (np.int64(118), np.int64(104)),
#    '^': np.int64(741),
#    'v': np.int64(727),
#    '<': np.int64(610),
#    '>': np.int64(740)},
#   736: {'position': (np.int64(119), np.int64(7)),
#    '^': np.int64(745),
#    'v': None,
#    '<': np.int64(639),
#    '>': None},
#   737: {'position': (np.int64(119), np.int64(22)),
#    '^': np.int64(745),
#    'v': np.int64(729),
#    '<': np.int64(667),
#    '>': None},
#   738: {'position': (np.int64(119), np.int64(56)),
#    '^': np.int64(746),
#    'v': np.int64(732),
#    '<': np.int64(672),
#    '>': None},
#   739: {'position': (np.int64(119), np.int64(66)),
#    '^': np.int64(749),
#    'v': np.int64(733),
#    '<': np.int64(287),
#    '>': np.int64(790)},
#   740: {'position': (np.int64(119), np.int64(103)),
#    '^': np.int64(750),
#    'v': np.int64(734),
#    '<': np.int64(735),
#    '>': np.int64(800)},
#   741: {'position': (np.int64(119), np.int64(121)),
#    '^': None,
#    'v': np.int64(735),
#    '<': np.int64(686),
#    '>': None},
#   742: {'position': (np.int64(119), np.int64(126)),
#    '^': None,
#    'v': np.int64(735),
#    '<': np.int64(721),
#    '>': None},
#   743: {'position': (np.int64(119), np.int64(127)),
#    '^': None,
#    'v': np.int64(735),
#    '<': np.int64(722),
#    '>': None},
#   744: {'position': (np.int64(119), np.int64(129)),
#    '^': None,
#    'v': np.int64(735),
#    '>': np.int64(802)},
#   745: {'position': (np.int64(120), np.int64(34)),
#    '^': np.int64(755),
#    'v': np.int64(737),
#    '<': np.int64(731),
#    '>': None},
#   746: {'position': (np.int64(120), np.int64(58)),
#    '^': np.int64(757),
#    'v': np.int64(738),
#    '<': np.int64(656),
#    '>': None},
#   747: {'position': (np.int64(120), np.int64(63)),
#    '^': np.int64(757),
#    'v': np.int64(738),
#    '<': np.int64(712),
#    '>': None},
#   748: {'position': (np.int64(120), np.int64(66)),
#    '^': np.int64(757),
#    'v': np.int64(738),
#    '<': np.int64(287),
#    '>': np.int64(790)},
#   749: {'position': (np.int64(120), np.int64(92)),
#    '^': np.int64(759),
#    'v': np.int64(739),
#    '<': np.int64(734),
#    '>': None},
#   750: {'position': (np.int64(120), np.int64(113)),
#    '^': np.int64(761),
#    'v': np.int64(740),
#    '<': np.int64(694),
#    '>': np.int64(771)},
#   751: {'position': (np.int64(121), np.int64(5)),
#    '^': np.int64(764),
#    'v': None,
#    '<': np.int64(671),
#    '>': np.int64(795)},
#   752: {'position': (np.int64(121), np.int64(15)),
#    '^': np.int64(766),
#    'v': None,
#    '<': np.int64(706),
#    '>': np.int64(775)},
#   753: {'position': (np.int64(121), np.int64(28)),
#    '^': np.int64(767),
#    'v': None,
#    '<': np.int64(655),
#    '>': None},
#   754: {'position': (np.int64(121), np.int64(32)),
#    '^': np.int64(767),
#    'v': None,
#    '<': np.int64(505),
#    '>': None},
#   755: {'position': (np.int64(121), np.int64(42)),
#    '^': np.int64(767),
#    'v': np.int64(745),
#    '<': np.int64(732),
#    '>': np.int64(811)},
#   756: {'position': (np.int64(121), np.int64(51)),
#    '^': np.int64(767),
#    'v': np.int64(745),
#    '<': np.int64(605),
#    '>': np.int64(787)},
#   757: {'position': (np.int64(121), np.int64(71)),
#    '^': np.int64(769),
#    'v': np.int64(748),
#    '<': np.int64(718),
#    '>': None},
#   758: {'position': (np.int64(121), np.int64(75)),
#    '^': np.int64(769),
#    'v': np.int64(748),
#    '<': np.int64(629),
#    '>': None},
#   759: {'position': (np.int64(121), np.int64(98)),
#    '^': np.int64(770),
#    'v': np.int64(749),
#    '<': np.int64(692),
#    '>': None},
#   760: {'position': (np.int64(121), np.int64(104)),
#    '^': np.int64(770),
#    'v': np.int64(749),
#    '<': np.int64(610),
#    '>': np.int64(814)},
#   761: {'position': (np.int64(121), np.int64(117)),
#    '^': np.int64(773),
#    'v': np.int64(750),
#    '<': np.int64(518),
#    '>': np.int64(772)},
#   762: {'position': (np.int64(122), np.int64(0)),
#    '^': np.int64(774),
#    'v': None,
#    '<': np.int64(619)},
#   763: {'position': (np.int64(122), np.int64(2)),
#    '^': np.int64(774),
#    'v': None,
#    '<': np.int64(714),
#    '>': None},
#   764: {'position': (np.int64(122), np.int64(7)),
#    '^': np.int64(774),
#    'v': np.int64(751),
#    '<': np.int64(639),
#    '>': None},
#   765: {'position': (np.int64(122), np.int64(11)),
#    '^': np.int64(774),
#    'v': np.int64(751),
#    '<': np.int64(715),
#    '>': None},
#   766: {'position': (np.int64(122), np.int64(20)),
#    '^': np.int64(776),
#    'v': np.int64(752),
#    '<': np.int64(698),
#    '>': np.int64(793)},
#   767: {'position': (np.int64(122), np.int64(53)),
#    '^': np.int64(782),
#    'v': np.int64(756),
#    '<': np.int64(682),
#    '>': None},
#   768: {'position': (np.int64(122), np.int64(54)),
#    '^': np.int64(782),
#    'v': np.int64(756),
#    '<': np.int64(725),
#    '>': None},
#   769: {'position': (np.int64(122), np.int64(81)),
#    '^': np.int64(784),
#    'v': np.int64(758),
#    '<': np.int64(586),
#    '>': np.int64(805)},
#   770: {'position': (np.int64(122), np.int64(111)),
#    '^': None,
#    'v': np.int64(760),
#    '<': np.int64(384),
#    '>': None},
#   771: {'position': (np.int64(122), np.int64(112)),
#    '^': None,
#    'v': np.int64(760),
#    '<': np.int64(750),
#    '>': None},
#   772: {'position': (np.int64(122), np.int64(116)),
#    '^': None,
#    'v': np.int64(760),
#    '<': np.int64(761),
#    '>': None},
#   773: {'position': (np.int64(122), np.int64(121)),
#    '^': None,
#    'v': np.int64(761),
#    '<': np.int64(686),
#    '>': None},
#   774: {'position': (np.int64(123), np.int64(13)),
#    '^': np.int64(787),
#    'v': np.int64(765),
#    '<': np.int64(654),
#    '>': None},
#   775: {'position': (np.int64(123), np.int64(14)),
#    '^': np.int64(787),
#    'v': np.int64(765),
#    '<': np.int64(752),
#    '>': np.int64(786)},
#   776: {'position': (np.int64(123), np.int64(25)),
#    '^': np.int64(787),
#    'v': np.int64(766),
#    '<': np.int64(700),
#    '>': np.int64(804)},
#   777: {'position': (np.int64(123), np.int64(26)),
#    '^': np.int64(787),
#    'v': np.int64(766),
#    '<': np.int64(364),
#    '>': None},
#   778: {'position': (np.int64(123), np.int64(30)),
#    '^': np.int64(787),
#    'v': np.int64(766),
#    '<': np.int64(511),
#    '>': None},
#   779: {'position': (np.int64(123), np.int64(37)),
#    '^': np.int64(787),
#    'v': np.int64(766),
#    '<': np.int64(644),
#    '>': None},
#   780: {'position': (np.int64(123), np.int64(45)),
#    '^': np.int64(787),
#    'v': np.int64(766),
#    '<': np.int64(668),
#    '>': None},
#   781: {'position': (np.int64(123), np.int64(47)),
#    '^': np.int64(787),
#    'v': np.int64(766),
#    '<': np.int64(711),
#    '>': None},
#   782: {'position': (np.int64(123), np.int64(64)),
#    '^': np.int64(788),
#    'v': np.int64(768),
#    '<': np.int64(211),
#    '>': None},
#   783: {'position': (np.int64(123), np.int64(66)),
#    '^': np.int64(788),
#    'v': np.int64(768),
#    '<': np.int64(287),
#    '>': np.int64(790)},
#   784: {'position': (np.int64(123), np.int64(90)),
#    '^': None,
#    'v': np.int64(769),
#    '<': np.int64(727),
#    '>': None},
#   785: {'position': (np.int64(123), np.int64(104)),
#    '^': None,
#    'v': np.int64(769),
#    '<': np.int64(610),
#    '>': np.int64(814)},
#   786: {'position': (np.int64(124), np.int64(13)),
#    '^': np.int64(789),
#    'v': None,
#    '<': np.int64(775),
#    '>': None},
#   787: {'position': (np.int64(124), np.int64(50)),
#    '^': np.int64(790),
#    'v': np.int64(781),
#    '<': np.int64(756),
#    '>': None},
#   788: {'position': (np.int64(124), np.int64(87)),
#    '^': np.int64(791),
#    'v': np.int64(783),
#    '<': np.int64(703),
#    '>': None},
#   789: {'position': (np.int64(125), np.int64(34)),
#    '^': np.int64(794),
#    'v': np.int64(786),
#    '<': np.int64(731),
#    '>': None},
#   790: {'position': (np.int64(125), np.int64(65)),
#    '^': None,
#    'v': np.int64(787),
#    '<': np.int64(783),
#    '>': None},
#   791: {'position': (np.int64(125), np.int64(105)),
#    '^': None,
#    'v': np.int64(788),
#    '<': np.int64(663),
#    '>': None},
#   792: {'position': (np.int64(125), np.int64(122)),
#    '^': None,
#    'v': np.int64(788),
#    '<': np.int64(687),
#    '>': None},
#   793: {'position': (np.int64(126), np.int64(19)),
#    '^': np.int64(797),
#    'v': None,
#    '<': np.int64(766),
#    '>': None},
#   794: {'position': (np.int64(126), np.int64(35)),
#    '^': np.int64(797),
#    'v': np.int64(789),
#    '<': np.int64(526),
#    '>': None},
#   795: {'position': (np.int64(127), np.int64(4)),
#    '^': np.int64(803),
#    'v': None,
#    '<': np.int64(751),
#    '>': None},
#   796: {'position': (np.int64(127), np.int64(13)),
#    '^': np.int64(803),
#    'v': None,
#    '<': np.int64(775),
#    '>': None},
#   797: {'position': (np.int64(127), np.int64(47)),
#    '^': np.int64(805),
#    'v': np.int64(794),
#    '<': np.int64(711),
#    '>': None},
#   798: {'position': (np.int64(127), np.int64(56)),
#    '^': np.int64(805),
#    'v': np.int64(794),
#    '<': np.int64(672),
#    '>': None},
#   799: {'position': (np.int64(127), np.int64(94)),
#    '^': np.int64(808),
#    'v': np.int64(794),
#    '<': np.int64(574),
#    '>': None},
#   800: {'position': (np.int64(127), np.int64(102)),
#    '^': np.int64(808),
#    'v': np.int64(794),
#    '<': np.int64(740),
#    '>': None},
#   801: {'position': (np.int64(127), np.int64(119)),
#    '^': None,
#    'v': np.int64(794),
#    '<': np.int64(685),
#    '>': None},
#   802: {'position': (np.int64(127), np.int64(128)),
#    '^': None,
#    'v': np.int64(794),
#    '<': np.int64(744),
#    '>': None},
#   803: {'position': (np.int64(128), np.int64(17)),
#    '^': np.int64(810),
#    'v': np.int64(796),
#    '<': np.int64(659),
#    '>': None},
#   804: {'position': (np.int64(128), np.int64(24)),
#    '^': np.int64(810),
#    'v': np.int64(796),
#    '<': np.int64(776),
#    '>': None},
#   805: {'position': (np.int64(128), np.int64(80)),
#    '^': np.int64(813),
#    'v': np.int64(798),
#    '<': np.int64(769),
#    '>': None},
#   806: {'position': (np.int64(128), np.int64(81)),
#    '^': np.int64(813),
#    'v': np.int64(798),
#    '<': np.int64(586),
#    '>': None},
#   807: {'position': (np.int64(128), np.int64(87)),
#    '^': np.int64(813),
#    'v': np.int64(798),
#    '<': np.int64(703),
#    '>': None},
#   808: {'position': (np.int64(128), np.int64(106)),
#    '^': None,
#    'v': np.int64(800),
#    '<': np.int64(701),
#    '>': None},
#   809: {'position': (np.int64(129), np.int64(15)),
#    'v': None,
#    '<': np.int64(706),
#    '>': None},
#   810: {'position': (np.int64(129), np.int64(39)),
#    'v': np.int64(804),
#    '<': np.int64(579),
#    '>': None},
#   811: {'position': (np.int64(129), np.int64(41)),
#    'v': np.int64(804),
#    '<': np.int64(755),
#    '>': None},
#   812: {'position': (np.int64(129), np.int64(50)),
#    'v': np.int64(804),
#    '<': np.int64(756),
#    '>': None},
#   813: {'position': (np.int64(129), np.int64(94)),
#    'v': np.int64(807),
#    '<': np.int64(574),
#    '>': None},
#   814: {'position': (np.int64(129), np.int64(103)),
#    'v': np.int64(807),
#    '<': np.int64(785),
#    '>': None}})

# %%
def get_full_route(initial_position, initial_direction, map_size, blocks_dict, blocks_pos):
    # Find the first block in the initial direction
    current_position = get_first_block_in_direction(initial_position, initial_direction, map_size, blocks_pos)
    current_direction = initial_direction
    route = []
    while current_position is not None:
        if (current_position, current_direction) in route:
            route.append((current_position, current_direction))
            route.append('LOOP')
            break  # Avoid infinite loops
        route.append((current_position, current_direction))
        current_position = blocks_dict[current_position][current_direction]
        current_direction = guard_direction_shift[current_direction]
    return route

# %%
def insert_new_block(map_matrix, new_block):
    new_map_matrix = map_matrix.copy()
    new_map_matrix[tuple(new_block)] = '#'
    new_blocks_pos = np.where(new_map_matrix == '#')
    return new_blocks_pos

# %%
full_route = get_full_route((40,40), '^', map_size, blocks_dict, blocks_pos)
full_route
# Out:
# [(np.int64(229), '^'),
#  (np.int64(234), '>'),
#  (np.int64(268), 'v'),
#  (np.int64(261), '<')]

# %%
# Prepare all candidate positions for the new block
block_candidate_positions = np.where(visited_map == 'X')
print(block_candidate_positions, len(block_candidate_positions[0]))
# Out:
# (array([  5,   5,   5, ..., 127, 128, 129]), array([64, 65, 66, ..., 73, 73, 73])) 5199

# %%
guard_position
# Out:
# (np.int64(89), np.int64(74))

# %%
total_loops = 0
for i in range(len(block_candidate_positions[0])):
    if i % 100 == 0:
        print(f'Processing candidate {i}/{len(block_candidate_positions[0])}')
    test_new_block = (block_candidate_positions[0][i], block_candidate_positions[1][i])
    new_blocks_pos = insert_new_block(map_matrix, test_new_block)
    new_blocks_dict = create_blocks_dict(new_blocks_pos)
    new_full_route = get_full_route(guard_position, '^', map_size, new_blocks_dict, new_blocks_pos)
    if 'LOOP' in new_full_route:
        total_loops += 1


print(total_loops)
# Out:
# Processing candidate 0/5199
# Processing candidate 100/5199
# Processing candidate 200/5199
# Processing candidate 300/5199
# Processing candidate 400/5199
# Processing candidate 500/5199
# Processing candidate 600/5199
# Processing candidate 700/5199
# Processing candidate 800/5199
# Processing candidate 900/5199
# Processing candidate 1000/5199
# Processing candidate 1100/5199
# Processing candidate 1200/5199
# Processing candidate 1300/5199
# Processing candidate 1400/5199
# Processing candidate 1500/5199
# Processing candidate 1600/5199
# Processing candidate 1700/5199
# Processing candidate 1800/5199
# Processing candidate 1900/5199
# Processing candidate 2000/5199
# Processing candidate 2100/5199
# Processing candidate 2200/5199
# Processing candidate 2300/5199
# Processing candidate 2400/5199
# Processing candidate 2500/5199
# Processing candidate 2600/5199
# Processing candidate 2700/5199
# Processing candidate 2800/5199
# Processing candidate 2900/5199
# Processing candidate 3000/5199
# Processing candidate 3100/5199
# Processing candidate 3200/5199
# Processing candidate 3300/5199
# Processing candidate 3400/5199
# Processing candidate 3500/5199
# Processing candidate 3600/5199
# Processing candidate 3700/5199
# Processing candidate 3800/5199
# Processing candidate 3900/5199
# Processing candidate 4000/5199
# Processing candidate 4100/5199
# Processing candidate 4200/5199
# Processing candidate 4300/5199
# Processing candidate 4400/5199
# Processing candidate 4500/5199
# Processing candidate 4600/5199
# Processing candidate 4700/5199
# Processing candidate 4800/5199
# Processing candidate 4900/5199
# Processing candidate 5000/5199
# Processing candidate 5100/5199
# 1915
