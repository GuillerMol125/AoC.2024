# %%
import sys, os
import numpy as np
import pandas as pd
from utils.utils import read_txt, read_txt_np_int
from functools import lru_cache

# %% [markdown]
# # INPUT

# %%
inputfilename = './inputs/day13A.txt'

inputdata = read_txt(inputfilename)

testdata = ["Button A: X+94, Y+34",
"Button B: X+22, Y+67",
"Prize: X=8400, Y=5400",

"Button A: X+26, Y+66",
"Button B: X+67, Y+21",
"Prize: X=12748, Y=12176",

"Button A: X+17, Y+86",
"Button B: X+84, Y+37",
"Prize: X=7870, Y=6450",

"Button A: X+69, Y+23",
"Button B: X+27, Y+71",
"Prize: X=18641, Y=10279"]

# %%
data_to_use = inputdata

claw_machines = []
for line in data_to_use:
    if "Button A: " in line:
        buttonA = np.array([int(x.split('+')[1]) for x in line.split(': ')[1].split(', ')])
    if "Button B: " in line:
        buttonB = np.array([int(x.split('+')[1]) for x in line.split(': ')[1].split(', ')])
    if "Prize: " in line:
        prize = np.array([int(x.split('=')[1]) for x in line.split(': ')[1].split(', ')])
        claw_machines.append({'ButtonA': buttonA, 'ButtonB': buttonB, 'Prize': prize})

print(len(claw_machines))
claw_machines
# Out:
# 320
# [{'ButtonA': array([75, 30]),
#   'ButtonB': array([57, 75]),
#   'Prize': array([9885, 8130])},
#  {'ButtonA': array([48, 12]),
#   'ButtonB': array([20, 52]),
#   'Prize': array([1320, 5260])},
#  {'ButtonA': array([20, 86]),
#   'ButtonB': array([46, 33]),
#   'Prize': array([370, 767])},
#  {'ButtonA': array([21, 77]),
#   'ButtonB': array([65, 36]),
#   'Prize': array([4616, 8832])},
#  {'ButtonA': array([49, 88]),
#   'ButtonB': array([90, 36]),
#   'Prize': array([3292, 5284])},
#  {'ButtonA': array([46, 13]),
#   'ButtonB': array([11, 71]),
#   'Prize': array([6610, 7336])},
#  {'ButtonA': array([55, 23]),
#   'ButtonB': array([25, 47]),
#   'Prize': array([8960, 6506])},
#  {'ButtonA': array([19, 90]),
#   'ButtonB': array([91, 28]),
#   'Prize': array([1245, 3076])},
#  {'ButtonA': array([77, 15]),
#   'ButtonB': array([55, 57]),
#   'Prize': array([7535, 2301])},
#  {'ButtonA': array([29, 59]),
#   'ButtonB': array([39, 11]),
#   'Prize': array([15636,  3044])},
#  {'ButtonA': array([17, 94]),
#   'ButtonB': array([68, 34]),
#   'Prize': array([4607, 4612])},
#  {'ButtonA': array([56, 17]),
#   'ButtonB': array([11, 52]),
#   'Prize': array([9639, 2048])},
#  {'ButtonA': array([63, 49]),
#   'ButtonB': array([14, 94]),
#   'Prize': array([3703, 9529])},
#  {'ButtonA': array([54, 28]),
#   'ButtonB': array([22, 48]),
#   'Prize': array([11978, 11172])},
#  {'ButtonA': array([46, 11]),
#   'ButtonB': array([36, 61]),
#   'Prize': array([ 2678, 17058])},
#  {'ButtonA': array([66, 34]),
#   'ButtonB': array([14, 36]),
#   'Prize': array([15424,  3726])},
#  {'ButtonA': array([17, 72]),
#   'ButtonB': array([84, 66]),
#   'Prize': array([6233, 9882])},
#  {'ButtonA': array([17, 98]),
#   'ButtonB': array([86, 40]),
#   'Prize': array([5832, 9920])},
#  {'ButtonA': array([23, 48]),
#   'ButtonB': array([30, 13]),
#   'Prize': array([16304, 10705])},
#  {'ButtonA': array([49, 31]),
#   'ButtonB': array([25, 86]),
#   'Prize': array([3496, 8037])},
#  {'ButtonA': array([81, 24]),
#   'ButtonB': array([34, 89]),
#   'Prize': array([4240, 5834])},
#  {'ButtonA': array([35, 53]),
#   'ButtonB': array([70, 15]),
#   'Prize': array([4305, 1605])},
#  {'ButtonA': array([69, 19]),
#   'ButtonB': array([22, 60]),
#   'Prize': array([8042, 6368])},
#  {'ButtonA': array([22, 25]),
#   'ButtonB': array([44, 14]),
#   'Prize': array([3916, 2506])},
#  {'ButtonA': array([39, 53]),
#   'ButtonB': array([96, 11]),
#   'Prize': array([9240, 4553])},
#  {'ButtonA': array([70, 55]),
#   'ButtonB': array([18, 86]),
#   'Prize': array([5672, 7259])},
#  {'ButtonA': array([62, 27]),
#   'ButtonB': array([21, 54]),
#   'Prize': array([ 1842, 13220])},
#  {'ButtonA': array([17, 53]),
#   'ButtonB': array([46, 19]),
#   'Prize': array([ 7487, 19043])},
#  {'ButtonA': array([67, 25]),
#   'ButtonB': array([24, 63]),
#   'Prize': array([5154, 7272])},
#  {'ButtonA': array([59, 20]),
#   'ButtonB': array([12, 37]),
#   'Prize': array([17990,  1825])},
#  {'ButtonA': array([70, 24]),
#   'ButtonB': array([17, 58]),
#   'Prize': array([8465, 4706])},
#  {'ButtonA': array([16, 56]),
#   'ButtonB': array([56, 15]),
#   'Prize': array([10488, 19753])},
#  {'ButtonA': array([27, 16]),
#   'ButtonB': array([25, 47]),
#   'Prize': array([ 2997, 11753])},
#  {'ButtonA': array([66, 29]),
#   'ButtonB': array([26, 72]),
#   'Prize': array([2270, 5056])},
#  {'ButtonA': array([86, 62]),
#   'ButtonB': array([18, 89]),
#   'Prize': array([7356, 8040])},
#  {'ButtonA': array([95, 41]),
#   'ButtonB': array([51, 87]),
#   'Prize': array([2737, 2611])},
#  {'ButtonA': array([11, 52]),
#   'ButtonB': array([63, 15]),
#   'Prize': array([13818,  8890])},
#  {'ButtonA': array([24, 62]),
#   'ButtonB': array([58, 17]),
#   'Prize': array([ 4918, 16511])},
#  {'ButtonA': array([11, 47]),
#   'ButtonB': array([63, 18]),
#   'Prize': array([ 6709, 14881])},
#  {'ButtonA': array([48, 39]),
#   'ButtonB': array([17, 76]),
#   'Prize': array([4539, 8352])},
#  {'ButtonA': array([22, 49]),
#   'ButtonB': array([66, 17]),
#   'Prize': array([7260, 3430])},
#  {'ButtonA': array([80, 32]),
#   'ButtonB': array([11, 61]),
#   'Prize': array([10025,  7247])},
#  {'ButtonA': array([57, 29]),
#   'ButtonB': array([23, 48]),
#   'Prize': array([5957, 9914])},
#  {'ButtonA': array([38, 16]),
#   'ButtonB': array([50, 99]),
#   'Prize': array([5284, 9396])},
#  {'ButtonA': array([34, 17]),
#   'ButtonB': array([15, 38]),
#   'Prize': array([16255, 17811])},
#  {'ButtonA': array([47, 11]),
#   'ButtonB': array([29, 63]),
#   'Prize': array([6648, 3342])},
#  {'ButtonA': array([68, 37]),
#   'ButtonB': array([25, 99]),
#   'Prize': array([3930, 7433])},
#  {'ButtonA': array([92, 30]),
#   'ButtonB': array([21, 97]),
#   'Prize': array([3872, 9196])},
#  {'ButtonA': array([26, 82]),
#   'ButtonB': array([59, 11]),
#   'Prize': array([3307, 4683])},
#  {'ButtonA': array([62, 21]),
#   'ButtonB': array([28, 67]),
#   'Prize': array([13320, 17068])},
#  {'ButtonA': array([77, 47]),
#   'ButtonB': array([11, 45]),
#   'Prize': array([5391, 5509])},
#  {'ButtonA': array([16, 48]),
#   'ButtonB': array([71, 29]),
#   'Prize': array([ 5100, 17124])},
#  {'ButtonA': array([15, 56]),
#   'ButtonB': array([79, 34]),
#   'Prize': array([ 2175, 16304])},
#  {'ButtonA': array([45, 13]),
#   'ButtonB': array([84, 93]),
#   'Prize': array([10653,  9401])},
#  {'ButtonA': array([54, 30]),
#   'ButtonB': array([32, 60]),
#   'Prize': array([6564, 9020])},
#  {'ButtonA': array([42, 32]),
#   'ButtonB': array([12, 30]),
#   'Prize': array([3156, 2488])},
#  {'ButtonA': array([44, 16]),
#   'ButtonB': array([23, 55]),
#   'Prize': array([6028, 6296])},
#  {'ButtonA': array([68, 19]),
#   'ButtonB': array([30, 80]),
#   'Prize': array([17552,  1101])},
#  {'ButtonA': array([19, 77]),
#   'ButtonB': array([51, 12]),
#   'Prize': array([10654,  3135])},
#  {'ButtonA': array([99, 14]),
#   'ButtonB': array([37, 88]),
#   'Prize': array([3609, 3490])},
#  {'ButtonA': array([33, 13]),
#   'ButtonB': array([18, 61]),
#   'Prize': array([ 1742, 12692])},
#  {'ButtonA': array([81, 17]),
#   'ButtonB': array([64, 60]),
#   'Prize': array([3492, 1152])},
#  {'ButtonA': array([51, 16]),
#   'ButtonB': array([19, 73]),
#   'Prize': array([16809, 11712])},
#  {'ButtonA': array([74, 23]),
#   'ButtonB': array([12, 48]),
#   'Prize': array([12182, 10265])},
#  {'ButtonA': array([63, 15]),
#   'ButtonB': array([28, 81]),
#   'Prize': array([10903,  6794])},
#  {'ButtonA': array([14, 72]),
#   'ButtonB': array([70, 16]),
#   'Prize': array([11190, 10664])},
#  {'ButtonA': array([37, 11]),
#   'ButtonB': array([27, 67]),
#   'Prize': array([3354, 8452])},
#  {'ButtonA': array([33, 41]),
#   'ButtonB': array([77, 17]),
#   'Prize': array([5566, 2038])},
#  {'ButtonA': array([50, 12]),
#   'ButtonB': array([17, 50]),
#   'Prize': array([10907, 18238])},
#  {'ButtonA': array([55, 15]),
#   'ButtonB': array([15, 70]),
#   'Prize': array([ 7555, 15690])},
#  {'ButtonA': array([46, 24]),
#   'ButtonB': array([33, 61]),
#   'Prize': array([11745,  2657])},
#  {'ButtonA': array([58, 43]),
#   'ButtonB': array([28, 99]),
#   'Prize': array([4076, 6308])},
#  {'ButtonA': array([54, 99]),
#   'ButtonB': array([74, 36]),
#   'Prize': array([4050, 4734])},
#  {'ButtonA': array([34, 18]),
#   'ButtonB': array([20, 55]),
#   'Prize': array([10578, 15741])},
#  {'ButtonA': array([69, 18]),
#   'ButtonB': array([52, 62]),
#   'Prize': array([8509, 6482])},
#  {'ButtonA': array([13, 73]),
#   'ButtonB': array([96, 56]),
#   'Prize': array([3216, 5016])},
#  {'ButtonA': array([11, 27]),
#   'ButtonB': array([77, 50]),
#   'Prize': array([13190,  1791])},
#  {'ButtonA': array([35, 70]),
#   'ButtonB': array([54, 15]),
#   'Prize': array([2511, 2325])},
#  {'ButtonA': array([52, 21]),
#   'ButtonB': array([34, 51]),
#   'Prize': array([3456, 2961])},
#  {'ButtonA': array([16, 81]),
#   'ButtonB': array([90, 79]),
#   'Prize': array([1376, 3953])},
#  {'ButtonA': array([34, 13]),
#   'ButtonB': array([36, 55]),
#   'Prize': array([13586,  3897])},
#  {'ButtonA': array([27, 59]),
#   'ButtonB': array([53, 25]),
#   'Prize': array([5121, 1273])},
#  {'ButtonA': array([63, 15]),
#   'ButtonB': array([30, 73]),
#   'Prize': array([13970, 10239])},
#  {'ButtonA': array([86, 51]),
#   'ButtonB': array([46, 97]),
#   'Prize': array([1454, 2675])},
#  {'ButtonA': array([25, 93]),
#   'ButtonB': array([59, 11]),
#   'Prize': array([5324, 7088])},
#  {'ButtonA': array([43, 19]),
#   'ButtonB': array([29, 47]),
#   'Prize': array([19347,  5901])},
#  {'ButtonA': array([24, 68]),
#   'ButtonB': array([52, 12]),
#   'Prize': array([6632, 6552])},
#  {'ButtonA': array([39, 11]),
#   'ButtonB': array([12, 72]),
#   'Prize': array([18431,   819])},
#  {'ButtonA': array([14, 35]),
#   'ButtonB': array([61, 43]),
#   'Prize': array([3166, 1111])},
#  {'ButtonA': array([76, 48]),
#   'ButtonB': array([29, 72]),
#   'Prize': array([7155, 4680])},
#  {'ButtonA': array([24, 50]),
#   'ButtonB': array([46, 19]),
#   'Prize': array([16134,  3617])},
#  {'ButtonA': array([48, 72]),
#   'ButtonB': array([66, 11]),
#   'Prize': array([9204, 7294])},
#  {'ButtonA': array([66, 62]),
#   'ButtonB': array([22, 77]),
#   'Prize': array([3520, 7419])},
#  {'ButtonA': array([14, 47]),
#   'ButtonB': array([68, 39]),
#   'Prize': array([4250, 9875])},
#  {'ButtonA': array([67, 14]),
#   'ButtonB': array([58, 59]),
#   'Prize': array([6096, 1977])},
#  {'ButtonA': array([41, 21]),
#   'ButtonB': array([19, 38]),
#   'Prize': array([5924, 5047])},
#  {'ButtonA': array([20, 83]),
#   'ButtonB': array([43, 35]),
#   'Prize': array([4668, 8470])},
#  {'ButtonA': array([37, 95]),
#   'ButtonB': array([72, 46]),
#   'Prize': array([4106, 7904])},
#  {'ButtonA': array([34, 11]),
#   'ButtonB': array([18, 40]),
#   'Prize': array([13094, 14354])},
#  {'ButtonA': array([51, 85]),
#   'ButtonB': array([70, 16]),
#   'Prize': array([3158, 2042])},
#  {'ButtonA': array([96, 13]),
#   'ButtonB': array([28, 22]),
#   'Prize': array([4812, 1471])},
#  {'ButtonA': array([54, 22]),
#   'ButtonB': array([47, 67]),
#   'Prize': array([5636, 3636])},
#  {'ButtonA': array([26, 51]),
#   'ButtonB': array([23, 13]),
#   'Prize': array([18952, 12022])},
#  {'ButtonA': array([35, 55]),
#   'ButtonB': array([46, 17]),
#   'Prize': array([  660, 10525])},
#  {'ButtonA': array([33, 67]),
#   'ButtonB': array([48, 18]),
#   'Prize': array([10958,  9870])},
#  {'ButtonA': array([11, 43]),
#   'ButtonB': array([70, 32]),
#   'Prize': array([11658,  1306])},
#  {'ButtonA': array([25, 11]),
#   'ButtonB': array([27, 42]),
#   'Prize': array([2311, 2312])},
#  {'ButtonA': array([74, 12]),
#   'ButtonB': array([11, 39]),
#   'Prize': array([4519, 6941])},
#  {'ButtonA': array([63, 13]),
#   'ButtonB': array([15, 67]),
#   'Prize': array([2054, 5500])},
#  {'ButtonA': array([64, 25]),
#   'ButtonB': array([16, 65]),
#   'Prize': array([ 7152, 12645])},
#  {'ButtonA': array([44, 78]),
#   'ButtonB': array([51, 19]),
#   'Prize': array([15398,  6504])},
#  {'ButtonA': array([17, 91]),
#   'ButtonB': array([62, 41]),
#   'Prize': array([5992, 9386])},
#  {'ButtonA': array([33, 13]),
#   'ButtonB': array([11, 43]),
#   'Prize': array([16490,  4206])},
#  {'ButtonA': array([83, 43]),
#   'ButtonB': array([55, 97]),
#   'Prize': array([9426, 6596])},
#  {'ButtonA': array([14, 43]),
#   'ButtonB': array([20, 11]),
#   'Prize': array([ 9268, 16426])},
#  {'ButtonA': array([76, 24]),
#   'ButtonB': array([37, 98]),
#   'Prize': array([2006, 4604])},
#  {'ButtonA': array([63, 78]),
#   'ButtonB': array([49, 16]),
#   'Prize': array([5712, 3588])},
#  {'ButtonA': array([59, 13]),
#   'ButtonB': array([43, 43]),
#   'Prize': array([7668, 4908])},
#  {'ButtonA': array([50, 15]),
#   'ButtonB': array([31, 54]),
#   'Prize': array([11845,  4550])},
#  {'ButtonA': array([18, 60]),
#   'ButtonB': array([67, 31]),
#   'Prize': array([1030, 5800])},
#  {'ButtonA': array([13, 67]),
#   'ButtonB': array([52, 14]),
#   'Prize': array([8310, 6360])},
#  {'ButtonA': array([22, 99]),
#   'ButtonB': array([40, 27]),
#   'Prize': array([5070, 8892])},
#  {'ButtonA': array([82, 48]),
#   'ButtonB': array([14, 41]),
#   'Prize': array([13302,  1468])},
#  {'ButtonA': array([59, 20]),
#   'ButtonB': array([13, 28]),
#   'Prize': array([11713, 11164])},
#  {'ButtonA': array([44, 17]),
#   'ButtonB': array([21, 45]),
#   'Prize': array([19051,  1345])},
#  {'ButtonA': array([29, 46]),
#   'ButtonB': array([41, 12]),
#   'Prize': array([ 2664, 16794])},
#  {'ButtonA': array([11, 88]),
#   'ButtonB': array([85, 30]),
#   'Prize': array([3809, 9672])},
#  {'ButtonA': array([15, 65]),
#   'ButtonB': array([77, 29]),
#   'Prize': array([2350, 4090])},
#  {'ButtonA': array([40, 23]),
#   'ButtonB': array([18, 37]),
#   'Prize': array([1748, 7833])},
#  {'ButtonA': array([77, 45]),
#   'ButtonB': array([14, 37]),
#   'Prize': array([16594,  7835])},
#  {'ButtonA': array([79, 19]),
#   'ButtonB': array([34, 89]),
#   'Prize': array([5520, 2055])},
#  {'ButtonA': array([17, 38]),
#   'ButtonB': array([74, 51]),
#   'Prize': array([10003,  8167])},
#  {'ButtonA': array([11, 38]),
#   'ButtonB': array([48, 12]),
#   'Prize': array([11879, 13058])},
#  {'ButtonA': array([92, 11]),
#   'ButtonB': array([67, 53]),
#   'Prize': array([8641, 1708])},
#  {'ButtonA': array([12, 40]),
#   'ButtonB': array([61, 33]),
#   'Prize': array([17814,  2806])},
#  {'ButtonA': array([81, 13]),
#   'ButtonB': array([13, 60]),
#   'Prize': array([ 6107, 13017])},
#  {'ButtonA': array([55, 26]),
#   'ButtonB': array([19, 32]),
#   'Prize': array([19498, 13758])},
#  {'ButtonA': array([86, 12]),
#   'ButtonB': array([23, 43]),
#   'Prize': array([4245, 1985])},
#  {'ButtonA': array([12, 46]),
#   'ButtonB': array([75, 12]),
#   'Prize': array([11804,  7922])},
#  {'ButtonA': array([15, 49]),
#   'ButtonB': array([42, 24]),
#   'Prize': array([16187, 13179])},
#  {'ButtonA': array([23, 53]),
#   'ButtonB': array([56, 30]),
#   'Prize': array([9137, 4149])},
#  {'ButtonA': array([60, 18]),
#   'ButtonB': array([30, 71]),
#   'Prize': array([13100,  3902])},
#  {'ButtonA': array([86, 46]),
#   'ButtonB': array([11, 48]),
#   'Prize': array([ 5083, 12988])},
#  {'ButtonA': array([32, 64]),
#   'ButtonB': array([46, 15]),
#   'Prize': array([8222, 3287])},
#  {'ButtonA': array([81, 33]),
#   'ButtonB': array([54, 98]),
#   'Prize': array([7614, 5838])},
#  {'ButtonA': array([48, 29]),
#   'ButtonB': array([13, 39]),
#   'Prize': array([9514,  972])},
#  {'ButtonA': array([19, 81]),
#   'ButtonB': array([72, 51]),
#   'Prize': array([4588, 6762])},
#  {'ButtonA': array([37, 16]),
#   'ButtonB': array([17, 36]),
#   'Prize': array([11124, 15692])},
#  {'ButtonA': array([24, 73]),
#   'ButtonB': array([97, 40]),
#   'Prize': array([6593, 3476])},
#  {'ButtonA': array([17, 28]),
#   'ButtonB': array([56, 29]),
#   'Prize': array([10318, 12337])},
#  {'ButtonA': array([44, 37]),
#   'ButtonB': array([19, 53]),
#   'Prize': array([ 891, 1971])},
#  {'ButtonA': array([35, 89]),
#   'ButtonB': array([91, 57]),
#   'Prize': array([2639, 4269])},
#  {'ButtonA': array([15, 72]),
#   'ButtonB': array([58, 17]),
#   'Prize': array([ 8803, 14919])},
#  {'ButtonA': array([36, 53]),
#   'ButtonB': array([37, 13]),
#   'Prize': array([6655, 3303])},
#  {'ButtonA': array([56, 34]),
#   'ButtonB': array([22, 49]),
#   'Prize': array([12614, 18039])},
#  {'ButtonA': array([89, 95]),
#   'ButtonB': array([95, 22]),
#   'Prize': array([2605, 2463])},
#  {'ButtonA': array([16, 73]),
#   'ButtonB': array([75, 73]),
#   'Prize': array([ 7660, 12337])},
#  {'ButtonA': array([85, 26]),
#   'ButtonB': array([65, 89]),
#   'Prize': array([10630,  9403])},
#  {'ButtonA': array([28, 86]),
#   'ButtonB': array([20, 15]),
#   'Prize': array([3620, 8890])},
#  {'ButtonA': array([56, 19]),
#   'ButtonB': array([36, 74]),
#   'Prize': array([13276, 12044])},
#  {'ButtonA': array([29, 55]),
#   'ButtonB': array([40, 13]),
#   'Prize': array([5024, 4185])},
#  {'ButtonA': array([30, 91]),
#   'ButtonB': array([85, 26]),
#   'Prize': array([5250, 8970])},
#  {'ButtonA': array([60, 45]),
#   'ButtonB': array([32, 83]),
#   'Prize': array([4276, 6334])},
#  {'ButtonA': array([60, 22]),
#   'ButtonB': array([23, 54]),
#   'Prize': array([7926, 3710])},
#  {'ButtonA': array([76, 12]),
#   'ButtonB': array([12, 52]),
#   'Prize': array([18788, 14052])},
#  {'ButtonA': array([29, 12]),
#   'ButtonB': array([22, 52]),
#   'Prize': array([5032, 4096])},
#  {'ButtonA': array([12, 41]),
#   'ButtonB': array([30, 12]),
#   'Prize': array([ 9494, 11342])},
#  {'ButtonA': array([14, 55]),
#   'ButtonB': array([74, 16]),
#   'Prize': array([14450, 15167])},
#  {'ButtonA': array([37, 65]),
#   'ButtonB': array([56, 28]),
#   'Prize': array([ 5073, 13165])},
#  {'ButtonA': array([56, 43]),
#   'ButtonB': array([22, 88]),
#   'Prize': array([1676, 1998])},
#  {'ButtonA': array([40, 70]),
#   'ButtonB': array([51, 19]),
#   'Prize': array([ 672, 4288])},
#  {'ButtonA': array([38, 57]),
#   'ButtonB': array([31, 11]),
#   'Prize': array([5526, 5094])},
#  {'ButtonA': array([74, 19]),
#   'ButtonB': array([15, 51]),
#   'Prize': array([6548, 3190])},
#  {'ButtonA': array([22, 46]),
#   'ButtonB': array([31, 16]),
#   'Prize': array([11879,  4424])},
#  {'ButtonA': array([90, 20]),
#   'ButtonB': array([23, 36]),
#   'Prize': array([5397, 2404])},
#  {'ButtonA': array([36, 79]),
#   'ButtonB': array([95, 12]),
#   'Prize': array([8090, 4000])},
#  {'ButtonA': array([57, 14]),
#   'ButtonB': array([19, 61]),
#   'Prize': array([ 1944, 14244])},
#  {'ButtonA': array([65, 14]),
#   'ButtonB': array([31, 83]),
#   'Prize': array([ 1937, 16611])},
#  {'ButtonA': array([16, 44]),
#   'ButtonB': array([43, 28]),
#   'Prize': array([4971, 6360])},
#  {'ButtonA': array([11, 72]),
#   'ButtonB': array([86, 97]),
#   'Prize': array([5217, 6659])},
#  {'ButtonA': array([24, 44]),
#   'ButtonB': array([46, 19]),
#   'Prize': array([10556, 14790])},
#  {'ButtonA': array([71, 85]),
#   'ButtonB': array([44, 11]),
#   'Prize': array([4081, 1760])},
#  {'ButtonA': array([11, 44]),
#   'ButtonB': array([78, 46]),
#   'Prize': array([14445, 18736])},
#  {'ButtonA': array([91, 48]),
#   'ButtonB': array([30, 67]),
#   'Prize': array([5574, 4066])},
#  {'ButtonA': array([23, 49]),
#   'ButtonB': array([54, 25]),
#   'Prize': array([9611, 6047])},
#  {'ButtonA': array([88, 33]),
#   'ButtonB': array([50, 90]),
#   'Prize': array([7884, 5664])},
#  {'ButtonA': array([15, 61]),
#   'ButtonB': array([72, 16]),
#   'Prize': array([ 6827, 10097])},
#  {'ButtonA': array([18, 16]),
#   'ButtonB': array([21, 72]),
#   'Prize': array([1989, 3528])},
#  {'ButtonA': array([66, 30]),
#   'ButtonB': array([12, 26]),
#   'Prize': array([10148,  7988])},
#  {'ButtonA': array([26, 67]),
#   'ButtonB': array([65, 13]),
#   'Prize': array([4475, 4436])},
#  {'ButtonA': array([78, 38]),
#   'ButtonB': array([58, 90]),
#   'Prize': array([6644, 6324])},
#  {'ButtonA': array([24, 12]),
#   'ButtonB': array([24, 43]),
#   'Prize': array([14288,  1017])},
#  {'ButtonA': array([11, 40]),
#   'ButtonB': array([67, 21]),
#   'Prize': array([14990,  2264])},
#  {'ButtonA': array([61, 14]),
#   'ButtonB': array([11, 45]),
#   'Prize': array([ 4429, 12066])},
#  {'ButtonA': array([84, 98]),
#   'ButtonB': array([16, 88]),
#   'Prize': array([ 9188, 16682])},
#  {'ButtonA': array([18, 57]),
#   'ButtonB': array([76, 29]),
#   'Prize': array([ 1140, 19360])},
#  {'ButtonA': array([11, 35]),
#   'ButtonB': array([47, 13]),
#   'Prize': array([ 6934, 19244])},
#  {'ButtonA': array([18, 37]),
#   'ButtonB': array([88, 43]),
#   'Prize': array([5412, 4506])},
#  {'ButtonA': array([37, 14]),
#   'ButtonB': array([26, 69]),
#   'Prize': array([18035, 18988])},
#  {'ButtonA': array([18, 77]),
#   'ButtonB': array([94, 36]),
#   'Prize': array([3680, 5125])},
#  {'ButtonA': array([66, 24]),
#   'ButtonB': array([23, 54]),
#   'Prize': array([4197, 3306])},
#  {'ButtonA': array([62, 26]),
#   'ButtonB': array([27, 62]),
#   'Prize': array([3449, 2916])},
#  {'ButtonA': array([85, 73]),
#   'ButtonB': array([70, 12]),
#   'Prize': array([5620, 2950])},
#  {'ButtonA': array([96, 59]),
#   'ButtonB': array([29, 59]),
#   'Prize': array([10447,  8850])},
#  {'ButtonA': array([23, 11]),
#   'ButtonB': array([13, 27]),
#   'Prize': array([16099,  2429])},
#  {'ButtonA': array([16, 74]),
#   'ButtonB': array([30, 13]),
#   'Prize': array([2742, 6017])},
#  {'ButtonA': array([19, 48]),
#   'ButtonB': array([35, 17]),
#   'Prize': array([ 5143, 19210])},
#  {'ButtonA': array([14, 65]),
#   'ButtonB': array([43, 16]),
#   'Prize': array([11184,  5109])},
#  {'ButtonA': array([66, 24]),
#   'ButtonB': array([24, 68]),
#   'Prize': array([12068, 12320])},
#  {'ButtonA': array([86, 11]),
#   'ButtonB': array([13, 87]),
#   'Prize': array([2909, 5086])},
#  {'ButtonA': array([28, 54]),
#   'ButtonB': array([38, 21]),
#   'Prize': array([15326,  4685])},
#  {'ButtonA': array([90, 41]),
#   'ButtonB': array([19, 86]),
#   'Prize': array([5873, 8631])},
#  {'ButtonA': array([26, 15]),
#   'ButtonB': array([18, 50]),
#   'Prize': array([16498, 15585])},
#  {'ButtonA': array([26, 62]),
#   'ButtonB': array([46, 22]),
#   'Prize': array([16464, 19188])},
#  {'ButtonA': array([80, 30]),
#   'ButtonB': array([69, 96]),
#   'Prize': array([4291, 4344])},
#  {'ButtonA': array([53, 15]),
#   'ButtonB': array([16, 58]),
#   'Prize': array([1465, 4425])},
#  {'ButtonA': array([11, 22]),
#   'ButtonB': array([55, 18]),
#   'Prize': array([15544,  6332])},
#  {'ButtonA': array([26, 74]),
#   'ButtonB': array([72, 25]),
#   'Prize': array([ 7572, 10088])},
#  {'ButtonA': array([11, 48]),
#   'ButtonB': array([52, 26]),
#   'Prize': array([12503,  1044])},
#  {'ButtonA': array([35, 57]),
#   'ButtonB': array([88, 23]),
#   'Prize': array([9481, 3770])},
#  {'ButtonA': array([22, 62]),
#   'ButtonB': array([97, 63]),
#   'Prize': array([7253, 9291])},
#  {'ButtonA': array([11, 53]),
#   'ButtonB': array([44, 13]),
#   'Prize': array([4565, 4483])},
#  {'ButtonA': array([36, 12]),
#   'ButtonB': array([22, 58]),
#   'Prize': array([18656,  8528])},
#  {'ButtonA': array([48, 90]),
#   'ButtonB': array([71, 17]),
#   'Prize': array([11094, 10350])},
#  {'ButtonA': array([95, 99]),
#   'ButtonB': array([65, 14]),
#   'Prize': array([13680, 10172])},
#  {'ButtonA': array([20, 99]),
#   'ButtonB': array([65, 54]),
#   'Prize': array([1790, 4041])},
#  {'ButtonA': array([76, 23]),
#   'ButtonB': array([11, 38]),
#   'Prize': array([ 1899, 14197])},
#  {'ButtonA': array([34, 72]),
#   'ButtonB': array([72, 30]),
#   'Prize': array([7384, 6084])},
#  {'ButtonA': array([74, 18]),
#   'ButtonB': array([13, 74]),
#   'Prize': array([ 3317, 16128])},
#  {'ButtonA': array([85, 47]),
#   'ButtonB': array([11, 50]),
#   'Prize': array([13636,  9893])},
#  {'ButtonA': array([13, 25]),
#   'ButtonB': array([42, 18]),
#   'Prize': array([  604, 17884])},
#  {'ButtonA': array([94, 64]),
#   'ButtonB': array([14, 86]),
#   'Prize': array([3832, 8650])},
#  {'ButtonA': array([88, 19]),
#   'ButtonB': array([29, 70]),
#   'Prize': array([4698, 5731])},
#  {'ButtonA': array([59, 15]),
#   'ButtonB': array([18, 59]),
#   'Prize': array([ 7140, 10039])},
#  {'ButtonA': array([67, 12]),
#   'ButtonB': array([15, 71]),
#   'Prize': array([19205, 18916])},
#  {'ButtonA': array([33, 17]),
#   'ButtonB': array([41, 94]),
#   'Prize': array([2469, 3021])},
#  {'ButtonA': array([22, 70]),
#   'ButtonB': array([62, 11]),
#   'Prize': array([18330, 16422])},
#  {'ButtonA': array([68, 21]),
#   'ButtonB': array([15, 64]),
#   'Prize': array([19117,  8318])},
#  {'ButtonA': array([12, 75]),
#   'ButtonB': array([85, 81]),
#   'Prize': array([ 917, 3480])},
#  {'ButtonA': array([89, 14]),
#   'ButtonB': array([66, 96]),
#   'Prize': array([10202,  5372])},
#  {'ButtonA': array([25, 63]),
#   'ButtonB': array([29, 11]),
#   'Prize': array([6651, 9357])},
#  {'ButtonA': array([83, 48]),
#   'ButtonB': array([17, 76]),
#   'Prize': array([6142, 9044])},
#  {'ButtonA': array([49, 12]),
#   'ButtonB': array([19, 78]),
#   'Prize': array([1932, 8870])},
#  {'ButtonA': array([41, 13]),
#   'ButtonB': array([40, 58]),
#   'Prize': array([4784, 3964])},
#  {'ButtonA': array([63, 25]),
#   'ButtonB': array([48, 99]),
#   'Prize': array([6918, 9861])},
#  {'ButtonA': array([44, 18]),
#   'ButtonB': array([28, 67]),
#   'Prize': array([13260,  9568])},
#  {'ButtonA': array([45, 25]),
#   'ButtonB': array([16, 51]),
#   'Prize': array([4854, 6234])},
#  {'ButtonA': array([36, 54]),
#   'ButtonB': array([86, 34]),
#   'Prize': array([1672, 1178])},
#  {'ButtonA': array([37, 33]),
#   'ButtonB': array([21, 75]),
#   'Prize': array([3031, 5967])},
#  {'ButtonA': array([65, 22]),
#   'ButtonB': array([70, 98]),
#   'Prize': array([3585, 3294])},
#  {'ButtonA': array([57, 24]),
#   'ButtonB': array([18, 58]),
#   'Prize': array([10142,  7706])},
#  {'ButtonA': array([99, 17]),
#   'ButtonB': array([25, 78]),
#   'Prize': array([7511, 4754])},
#  {'ButtonA': array([56, 20]),
#   'ButtonB': array([12, 29]),
#   'Prize': array([8284, 2281])},
#  {'ButtonA': array([25, 12]),
#   'ButtonB': array([17, 35]),
#   'Prize': array([17070,  9295])},
#  {'ButtonA': array([16, 58]),
#   'ButtonB': array([47, 18]),
#   'Prize': array([4210, 1676])},
#  {'ButtonA': array([24, 53]),
#   'ButtonB': array([88, 55]),
#   'Prize': array([10184,  9671])},
#  {'ButtonA': array([14, 57]),
#   'ButtonB': array([66, 47]),
#   'Prize': array([5096, 6780])},
#  {'ButtonA': array([91, 18]),
#   'ButtonB': array([32, 47]),
#   'Prize': array([10866,  6013])},
#  {'ButtonA': array([44, 79]),
#   'ButtonB': array([47, 24]),
#   'Prize': array([4800, 7652])},
#  {'ButtonA': array([12, 33]),
#   'ButtonB': array([29, 19]),
#   'Prize': array([ 3304, 17190])},
#  {'ButtonA': array([97, 97]),
#   'ButtonB': array([21, 91]),
#   'Prize': array([4567, 4917])},
#  {'ButtonA': array([25, 80]),
#   'ButtonB': array([96, 51]),
#   'Prize': array([8194, 9824])},
#  {'ButtonA': array([77, 18]),
#   'ButtonB': array([25, 38]),
#   'Prize': array([4063, 1818])},
#  {'ButtonA': array([25, 89]),
#   'ButtonB': array([82, 26]),
#   'Prize': array([3630, 8934])},
#  {'ButtonA': array([13, 32]),
#   'ButtonB': array([76, 55]),
#   'Prize': array([ 1866, 17800])},
#  {'ButtonA': array([49, 14]),
#   'ButtonB': array([32, 58]),
#   'Prize': array([ 9528, 11206])},
#  {'ButtonA': array([23, 54]),
#   'ButtonB': array([59, 32]),
#   'Prize': array([5446, 5958])},
#  {'ButtonA': array([16, 97]),
#   'ButtonB': array([82, 59]),
#   'Prize': array([5482, 6509])},
#  {'ButtonA': array([76, 11]),
#   'ButtonB': array([68, 91]),
#   'Prize': array([704, 670])},
#  {'ButtonA': array([63, 37]),
#   'ButtonB': array([18, 39]),
#   'Prize': array([19241, 10872])},
#  {'ButtonA': array([17, 50]),
#   'ButtonB': array([45, 11]),
#   'Prize': array([13734, 16737])},
#  {'ButtonA': array([44, 20]),
#   'ButtonB': array([29, 66]),
#   'Prize': array([12504, 16028])},
#  {'ButtonA': array([26, 66]),
#   'ButtonB': array([88, 42]),
#   'Prize': array([9394, 8610])},
#  {'ButtonA': array([88, 34]),
#   'ButtonB': array([45, 91]),
#   'Prize': array([10505,  9727])},
#  {'ButtonA': array([19, 73]),
#   'ButtonB': array([85, 83]),
#   'Prize': array([5408, 8112])},
#  {'ButtonA': array([66, 20]),
#   'ButtonB': array([24, 78]),
#   'Prize': array([3510, 6934])},
#  {'ButtonA': array([95, 18]),
#   'ButtonB': array([20, 57]),
#   'Prize': array([4560, 1875])},
#  {'ButtonA': array([29, 28]),
#   'ButtonB': array([16, 60]),
#   'Prize': array([3939, 7100])},
#  {'ButtonA': array([43, 90]),
#   'ButtonB': array([74, 45]),
#   'Prize': array([2994, 2970])},
#  {'ButtonA': array([29, 76]),
#   'ButtonB': array([59, 19]),
#   'Prize': array([ 6326, 17315])},
#  {'ButtonA': array([12, 22]),
#   'ButtonB': array([50, 13]),
#   'Prize': array([10488, 18428])},
#  {'ButtonA': array([68, 12]),
#   'ButtonB': array([22, 80]),
#   'Prize': array([17244,  7404])},
#  {'ButtonA': array([71, 25]),
#   'ButtonB': array([15, 69]),
#   'Prize': array([1116, 3324])},
#  {'ButtonA': array([94, 88]),
#   'ButtonB': array([21, 82]),
#   'Prize': array([6023, 9566])},
#  {'ButtonA': array([12, 49]),
#   'ButtonB': array([55, 28]),
#   'Prize': array([9161, 4148])},
#  {'ButtonA': array([73, 34]),
#   'ButtonB': array([27, 84]),
#   'Prize': array([ 7610, 10544])},
#  {'ButtonA': array([89, 14]),
#   'ButtonB': array([53, 84]),
#   'Prize': array([10027,  7252])},
#  {'ButtonA': array([60, 17]),
#   'ButtonB': array([29, 77]),
#   'Prize': array([11588, 10010])},
#  {'ButtonA': array([70, 19]),
#   'ButtonB': array([42, 47]),
#   'Prize': array([5110, 4769])},
#  {'ButtonA': array([73, 12]),
#   'ButtonB': array([18, 74]),
#   'Prize': array([18979,   508])},
#  {'ButtonA': array([28, 89]),
#   'ButtonB': array([55, 37]),
#   'Prize': array([3557, 3726])},
#  {'ButtonA': array([20, 71]),
#   'ButtonB': array([74, 15]),
#   'Prize': array([ 240, 1764])},
#  {'ButtonA': array([11, 15]),
#   'ButtonB': array([84, 19]),
#   'Prize': array([4235, 1571])},
#  {'ButtonA': array([15, 82]),
#   'ButtonB': array([91, 44]),
#   'Prize': array([6849, 6152])},
#  {'ButtonA': array([25, 14]),
#   'ButtonB': array([21, 81]),
#   'Prize': array([2958, 8442])},
#  {'ButtonA': array([13, 56]),
#   'ButtonB': array([81, 26]),
#   'Prize': array([5732, 6608])},
#  {'ButtonA': array([84, 11]),
#   'ButtonB': array([45, 77]),
#   'Prize': array([1968, 1111])},
#  {'ButtonA': array([79, 17]),
#   'ButtonB': array([40, 99]),
#   'Prize': array([4393, 2482])},
#  {'ButtonA': array([16, 57]),
#   'ButtonB': array([94, 74]),
#   'Prize': array([ 9600, 11243])},
#  {'ButtonA': array([36, 28]),
#   'ButtonB': array([86, 11]),
#   'Prize': array([6190, 2523])},
#  {'ButtonA': array([96, 22]),
#   'ButtonB': array([24, 89]),
#   'Prize': array([9216, 4784])},
#  {'ButtonA': array([57, 23]),
#   'ButtonB': array([19, 60]),
#   'Prize': array([19120,  4428])},
#  {'ButtonA': array([17, 87]),
#   'ButtonB': array([41, 46]),
#   'Prize': array([1957, 2807])},
#  {'ButtonA': array([29, 19]),
#   'ButtonB': array([33, 95]),
#   'Prize': array([3414, 4218])},
#  {'ButtonA': array([51, 20]),
#   'ButtonB': array([58, 85]),
#   'Prize': array([8149, 7180])},
#  {'ButtonA': array([40, 14]),
#   'ButtonB': array([19, 36]),
#   'Prize': array([3540, 3000])},
#  {'ButtonA': array([56, 53]),
#   'ButtonB': array([92, 17]),
#   'Prize': array([9864, 3870])},
#  {'ButtonA': array([55, 89]),
#   'ButtonB': array([50, 16]),
#   'Prize': array([8175, 7257])},
#  {'ButtonA': array([56, 30]),
#   'ButtonB': array([41, 90]),
#   'Prize': array([3087, 5940])},
#  {'ButtonA': array([56, 14]),
#   'ButtonB': array([17, 44]),
#   'Prize': array([ 9023, 15770])},
#  {'ButtonA': array([47, 14]),
#   'ButtonB': array([13, 37]),
#   'Prize': array([13845,  3384])},
#  {'ButtonA': array([33, 12]),
#   'ButtonB': array([20, 32]),
#   'Prize': array([17882, 19448])},
#  {'ButtonA': array([39, 80]),
#   'ButtonB': array([47, 14]),
#   'Prize': array([2467, 4154])},
#  {'ButtonA': array([57, 38]),
#   'ButtonB': array([20, 41]),
#   'Prize': array([3381, 8345])},
#  {'ButtonA': array([51, 14]),
#   'ButtonB': array([17, 79]),
#   'Prize': array([5304, 8592])},
#  {'ButtonA': array([54, 24]),
#   'ButtonB': array([24, 48]),
#   'Prize': array([ 2462, 16568])},
#  {'ButtonA': array([11, 37]),
#   'ButtonB': array([43, 39]),
#   'Prize': array([561, 725])},
#  {'ButtonA': array([48, 23]),
#   'ButtonB': array([19, 40]),
#   'Prize': array([ 3232, 15593])},
#  {'ButtonA': array([86, 39]),
#   'ButtonB': array([12, 55]),
#   'Prize': array([ 2146, 17900])},
#  {'ButtonA': array([14, 43]),
#   'ButtonB': array([23, 20]),
#   'Prize': array([2192, 2276])}]

# %% [markdown]
# ## PART 1

# %%
def check_machine(prize, buttonA, buttonB):
    buttonA_delta = buttonA[1] - buttonA[0]
    buttonB_delta = buttonB[1] - buttonB[0]
    prize_delta = prize[1] - prize[0]

    buttonA_ratio = buttonA[1]/buttonA[0]
    buttonB_ratio = buttonB[1]/buttonB[0]
    prize_ratio = prize[1]/prize[0]

    if (buttonA_delta*buttonB_delta <= 0):
        return
    else:
        print(f"Prize: {prize}, ButtonA: {buttonA}, ButtonB: {buttonB}")
        print(f"Prize ratio: {prize_ratio}, ButtonA ratio: {buttonA_ratio}, ButtonB ratio: {buttonB_ratio}")

def get_valid_presses(prize, buttonA, buttonB, max_presses):
    valid_presses = []
    # We keep removing buttonA and check buttonB
    for i in range(max_presses+1):
        pending_distance = prize - i*buttonA
        if (pending_distance < 0).any():
            break
        ratio0 = pending_distance[0] / buttonB[0]
        ratio1 = pending_distance[1] / buttonB[1]
        if (ratio0 == ratio1) and ratio0 <= max_presses and ratio0.is_integer():
            valid_presses.append([i, ratio0])
    return valid_presses

def solve_machine(prize, buttonA, buttonB, max_presses, press_token_cost):
    valid_presses = get_valid_presses(prize, buttonA, buttonB, max_presses)
    if len(valid_presses) == 0:
        return None
    lowest_cost = max_presses*press_token_cost[0] + max_presses*press_token_cost[1]
    for valid_press in valid_presses:
        token_cost = valid_press[0]*press_token_cost[0] + valid_press[1]*press_token_cost[1]
        if token_cost < lowest_cost:
            lowest_cost = token_cost
    return lowest_cost

# %%
# Solve part 1
total_token_cost = 0
all_token_costs_1 = []
for claw_machine in claw_machines:
    token_cost = solve_machine(claw_machine['Prize'], claw_machine['ButtonA'], claw_machine['ButtonB'], 100, (3, 1))
    all_token_costs_1.append(token_cost)
    if token_cost:
        total_token_cost += token_cost
print(int(total_token_cost))
# Out:
# 33481

# %% [markdown]
# ## PART 2

# %%
def solve_linear_system(prize, buttonA, buttonB):
    A = np.array([buttonA, buttonB]).transpose()
    if np.linalg.det(A) == 0:
        print(f"Multiple solutions for {prize}: buttonA: {buttonA}, buttonB: {buttonB}")
        return None
    B = prize
    X = np.linalg.solve(A, B)
    X_int = X.round(decimals=0).astype(int)
    if (np.dot(A, X_int) == B).all():
        return X_int
    return None

def get_cost(prize, buttonA, buttonB, press_token_cost):
    presses = solve_linear_system(prize, buttonA, buttonB)
    if presses is not None:
        return np.dot(presses, press_token_cost)
    return None

# %%
# Solve part 2
total_token_cost = 0
all_token_costs_2 = []
for claw_machine in claw_machines:
    prize = claw_machine['Prize']+ np.array([10000000000000,10000000000000])
    buttonA = claw_machine['ButtonA']
    buttonB = claw_machine['ButtonB']
    token_cost = get_cost(prize, buttonA, buttonB, np.array([3, 1]))
    all_token_costs_2.append(token_cost)
    if token_cost is not None:
        total_token_cost += token_cost
print(total_token_cost)
# Out:
# 92572057880885
